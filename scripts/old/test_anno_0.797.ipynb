# %%
# Read in Libraries
from __future__ import division, print_function
from logbook import Logger, StreamHandler
import sys
StreamHandler(sys.stdout).push_application()
log = Logger('Logbook')
import shutil, csv, time
timestr = time.strftime("%Y%m%d")
import ujson as json
import utils; reload(utils)
from utils import *
import gc
# from __future__ import division, print_function
from theano.sandbox import cuda
from vgg16bn import Vgg16BN
from sklearn import metrics
# %matplotlib inline

def accuracyfunc(y_act, y_pred):
    return metrics.accuracy_score(np.argmax(y_act, axis=1), np.argmax(y_pred, axis=1))
    
def refresh_directory_structure(name, sub_dirs):
    gdir = os.path.join(path, name)
    if os.path.exists(gdir):
        shutil.rmtree(gdir)
    os.makedirs(gdir)
    for sub_dir in sub_dirs:
        os.makedirs(os.path.join(gdir, sub_dir))
# Out:
# Using gpu device 0: Tesla K80 (CNMeM is disabled, cuDNN 5103)
# /home/ubuntu/anaconda2/lib/python2.7/site-packages/theano/sandbox/cuda/__init__.py:600: UserWarning: Your cuDNN version is more recent than the one Theano officially supports. If you see any problems, try updating Theano or downgrading cuDNN to version 5.
#   warnings.warn(warn)
# Using Theano backend.

# %%
# Set Parameters and check files
refresh_directories = False
input_exists = True
full = True
log.info('Set Paramters')
path = "../data/fish/"
batch_size=32
clip = 0.99
bags = 1
load_size = (440, 780)#(360, 640)
# Out:
# [2017-02-18 22:33:12.277079] INFO: Logbook: Set Paramters

# %%
# Create the test and valid directory
if refresh_directories:
    log.info('Create directory structure and validation files')
    sub_dirs = os.listdir(os.path.join(path, 'train-all'))
    if '.DS_Store' in sub_dirs: sub_dirs.remove('.DS_Store')
    refresh_directory_structure('train', sub_dirs)
    refresh_directory_structure('valid', sub_dirs)
    for c,row in enumerate(csv.DictReader(open('../image_validation_set.csv'))):
        value = 'valid' if row['Validation'] == '1' else 'train'
        name_from = os.path.join(path, 'train-all', row['SubDirectory'], row['file_name'])
        name_to   = os.path.join(path, value, row['SubDirectory'], row['file_name'])
        shutil.copyfile(name_from, name_to)

# %%
# Read in our VGG pretrained model
log.info('Get VGG')
model = vgg_ft_bn(8)

# Create our VGG model
log.info('Create VGG')
vgg640 = Vgg16BN(load_size).model
vgg640.pop()
vgg640.input_shape, vgg640.output_shape
vgg640.compile(Adam(), 'categorical_crossentropy', metrics=['accuracy'])

# get labels
(val_classes, trn_classes, val_labels, trn_labels,
    val_filenames, filenames, test_filenames) = get_classes(path)

# Read in filenames
log.info('Read filenames')
raw_filenames = [f.split('/')[-1] for f in filenames]
raw_test_filenames = [f.split('/')[-1] for f in test_filenames]
raw_val_filenames = [f.split('/')[-1] for f in val_filenames]
# Out:
# [2017-02-18 22:33:12.301056] INFO: Logbook: Get VGG
# [2017-02-18 22:33:15.466100] INFO: Logbook: Create VGG
# Found 3086 images belonging to 8 classes.
# Found 691 images belonging to 8 classes.
# Found 1000 images belonging to 1 classes.
# [2017-02-18 22:33:16.093835] INFO: Logbook: Read filenames

# %%
# Read in the boxes
anno_classes = ['alb', 'bet', 'dol', 'lag', 'other', 'shark', 'yft']
bb_json = {}
for c in anno_classes:
    j = json.load(open(os.path.join(path, 'box/{}_labels.json'.format(c)), 'r'))
    for l in j:
        if 'annotations' in l.keys() and len(l['annotations'])>0:
            bb_json[l['filename'].split('/')[-1]] = sorted(
                l['annotations'], key=lambda x: x['height']*x['width'])[-1]

# make it easy to find the nof dots, by putting themin the middle
#empty_bbox = {'height': 0., 'width': 0., 'x': 1280/2., 'y': 720/2}
empty_bbox = {'height': 0., 'width': 0., 'x': 0., 'y': 0.}

for f in raw_filenames:
    if not f in bb_json.keys(): bb_json[f] = empty_bbox
for f in raw_val_filenames:
    if not f in bb_json.keys(): bb_json[f] = empty_bbox

# %%
# Finally, we convert the dictionary into an array, and convert the coordinates to our resized 224x224 images.
bb_params = ['height', 'width', 'x', 'y']
def convert_bb(bb, size):
    bb = [bb[p] for p in bb_params]
    conv_x = (load_size[1] / size[0])#(224. / size[0])
    conv_y = (load_size[0] / size[1])#(224. / size[1])
    bb[0] = bb[0]*conv_y
    bb[1] = bb[1]*conv_x
    bb[2] = max(bb[2]*conv_x, 0)
    bb[3] = max(bb[3]*conv_y, 0)
    return bb

# %%
trn_sizes = [PIL.Image.open(path+'train/'+f).size for f in filenames]
val_sizes = [PIL.Image.open(path+'valid/'+f).size for f in val_filenames]
tst_sizes = [PIL.Image.open(path+'test/'+f).size for f in test_filenames]

# %%
trn_bbox = np.stack([convert_bb(bb_json[f], s) for f,s in zip(raw_filenames, trn_sizes)], 
                   ).astype(np.float32)
val_bbox = np.stack([convert_bb(bb_json[f], s) 
                   for f,s in zip(raw_val_filenames, val_sizes)]).astype(np.float32)

# %%
def create_rect(bb, color='red'):
    return plt.Rectangle((bb[2], bb[3]), bb[1], bb[0], color=color, fill=False, lw=3)

def show_bb(i):
    bb = val_bbox[i]
    plot(val[i])
    plt.gca().add_patch(create_rect(bb))

val = get_data(path+'valid', load_size)
show_bb(500)
del val
gc.collect()
# Out:
# Found 691 images belonging to 8 classes.
# 1906

# %%
log.info('Read in data')
if not input_exists:

    batches = get_batches(path+'train', batch_size=batch_size)
    val_batches = get_batches(path+'valid', batch_size=batch_size*2, shuffle=False)
    (val_classes, trn_classes, val_labels, trn_labels, 
        val_filenames, filenames, test_filenames) = get_classes(path)
    
    # Fetch our large images 
    # Precompute the output of the convolutional part of VGG
    log.info('Fetch images')
    log.info('Get VGG output')
    log.info('Write VGG output')
    
    val = get_data(path+'valid', load_size)
    conv_val_feat = vgg640.predict(val, batch_size=16, verbose=1)
    save_array(path+'results/conv_val_big_feat.dat', conv_val_feat)
    del val, conv_val_feat
    gc.collect()
    
    trn = get_data(path+'train', load_size)
    conv_trn_feat = vgg640.predict(trn, batch_size=16, verbose=1)    
    del trn
    gc.collect()
    save_array(path+'results/conv_trn_big_feat.dat', conv_trn_feat) 
    del conv_trn_feat
    gc.collect()
    
    test = get_data(path+'test', load_size)
    conv_test_feat = vgg640.predict(test, batch_size=16, verbose=1)
    save_array(path+'results/conv_test_big_feat.dat', conv_test_feat)     
    del test, conv_test_feat
    gc.collect()

    # For memory purposes delete out the original train and validation
    log.info('Clear up memory')
    #del trn, val, test
    gc.collect()
    gc.collect()
# Out:
# [2017-02-18 22:34:07.151478] INFO: Logbook: Read in data

# %%
gc.collect()
conv_val_feat = load_array(path+'results/conv_val_big_feat.dat')
conv_trn_feat = load_array(path+'results/conv_trn_big_feat.dat') 
conv_test_feat = load_array(path+'results/conv_test_big_feat.dat')

# %%
if full:
    conv_trn_feat = np.concatenate([conv_trn_feat, conv_val_feat])
    trn_labels = np.concatenate([trn_labels, val_labels]) 
    trn_bbox = np.concatenate([trn_bbox, val_bbox])
    
# Our Convolutional Net Architecture
log.info('Create and fit CNN')
p=0.6
# Set up the fully convolutional net (FCN); 
conv_layers,_ = split_at(vgg640, Convolution2D)
nf=128; p=0. # No dropout
# Out:
# [2017-02-18 22:34:19.675924] INFO: Logbook: Create and fit CNN

# %%
gc.collect()
nf = 512
p  = 0.3
def create_model():
    inp = Input(conv_layers[-1].output_shape[1:])
    x = MaxPooling2D()(inp)
    x = ZeroPadding2D((1,1))(x)
    x = Convolution2D(nf,3,3, activation='relu', border_mode='same')(x)
    x =   Dropout(p)(x)
    x = BatchNormalization(axis=1)(x)
    #x = MaxPooling2D()(x)
    #x = ZeroPadding2D((1,1))(x)
    #x = Convolution2D(nf,3,3, activation='relu', border_mode='same')(x)
    #x =   Dropout(p)(x)
    #x = BatchNormalization(axis=1)(x)
    x = MaxPooling2D()(x)
    x = ZeroPadding2D((1,1))(x)
    x = Convolution2D(nf,3,3, activation='relu', border_mode='same')(x)
    x =   Dropout(p)(x)
    x = BatchNormalization(axis=1)(x)
    x1 =   MaxPooling2D()(x)
    x1 =   Convolution2D(8,3,3, border_mode='same')(x1)
    x1 =   Dropout(p/2)(x1)
    x1 =   GlobalAveragePooling2D()(x1)
    x = Dropout(p/2)(x)
    x = Flatten()(x)
    x = Dense(1024, activation='relu')(x)
    x = BatchNormalization()(x)
    x = Dropout(p/2)(x)
    x = Dense(1024, activation='relu')(x)
    x = BatchNormalization()(x)
    x = Dropout(p/2)(x)
    x_bb = Dense(4, name='bb')(x)
    x_class = Dense(8, activation='softmax', name='class')(x1)
    return inp, x_bb, x_class

## Set up the fully convolutional net (FCN); 
#conv_layers,_ = split_at(vgg640, Convolution2D)
#nf=128; p=0. # No dropout

model = []
predsls = []
pvalsls = []

for ii in range(5):
    inp, x_bb, x_class = create_model()
    model.append(Model([inp], [x_bb, x_class]))
    #model.summary()
    model[ii].compile(Adam(lr=1e-3), loss=['mse', 'categorical_crossentropy'], metrics=['accuracy'],
                 loss_weights=[.001, 1.])
    model[ii].fit(conv_trn_feat, [trn_bbox, trn_labels], batch_size=batch_size, nb_epoch=5, 
                 validation_data=(conv_val_feat, [val_bbox, val_labels]))
    model[ii].optimizer.lr = 1e-4
    model[ii].optimizer.loss_weights=[.00001, 1.]
    model[ii].fit(conv_trn_feat, [trn_bbox, trn_labels], batch_size=batch_size, nb_epoch=2, 
                 validation_data=(conv_val_feat, [val_bbox, val_labels]))
    model[ii].optimizer.lr = 1e-5

    count = 0
    while count < 8:
        model[ii].fit(conv_trn_feat, [trn_bbox, trn_labels], batch_size=batch_size, nb_epoch=1, 
                     validation_data=(conv_val_feat, [val_bbox, val_labels]))
        predsls.append(model[ii].predict(conv_test_feat, batch_size=batch_size)[1]) # or try 32 batch_size
        pvalsls.append(model[ii].predict(conv_val_feat, batch_size=batch_size)[1])
        val_score = "%.3f" % metrics.log_loss(val_labels, sum(pvalsls)/len(pvalsls))
        acc_score = "%.3f" % accuracyfunc(val_labels, do_clip(sum(pvalsls)/len(pvalsls), clip))
        log.info('Bagged Validation Logloss ' + str(val_score))
        log.info('Bagged Validation Accuracy ' + str(acc_score))
        count += 1
# Out:
# th
# Train on 3777 samples, validate on 691 samples
# Epoch 1/5
# 3777/3777 [==============================] - 33s - loss: 34.4435 - bb_loss: 33394.2686 - class_loss: 1.0492 - bb_acc: 0.6230 - class_acc: 0.6939 - val_loss: 28.2478 - val_bb_loss: 27823.5364 - val_class_loss: 0.4243 - val_bb_acc: 0.7540 - val_class_acc: 0.9059
# Epoch 2/5
# 3777/3777 [==============================] - 33s - loss: 22.2877 - bb_loss: 21979.1656 - class_loss: 0.3085 - bb_acc: 0.6987 - class_acc: 0.9076 - val_loss: 18.1931 - val_bb_loss: 17638.7677 - val_class_loss: 0.5543 - val_bb_acc: 0.6773 - val_class_acc: 0.7887
# Epoch 3/5
# 3777/3777 [==============================] - 33s - loss: 9.5350 - bb_loss: 9283.6714 - class_loss: 0.2514 - bb_acc: 0.7389 - class_acc: 0.9298 - val_loss: 5.2009 - val_bb_loss: 5083.0964 - val_class_loss: 0.1178 - val_bb_acc: 0.7945 - val_class_acc: 0.9609
# Epoch 4/5
# 3777/3777 [==============================] - 33s - loss: 2.7923 - bb_loss: 2714.5000 - class_loss: 0.0778 - bb_acc: 0.8038 - class_acc: 0.9778 - val_loss: 2.3409 - val_bb_loss: 2144.4258 - val_class_loss: 0.1965 - val_bb_acc: 0.8263 - val_class_acc: 0.9508
# Epoch 5/5
# 3777/3777 [==============================] - 33s - loss: 1.5875 - bb_loss: 1493.6216 - class_loss: 0.0939 - bb_acc: 0.7972 - class_acc: 0.9672 - val_loss: 1.2904 - val_bb_loss: 1036.5447 - val_class_loss: 0.2538 - val_bb_acc: 0.7482 - val_class_acc: 0.9291
# Train on 3777 samples, validate on 691 samples
# Epoch 1/2
# 3777/3777 [==============================] - 33s - loss: 1.0384 - bb_loss: 1006.4800 - class_loss: 0.0319 - bb_acc: 0.8033 - class_acc: 0.9910 - val_loss: 0.4740 - val_bb_loss: 423.3801 - val_class_loss: 0.0506 - val_bb_acc: 0.8495 - val_class_acc: 0.9957
# Epoch 2/2
# 3777/3777 [==============================] - 33s - loss: 0.9994 - bb_loss: 893.9712 - class_loss: 0.1054 - bb_acc: 0.8025 - class_acc: 0.9682 - val_loss: 1.0194 - val_bb_loss: 575.1863 - val_class_loss: 0.4442 - val_bb_acc: 0.8741 - val_class_acc: 0.8582
# Train on 3777 samples, validate on 691 samples
# Epoch 1/1
# 3777/3777 [==============================] - 33s - loss: 1.1040 - bb_loss: 990.9092 - class_loss: 0.1131 - bb_acc: 0.7877 - class_acc: 0.9719 - val_loss: 0.4943 - val_bb_loss: 474.1649 - val_class_loss: 0.0202 - val_bb_acc: 0.8900 - val_class_acc: 0.9928
# [2017-02-18 22:39:14.029613] INFO: Logbook: Bagged Validation Logloss 0.020
# [2017-02-18 22:39:14.030708] INFO: Logbook: Bagged Validation Accuracy 0.993
# Train on 3777 samples, validate on 691 samples
# Epoch 1/1
# 3777/3777 [==============================] -
# th
# Train on 3777 samples, validate on 691 samples
# Epoch 1/5
# 3777/3777 [==============================] - 33s - loss: 34.1503 - bb_loss: 33138.4641 - class_loss: 1.0119 - bb_acc: 0.6391 - class_acc: 0.7074 - val_loss: 43.2084 - val_bb_loss: 42495.2554 - val_class_loss: 0.7132 - val_bb_acc: 0.7236 - val_class_acc: 0.7496
# Epoch 2/5
# 3777/3777 [==============================] - 33s - loss: 22.2206 - bb_loss: 21907.8390 - class_loss: 0.3128 - bb_acc: 0.7035 - class_acc: 0.9102 - val_loss: 14.6848 - val_bb_loss: 14402.7444 - val_class_loss: 0.2820 - val_bb_acc: 0.7540 - val_class_acc: 0.9219
# Epoch 3/5
# 3777/3777 [==============================] - 33s - loss: 9.0941 - bb_loss: 8952.1517 - class_loss: 0.1420 - bb_acc: 0.7575 - class_acc: 0.9621 - val_loss: 3.8864 - val_bb_loss: 3758.7706 - val_class_loss: 0.1276 - val_bb_acc: 0.8046 - val_class_acc: 0.9754
# Epoch 4/5
# 3777/3777 [==============================] - 33s - loss: 2.9791 - bb_loss: 2844.6354 - class_loss: 0.1345 - bb_acc: 0.8020 - class_acc: 0.9640 - val_loss: 6.5732 - val_bb_loss: 5220.4968 - val_class_loss: 1.3527 - val_bb_acc: 0.6440 - val_class_acc: 0.6758
# Epoch 5/5
# 3777/3777 [==============================] - 33s - loss: 1.7040 - bb_loss: 1601.8645 - class_loss: 0.1022 - bb_acc: 0.8001 - class_acc: 0.9722 - val_loss: 0.9363 - val_bb_loss: 881.6177 - val_class_loss: 0.0547 - val_bb_acc: 0.8148 - val_class_acc: 0.9913
# Train on 3777 samples, validate on 691 samples
# Epoch 1/2
# 3777/3777 [==============================] - 33s - loss: 1.1675 - bb_loss: 1116.9818 - class_loss: 0.0505 - bb_acc: 0.8051 - class_acc: 0.9844 - val_loss: 0.5568 - val_bb_loss: 500.4497 - val_class_loss: 0.0564 - val_bb_acc: 0.8524 - val_class_acc: 0.9870
# Epoch 2/2
# 3777/3777 [==============================] - 33s - loss: 1.0040 - bb_loss: 983.9905 - class_loss: 0.0200 - bb_acc: 0.7964 - class_acc: 0.9942 - val_loss: 1.1100 - val_bb_loss: 778.6411 - val_class_loss: 0.3313 - val_bb_acc: 0.8220 - val_class_acc: 0.9030
# Train on 3777 samples, validate on 691 samples
# Epoch 1/1
# 3777/3777 [==============================] - 33s - loss: 1.0071 - bb_loss: 902.7632 - class_loss: 0.1043 - bb_acc: 0.7980 - class_acc: 0.9741 - val_loss: 0.4890 - val_bb_loss: 449.2813 - val_class_loss: 0.0397 - val_bb_acc: 0.8249 - val_class_acc: 0.9928
# [2017-02-18 22:48:45.593560] INFO: Logbook: Bagged Validation Logloss 0.010
# [2017-02-18 22:48:45.594386] INFO: Logbook: Bagged Validation Accuracy 1.000
# Train on 3777 samples, validate on 691 samples
# Epoch 1/1
# 3777/3777 [==============================] - 33s - loss: 1.0628 - bb_loss: 963.0210 - class_loss: 0.0997 - bb_acc: 0.8022 - class_acc: 0.9764 - val_loss: 0.5707 - val_bb_loss: 553.3010 - val_class_loss: 0.0174 - val_bb_acc: 0.8205 - val_class_acc: 0.9971
# [2017-02-18 22:49:25.176859] INFO: Logbook: Bagged Validation Logloss 0.011
# [2017-02-18 22:49:25.177687] INFO: Logbook: Bagged Validation Accuracy 1.000
# Train on 3777 samples, validate on 691 samples
# Epoch 1/1
# 3777/3777 [==============================] -
# 3777/3777 [==============================] - 33s - loss: 9.5614 - bb_loss: 9308.5868 - class_loss: 0.2528 - bb_acc: 0.7580 - class_acc: 0.9378 - val_loss: 3.3107 - val_bb_loss: 3162.6762 - val_class_loss: 0.1480 - val_bb_acc: 0.7670 - val_class_acc: 0.9667
# Epoch 4/5
# 3777/3777 [==============================] - 33s - loss: 2.9775 - bb_loss: 2832.8588 - class_loss: 0.1446 - bb_acc: 0.7983 - class_acc: 0.9600 - val_loss: 2.0581 - val_bb_loss: 1792.0248 - val_class_loss: 0.2661 - val_bb_acc: 0.8307 - val_class_acc: 0.9146
# Epoch 5/5
# 3777/3777 [==============================] - 33s - loss: 1.6371 - bb_loss: 1472.6273 - class_loss: 0.1644 - bb_acc: 0.8120 - class_acc: 0.9587 - val_loss: 1.1847 - val_bb_loss: 1145.1235 - val_class_loss: 0.0396 - val_bb_acc: 0.7931 - val_class_acc: 0.9899
# Train on 3777 samples, validate on 691 samples
# Epoch 1/2
# 3777/3777 [==============================] - 33s - loss: 1.2418 - bb_loss: 1196.6875 - class_loss: 0.0451 - bb_acc: 0.7914 - class_acc: 0.9878 - val_loss: 0.6368 - val_bb_loss: 578.0478 - val_class_loss: 0.0587 - val_bb_acc: 0.8278 - val_class_acc: 0.9913
# Epoch 2/2
# 3777/3777 [==============================] - 33s - loss: 0.9797 - bb_loss: 956.7146 - class_loss: 0.0230 - bb_acc: 0.8006 - class_acc: 0.9923 - val_loss: 0.9416 - val_bb_loss: 513.2802 - val_class_loss: 0.4283 - val_bb_acc: 0.8452 - val_class_acc: 0.8755
# Train on 3777 samples, validate on 691 samples
# Epoch 1/1
# 3777/3777 [==============================] - 34s - loss: 1.3582 - bb_loss: 1074.9255 - class_loss: 0.2832 - bb_acc: 0.8014 - class_acc: 0.9388 - val_loss: 0.6857 - val_bb_loss: 650.9787 - val_class_loss: 0.0348 - val_bb_acc: 0.8263 - val_class_acc: 0.9899
# [2017-02-18 23:07:52.861607] INFO: Logbook: Bagged Validation Logloss 0.022
# [2017-02-18 23:07:52.862459] INFO: Logbook: Bagged Validation Accuracy 1.000
# Train on 3777 samples, validate on 691 samples
# Epoch 1/1
# 3777/3777 [==============================] - 34s - loss: 0.9124 - bb_loss: 883.5523 - class_loss: 0.0288 - bb_acc: 0.7996 - class_acc: 0.9923 - val_loss: 0.4531 - val_bb_loss: 423.4538 - val_class_loss: 0.0296 - val_bb_acc: 0.8538 - val_class_acc: 0.9899
# [2017-02-18 23:08:32.877824] INFO: Logbook: Bagged Validation Logloss 0.022
# [2017-02-18 23:08:32.878656] INFO: Logbook: Bagged Validation Accuracy 1.000
# Train on 3777 samples, validate on 691 samples
# Epoch 1/1
# 3777/3777 [==============================] - 34s - loss: 0.8420 - bb_loss: 827.2766 - class_loss: 0.0148 - bb_acc: 0.7996 - class_acc: 0.9960 - val_loss: 0.2941 - val_bb_loss: 287.2114 - val_class_loss: 0.0068 - val_bb_acc: 0.8553 - val_class_acc: 0.9986
# [2017-02-18 23:09:13.015541] INFO: Logbook: Bagged Validation Logloss 0.021
# [2017-02-18 23:09:13.016411] INFO: Logbook: Bagged Validation Accuracy 1.000
# Train on 3777 samples, validate on 691 samples
# Epoch 1/1
# 3777/3777 [==============================] -
# 3777/3777 [==============================] - 33s - loss: 3.0541 - bb_loss: 2940.9911 - class_loss: 0.1132 - bb_acc: 0.7932 - class_acc: 0.9669 - val_loss: 1.5096 - val_bb_loss: 1414.3822 - val_class_loss: 0.0952 - val_bb_acc: 0.8553 - val_class_acc: 0.9740
# Epoch 5/5
# 3777/3777 [==============================] - 33s - loss: 1.6622 - bb_loss: 1578.3455 - class_loss: 0.0839 - bb_acc: 0.7919 - class_acc: 0.9799 - val_loss: 3.4414 - val_bb_loss: 2610.3276 - val_class_loss: 0.8311 - val_bb_acc: 0.8452 - val_class_acc: 0.6874
# Train on 3777 samples, validate on 691 samples
# Epoch 1/2
# 3777/3777 [==============================] - 33s - loss: 1.3826 - bb_loss: 1252.6641 - class_loss: 0.1300 - bb_acc: 0.8012 - class_acc: 0.9629 - val_loss: 1.0345 - val_bb_loss: 863.4887 - val_class_loss: 0.1710 - val_bb_acc: 0.8148 - val_class_acc: 0.9638
# Epoch 2/2
# 3777/3777 [==============================] - 33s - loss: 1.1156 - bb_loss: 1061.0767 - class_loss: 0.0545 - bb_acc: 0.7943 - class_acc: 0.9870 - val_loss: 0.8473 - val_bb_loss: 660.0066 - val_class_loss: 0.1872 - val_bb_acc: 0.8090 - val_class_acc: 0.9522
# Train on 3777 samples, validate on 691 samples
# Epoch 1/1
# 3777/3777 [==============================] - 33s - loss: 1.1091 - bb_loss: 997.0991 - class_loss: 0.1120 - bb_acc: 0.7916 - class_acc: 0.9725 - val_loss: 0.7583 - val_bb_loss: 652.4564 - val_class_loss: 0.1058 - val_bb_acc: 0.8596 - val_class_acc: 0.9855
# [2017-02-18 23:17:31.850624] INFO: Logbook: Bagged Validation Logloss 0.022
# [2017-02-18 23:17:31.851587] INFO: Logbook: Bagged Validation Accuracy 1.000
# Train on 3777 samples, validate on 691 samples
# Epoch 1/1
# 3777/3777 [==============================] - 33s - loss: 0.8702 - bb_loss: 838.8924 - class_loss: 0.0313 - bb_acc: 0.8075 - class_acc: 0.9934 - val_loss: 0.5997 - val_bb_loss: 516.8357 - val_class_loss: 0.0829 - val_bb_acc: 0.8611 - val_class_acc: 0.9942
# [2017-02-18 23:18:11.633372] INFO: Logbook: Bagged Validation Logloss 0.022
# [2017-02-18 23:18:11.634300] INFO: Logbook: Bagged Validation Accuracy 1.000
# Train on 3777 samples, validate on 691 samples
# Epoch 1/1
# 3777/3777 [==============================] - 33s - loss: 0.8498 - bb_loss: 825.3709 - class_loss: 0.0244 - bb_acc: 0.8088 - class_acc: 0.9955 - val_loss: 0.8224 - val_bb_loss: 728.1055 - val_class_loss: 0.0943 - val_bb_acc: 0.8292 - val_class_acc: 0.9884
# [2017-02-18 23:18:51.403276] INFO: Logbook: Bagged Validation Logloss 0.022
# [2017-02-18 23:18:51.404052] INFO: Logbook: Bagged Validation Accuracy 1.000
# Train on 3777 samples, validate on 691 samples
# Epoch 1/1
# 3777/3777 [==============================] - 33s - loss: 0.9315 - bb_loss: 775.5139 - class_loss: 0.1560 - bb_acc: 0.8054 - class_acc: 0.9682 - val_loss: 0.7092 - val_bb_loss: 630.0763 - val_class_loss: 0.0792 - val_bb_acc: 0.8220 - val_class_acc: 0.9913
# [2017-02-18 23:19:31.143233] INFO: Logbook: Bagged Validation Logloss 0.022
# [2017-02-18 23:19:31.144042] INFO: Logbook: Bagged Validation Accuracy 1.000
# Train on 3777 samples, validate on 691 samples
# Epoch 1/1
# 3777/3777 [==============================] - 33s - loss: 0.7855 - bb_loss: 747.4109 - class_loss: 0.0381 - bb_acc: 0.8118 - class_acc: 0.9944 - val_loss: 0.7203 - val_bb_loss: 547.6353 - val_class_loss: 0.1727 - val_bb_acc: 0.9363 - val_class_acc: 0.9537
# [2017-02-18 23:20:10.842444] INFO: Logbook: Bagged Validation Logloss 0.023
# [2017-02-18 23:20:10.843248] INFO: Logbook: Bagged Validation Accuracy 1.000
# Train on 3777 samples, validate on 691 samples
# Epoch 1/1
# 3777/3777 [==============================] - 33s - loss: 0.8007 - bb_loss: 718.8626 - class_loss: 0.0819 - bb_acc: 0.8070 - class_acc: 0.9807 - val_loss: 0.4064 - val_bb_loss: 333.6358 - val_class_loss: 0.0728 - val_bb_acc: 0.9074 - val_class_acc: 0.9957
# [2017-02-18 23:20:50.528754] INFO: Logbook: Bagged Validation Logloss 0.023
# [2017-02-18 23:20:50.529679] INFO: Logbook: Bagged Validation Accuracy 1.000
# Train on 3777 samples, validate on 691 samples
# Epoch 1/1
# 3777/3777 [==============================] - 33s - loss: 0.7216 - bb_loss: 697.4221 - class_loss: 0.0242 - bb_acc: 0.8125 - class_acc: 0.9974 - val_loss: 0.4103 - val_bb_loss: 316.6139 - val_class_loss: 0.0936 - val_bb_acc: 0.8452 - val_class_acc: 0.9899
# [2017-02-18 23:21:30.194052] INFO: Logbook: Bagged Validation Logloss 0.022
# [2017-02-18 23:21:30.194869] INFO: Logbook: Bagged Validation Accuracy 1.000
# Train on 3777 samples, validate on 691 samples
# Epoch 1/1
# 3777/3777 [==============================] - 33s - loss: 0.8800 - bb_loss: 769.9944 - class_loss: 0.1100 - bb_acc: 0.8163 - class_acc: 0.9751 - val_loss: 0.4408 - val_bb_loss: 299.3685 - val_class_loss: 0.1414 - val_bb_acc: 0.8263 - val_class_acc: 0.9797
# [2017-02-18 23:22:09.908561] INFO: Logbook: Bagged Validation Logloss 0.023
# [2017-02-18 23:22:09.909500] INFO: Logbook: Bagged Validation Accuracy 1.000

# %%
val = get_data(path+'valid', load_size)
pval_bbox = model[0].predict(conv_val_feat, batch_size=batch_size)[0]
# Out:
# Found 691 images belonging to 8 classes.

# %%
def create_rect(bb, color='red'):
    return plt.Rectangle((bb[2], bb[3]), bb[1], bb[0], color=color, fill=False, lw=3)

def show_bb(i):
    bb = val_bbox[i]
    pbb = pval_bbox[i]
    plot(val[i])
    plt.gca().add_patch(create_rect(bb, color='red'))
    plt.gca().add_patch(create_rect(pbb, color='yellow'))

show_bb(350)

# %%
# metrics.log_loss(val_labels, do_clip(sum(pvalsls)/len(pvalsls), .9999))
preds = sum(predsls)/len(predsls)
subm = do_clip(preds, clip)

if full:
    subm_name = path+'results/subm_full_conv_' + timestr + 'B.csv' #'.csv.gz'
else:
    subm_name = path+'results/subm_part_conv_' + timestr + 'B.csv' #'.csv.gz'

classes = ['ALB', 'BET', 'DOL', 'LAG', 'NoF', 'OTHER', 'SHARK', 'YFT']
submission = pd.DataFrame(subm, columns=classes)
submission.insert(0, 'image', raw_test_filenames)
submission.to_csv(subm_name, index=False)#, compression='gzip')
log.info('Done - files @ ' + subm_name)
# Out:
# [2017-02-18 23:24:30.029553] INFO: Logbook: Done - files @ ../data/fish/results/subm_full_conv_20170218B.csv

# %%
FileLink(subm_name)
# Out:
# /home/ubuntu/fish/data/fish/results/subm_full_conv_20170218B.csv
