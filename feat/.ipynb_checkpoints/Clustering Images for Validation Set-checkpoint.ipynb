# %%
import os
import io
from PIL import Image
import pandas as pd
import numpy as np
import datetime
import matplotlib.pyplot as plt
import multiprocessing
from sklearn import cluster
import random
# %matplotlib inline
new_style = {'grid': False}
plt.rc('axes', **new_style)
random.seed(100);

# %%
# Set working directory
os.chdir('../data')

# %%
def hamdist(hash_set):
    diffs = 0
    for ch1, ch2 in zip(hash_set[0], hash_set[1]):
        if ch1 != ch2:
            diffs += 1
    return diffs

def dhash(image,hash_size = 16):
    image = image.convert('LA').resize((hash_size+1,hash_size),Image.ANTIALIAS)
    pixels = list(image.getdata())
    difference = []
    for row in xrange(hash_size):
        for col in xrange(hash_size):
            pixel_left = image.getpixel((col,row))
            pixel_right = image.getpixel((col+1,row))
            difference.append(pixel_left>pixel_right)
    decimal_value = 0
    hex_string = []
    for index, value in enumerate(difference):
        if value:
            decimal_value += 2**(index%8)
        if (index%8) == 7:
            hex_string.append(hex(decimal_value)[2:].rjust(2,'0'))
            decimal_value = 0
    return ''.join(hex_string)

# %%
counter = 1
hash_size = 16

# %%
os.path.join(parent_dir, direc)
# Out:
# 'test/.DS_Store'

# %%
# Lets get the train and test images and their respective gradient hashes
img_id_hash = []
parent_dir = "train-all"
subdir = os.listdir(os.path.join(parent_dir))
for direc in subdir: 
    try:
        names = os.listdir(os.path.join(parent_dir, direc))
    except:
        continue
    print counter, direc, parent_dir
    for name in names:
        imgdata = Image.open(os.path.join(parent_dir, direc, name)).convert("L")
        img_hash = dhash(imgdata, hash_size)
        img_id_hash.append([parent_dir, direc, name, img_hash])
        counter+=1

#parent_dir = "test"
#names = os.listdir(parent_dir)
#print counter, direc
#for name in names:
#    imgdata = Image.open(os.path.join(parent_dir, name)).convert("L")
#    img_hash = dhash(imgdata, hash_size)
#    img_id_hash.append([parent_dir, 'test', name, img_hash])
#    counter+=1

df = pd.DataFrame(img_id_hash,columns=['ParDirectory' , 'SubDirectory', 'file_name', 'image_hash'])
# Out:
# 1 DOL train-all
# 118 YFT train-all
# 852 NoF train-all
# 1317 SHARK train-all
# 1493 ALB train-all
# 3212 LAG train-all
# 3279 BET train-all
# 3479 OTHER train-all

# %%
df.head(3)
# Out:
#   ParDirectory SubDirectory      file_name  \
# 0    train-all          DOL  img_05521.jpg
# 1    train-all          DOL  img_06204.jpg
# 2    train-all          DOL  img_02267.jpg
#
#                                           image_hash
# 0  78857a8f7c8379037991fe146b25f369e2c9cdd9c9aecb...
# 1  4c88c638f536c50ca18d608c798ed3cea34611458d458d...
# 2  3bb113e109439dc511d133c9356135e11de101f34cf314...

# %%
# Create the distance matrix for the distances in images
pool = multiprocessing.Pool(8)
distances = np.zeros((df.shape[0], df.shape[0]))
for i, row in df.iterrows():
    #if i % 50 == 0: print i
    all_hashes = [(row['image_hash'], f) for f in df.image_hash.tolist()]
    dists = pool.map(hamdist, all_hashes)
    distances[i, :] = dists

# %%
# Get a histogram of the distances
plt.hist(distances.flatten(), bins=50)
plt.title('Histogram of distance matrix')

# %%
# Cluster the images - average cluster size ~ 10
cls = cluster.KMeans(n_clusters=df.shape[0]/10, n_jobs = 8)
y = cls.fit_predict(distances)

# %%
# show the size of the first 50 clusters
print(pd.Series(y).value_counts()[:5])
# Out:
# 76     36
# 32     34
# 18     29
# 28     27
# 149    26
# dtype: int64

# %%
# Lets look at the first 5 clusters
_, ax = plt.subplots(12, 5, figsize=(10, 20))
ax = ax.flatten()
counter = 0
for c in range(20):
    for i, row in df[y==c].iterrows():
        if counter  == len(ax): 
            break
        if row['ParDirectory'] == 'test' :
            imgdata = Image.open(os.path.join(row['ParDirectory'], row['file_name']))
        else:
            imgdata = Image.open(os.path.join(row['ParDirectory'], row['SubDirectory'], row['file_name']))
        axis = ax[counter]
        axis.set_title('Cluster ' + str(c) + ' ' + row['SubDirectory'], fontsize=10)
        axis.imshow(np.asarray(imgdata), interpolation='nearest', aspect='auto')        
        axis.axis('off')
        counter += 1

# %%
# Lets pullout some random 
random.seed(200)
samp = random.sample(range(len(np.unique(y))), len(np.unique(y))/6)
df['Cluster'] = y
df['Validation'] = np.where(df['Cluster'].isin(samp), 1, 0)

# %%
# Break down of full data
df.SubDirectory.value_counts()
# Out:
# ALB      1719
# YFT       734
# NoF       465
# OTHER     299
# BET       200
# SHARK     176
# DOL       117
# LAG        67
# Name: SubDirectory, dtype: int64

# %%
# Break down of validation data
df[df['Validation'] == 1].SubDirectory.value_counts()
# Out:
# ALB      298
# YFT      107
# OTHER    104
# NoF       69
# SHARK     59
# BET       27
# DOL       16
# LAG       11
# Name: SubDirectory, dtype: int64

# %%
# Write file out to main directory
df.to_csv('../image_validation_set.csv', index=False)
