# %%
# Read in Libraries
from __future__ import division, print_function
from logbook import Logger, StreamHandler
import sys
StreamHandler(sys.stdout).push_application()
log = Logger('Logbook')
import shutil, csv, time
timestr = time.strftime("%Y%m%d")
import ujson as json
import utils; reload(utils)
from utils import *
import gc
# from __future__ import division, print_function
from theano.sandbox import cuda
from vgg16bn import Vgg16BN
from sklearn import metrics
# %matplotlib inline

def accuracyfunc(y_act, y_pred):
    return metrics.accuracy_score(np.argmax(y_act, axis=1), np.argmax(y_pred, axis=1))
    
def refresh_directory_structure(name, sub_dirs):
    gdir = os.path.join(path, name)
    if os.path.exists(gdir):
        shutil.rmtree(gdir)
    os.makedirs(gdir)
    for sub_dir in sub_dirs:
        os.makedirs(os.path.join(gdir, sub_dir))
# Out:
# Using gpu device 0: Tesla K80 (CNMeM is disabled, cuDNN 5103)
# /home/ubuntu/anaconda2/lib/python2.7/site-packages/theano/sandbox/cuda/__init__.py:600: UserWarning: Your cuDNN version is more recent than the one Theano officially supports. If you see any problems, try updating Theano or downgrading cuDNN to version 5.
#   warnings.warn(warn)
# Using Theano backend.

# %%
# Set Parameters and check files
refresh_directories = False
input_exists = True
full = False
log.info('Set Paramters')
path = "../data/fish/"
batch_size=32
clip = 0.99
bags = 1
load_size = (440, 780)#(360, 640)
aug_batches = 2
# Out:
# [2017-02-20 23:10:40.117614] INFO: Logbook: Set Paramters

# %%
# Create the test and valid directory
if refresh_directories:
    log.info('Create directory structure and validation files')
    sub_dirs = os.listdir(os.path.join(path, 'train-all'))
    if '.DS_Store' in sub_dirs: sub_dirs.remove('.DS_Store')
    refresh_directory_structure('train', sub_dirs)
    refresh_directory_structure('valid', sub_dirs)
    for c,row in enumerate(csv.DictReader(open('../image_validation_set.csv'))):
        value = 'valid' if row['Validation'] == '1' else 'train'
        name_from = os.path.join(path, 'train-all', row['SubDirectory'], row['file_name'])
        name_to   = os.path.join(path, value, row['SubDirectory'], row['file_name'])
        shutil.copyfile(name_from, name_to)

# %%
# Read in our VGG pretrained model
log.info('Get VGG')
model = vgg_ft_bn(8)

# Create our VGG model
log.info('Create VGG')
vgg640 = Vgg16BN(load_size).model
vgg640.pop()
vgg640.input_shape, vgg640.output_shape
vgg640.compile(Adam(), 'categorical_crossentropy', metrics=['accuracy'])

# get labels
(val_classes, trn_classes, val_labels, trn_labels,
    val_filenames, filenames, test_filenames) = get_classes(path)

# Read in filenames
log.info('Read filenames')
raw_filenames = [f.split('/')[-1] for f in filenames]
raw_test_filenames = [f.split('/')[-1] for f in test_filenames]
raw_val_filenames = [f.split('/')[-1] for f in val_filenames]
# Out:
# [2017-02-20 23:10:40.147741] INFO: Logbook: Get VGG
# [2017-02-20 23:10:43.304306] INFO: Logbook: Create VGG
# Found 3086 images belonging to 8 classes.
# Found 691 images belonging to 8 classes.
# Found 1000 images belonging to 1 classes.
# [2017-02-20 23:10:43.842927] INFO: Logbook: Read filenames

# %%
# Read in the boxes
anno_classes = ['alb', 'bet', 'dol', 'lag', 'other', 'shark', 'yft']
bb_json = {}
for c in anno_classes:
    j = json.load(open(os.path.join(path, 'box/{}_labels.json'.format(c)), 'r'))
    for l in j:
        if 'annotations' in l.keys() and len(l['annotations'])>0:
            bb_json[l['filename'].split('/')[-1]] = sorted(
                l['annotations'], key=lambda x: x['height']*x['width'])[-1]

# make it easy to find the nof dots, by putting themin the middle
#empty_bbox = {'height': 0., 'width': 0., 'x': 1280/2., 'y': 720/2}
empty_bbox = {'height': 0., 'width': 0., 'x': 0., 'y': 0.}

for f in raw_filenames:
    if not f in bb_json.keys(): bb_json[f] = empty_bbox
for f in raw_val_filenames:
    if not f in bb_json.keys(): bb_json[f] = empty_bbox

# Finally, we convert the dictionary into an array, and convert the coordinates to our resized 224x224 images.
bb_params = ['height', 'width', 'x', 'y']
def convert_bb(bb, size):
    bb = [bb[p] for p in bb_params]
    conv_x = (load_size[1] / size[0])#(224. / size[0])
    conv_y = (load_size[0] / size[1])#(224. / size[1])
    bb[0] = bb[0]*conv_y
    bb[1] = bb[1]*conv_x
    bb[2] = max(bb[2]*conv_x, 0)
    bb[3] = max(bb[3]*conv_y, 0)
    return bb

# %%
trn_sizes = [PIL.Image.open(path+'train/'+f).size for f in filenames]
val_sizes = [PIL.Image.open(path+'valid/'+f).size for f in val_filenames]
tst_sizes = [PIL.Image.open(path+'test/'+f).size for f in test_filenames]

# %%
trn_bbox = np.stack([convert_bb(bb_json[f], s) for f,s in zip(raw_filenames, trn_sizes)], 
                   ).astype(np.float32)
val_bbox = np.stack([convert_bb(bb_json[f], s) 
                   for f,s in zip(raw_val_filenames, val_sizes)]).astype(np.float32)

# %%
def create_rect(bb, color='red'):
    return plt.Rectangle((bb[2], bb[3]), bb[1], bb[0], color=color, fill=False, lw=3)

def show_bb(i):
    bb = val_bbox[i]
    plot(val[i])
    plt.gca().add_patch(create_rect(bb))

val = get_data(path+'valid', load_size)
show_bb(500)
del val
gc.collect()
gc.collect()
# Out:
# Found 691 images belonging to 8 classes.
# 0

# %%
gen_t = image.ImageDataGenerator(rotation_range=15, height_shift_range=0.05, 
                shear_range=0.05, channel_shift_range=20, width_shift_range=0.05)
da_val_batches = get_batches(path+'valid', gen_t, batch_size=batch_size, shuffle=False, target_size=load_size)
da_trn_batches = get_batches(path+'train', gen_t, batch_size=batch_size, shuffle=False, target_size=load_size)
da_tst_batches = get_batches(path+'test', gen_t, batch_size=batch_size, shuffle=False, target_size=load_size)
gc.collect()
# Out:
# Found 691 images belonging to 8 classes.
# Found 3086 images belonging to 8 classes.
# Found 1000 images belonging to 1 classes.
# 4169

# %%
log.info('Read in data')
if not input_exists:
    
    # Fetch our large images 
    # Precompute the output of the convolutional part of VGG
    log.info('Fetch images')
    log.info('Get VGG output')
    log.info('Write VGG output')
    
    #log.info('Save Val Weights')
    da_conv_val_feat = vgg640.predict_generator(da_val_batches, da_val_batches.nb_sample*aug_batches)
    save_array(path+'results/da_conv_val_feat.dat', da_conv_val_feat)
    del da_conv_val_feat
    gc.collect()
    
    #log.info('Save Trn Weights')
    da_conv_trn_feat = vgg640.predict_generator(da_trn_batches, da_trn_batches.nb_sample*aug_batches)
    save_array(path+'results/da_conv_trn_feat.dat', da_conv_trn_feat)
    del da_conv_trn_feat
    gc.collect()
    
    val = get_data(path+'valid', load_size)
    conv_val_feat = vgg640.predict(val, batch_size=16, verbose=1)
    save_array(path+'results/dano_conv_val_feat.dat', conv_val_feat)
    del val, conv_val_feat
    gc.collect()
    
    test = get_data(path+'test', load_size)
    conv_test_feat = vgg640.predict(test, batch_size=16, verbose=1)
    save_array(path+'results/dano_conv_test_feat.dat', conv_test_feat)     
    del test, conv_test_feat
    gc.collect()
    gc.collect()
    
    trn = get_data(path+'train', load_size)
    conv_trn_feat = vgg640.predict(trn, batch_size=16, verbose=1)    
    del trn
    gc.collect()
    save_array(path+'results/dano_conv_trn_feat.dat', conv_trn_feat) 
    del conv_trn_feat
    gc.collect()
    
    # For memory purposes delete out the original train and validation
    log.info('Clear up memory')
    #del trn, val, test
    gc.collect()
    gc.collect()
# Out:
# [2017-02-20 23:11:35.963714] INFO: Logbook: Read in data

# %%
# Let's include the real training data as well in its non-augmented form.
da_conv_trn_feat = load_array(path+'results/da_conv_trn_feat.dat')
dano_conv_trn_feat = load_array(path+'results/dano_conv_trn_feat.dat')
gc.collect()
da_conv_trn_feat = np.concatenate([da_conv_trn_feat, dano_conv_trn_feat])
del dano_conv_trn_feat 
gc.collect()

# Validation set shouldonly be augmented for a full run
da_conv_val_feat = load_array(path+'results/dano_conv_val_feat.dat')
if full:
    dano_conv_val_feat = load_array(path+'results/da_conv_val_feat.dat')
    da_conv_val_feat = np.concatenate([da_conv_val_feat, dano_conv_val_feat])
    del dano_conv_val_feat 
    gc.collect()

conv_test_feat = load_array(path+'results/dano_conv_test_feat.dat')

# %%
# Since we've now got a dataset 3x bigger than before, we'll need to copy our labels 6 times too.
da_trn_labels = np.concatenate([trn_labels]*(aug_batches + 1))
da_trn_bbox = np.concatenate([trn_bbox]*(aug_batches + 1))

# Validation set shouldonly be augmented for a full run
if full:
    da_val_labels = np.concatenate([val_labels]*(aug_batches + 1))
    da_val_bbox = np.concatenate([val_bbox]*(aug_batches + 1))
else:
    da_val_labels = val_labels
    da_val_bbox = val_bbox

# %%
if full:
    da_conv_trn_feat = np.concatenate([da_conv_trn_feat, da_conv_val_feat])
    da_trn_labels = np.concatenate([da_trn_labels, da_val_labels]) 
    da_trn_bbox = np.concatenate([da_trn_bbox, da_val_bbox])
    
# Our Convolutional Net Architecture
log.info('Create and fit CNN')
p=0.6
# Set up the fully convolutional net (FCN); 
conv_layers,_ = split_at(vgg640, Convolution2D)
nf=128; p=0. # No dropout
# Out:
# [2017-02-20 23:12:41.634161] INFO: Logbook: Create and fit CNN

# %%
gc.collect()
gc.collect()
# Out:
# 0

# %%
gc.collect()
nf = 512
p  = 0.3
def create_model():
    inp = Input(conv_layers[-1].output_shape[1:])
    x = MaxPooling2D()(inp)
    x = ZeroPadding2D((1,1))(x)
    x = Convolution2D(nf,3,3, activation='relu', border_mode='same')(x)
    x =   Dropout(p)(x)
    #x = BatchNormalization(axis=1)(x)
    #x = MaxPooling2D()(x)
    #x = ZeroPadding2D((1,1))(x)
    #x = Convolution2D(nf,3,3, activation='relu', border_mode='same')(x)
    #x =   Dropout(p)(x)
    x = BatchNormalization(axis=1)(x)
    x = MaxPooling2D()(x)
    x = ZeroPadding2D((1,1))(x)
    x = Convolution2D(nf,3,3, activation='relu', border_mode='same')(x)
    x =   Dropout(p)(x)
    x = BatchNormalization(axis=1)(x)
    x1 =   MaxPooling2D()(x)
    x1 =   Convolution2D(8,3,3, border_mode='same')(x1)
    x1 =   Dropout(p/2)(x1)
    x1 =   GlobalAveragePooling2D()(x1)
    x = Dropout(p/2)(x)
    x = Flatten()(x)
    x = Dense(1024, activation='relu')(x)
    x = BatchNormalization()(x)
    x = Dropout(p/2)(x)
    x = Dense(1024, activation='relu')(x)
    x = BatchNormalization()(x)
    x = Dropout(p/2)(x)
    x_bb = Dense(4, name='bb')(x)
    x_class = Dense(8, activation='softmax', name='class')(x1)
    return inp, x_bb, x_class

## Set up the fully convolutional net (FCN); 
#conv_layers,_ = split_at(vgg640, Convolution2D)
#nf=128; p=0. # No dropout

model = []
predsls = []
pvalsls = []

for ii in range(1):
    inp, x_bb, x_class = create_model()
    model.append(Model([inp], [x_bb, x_class]))
    #model.summary()
    model[ii].compile(Adam(lr=1e-4), loss=['mse', 'categorical_crossentropy'], metrics=['accuracy'],
                 loss_weights=[.001, 1.])
    model[ii].fit(da_conv_trn_feat, [da_trn_bbox, da_trn_labels], batch_size=batch_size, nb_epoch=1, 
                 validation_data=(da_conv_val_feat, [da_val_bbox, da_val_labels]))
    #model[ii].optimizer.lr = 1e-4
    #model[ii].optimizer.loss_weights=[.00001, 1.]
    #model[ii].fit(da_conv_trn_feat, [da_trn_bbox, da_trn_labels], batch_size=batch_size, nb_epoch=3, 
    #             validation_data=(da_conv_val_feat, [da_val_bbox, da_val_labels]))
    model[ii].optimizer.lr = 1e-5

    count = 0
    while count < 8:
        model[ii].fit(da_conv_trn_feat, [da_trn_bbox, da_trn_labels], batch_size=batch_size, nb_epoch=1, 
                     validation_data=(da_conv_val_feat, [da_val_bbox, da_val_labels]))
        predsls.append(model[ii].predict(conv_test_feat, batch_size=batch_size)[1]) # or try 32 batch_size
        pvalsls.append(model[ii].predict(da_conv_val_feat, batch_size=batch_size)[1])
        val_score = "%.3f" % metrics.log_loss(da_val_labels, sum(pvalsls)/len(pvalsls))
        acc_score = "%.3f" % accuracyfunc(da_val_labels, do_clip(sum(pvalsls)/len(pvalsls), clip))
        log.info('Bagged Validation Logloss ' + str(val_score))
        log.info('Bagged Validation Accuracy ' + str(acc_score))
        count += 1
# Out:
# th
# Train on 11331 samples, validate on 2073 samples
# Epoch 1/1
# 11331/11331 [==============================] - 101s - loss: 36.5317 - bb_loss: 35796.0122 - class_loss: 0.7356 - bb_acc: 0.6215 - class_acc: 0.7545 - val_loss: 34.7197 - val_bb_loss: 33743.1853 - val_class_loss: 0.9765 - val_bb_acc: 0.6913 - val_class_acc: 0.5866
# Train on 11331 samples, validate on 2073 samples
# Epoch 1/3
# 11331/11331 [==============================] - 101s - loss: 32.0717 - bb_loss: 31866.4102 - class_loss: 0.2052 - bb_acc: 0.6883 - class_acc: 0.9467 - val_loss: 30.2873 - val_bb_loss: 30091.0413 - val_class_loss: 0.1963 - val_bb_acc: 0.7352 - val_class_acc: 0.9773
# Epoch 2/3
# 11331/11331 [==============================] - 100s - loss: 28.5517 - bb_loss: 28466.9542 - class_loss: 0.0848 - bb_acc: 0.7161 - class_acc: 0.9832 - val_loss: 26.0047 - val_bb_loss: 25928.8851 - val_class_loss: 0.0758 - val_bb_acc: 0.7434 - val_class_acc: 0.9952
# Epoch 3/3
# 11331/11331 [==============================] - 102s - loss: 25.3884 - bb_loss: 25328.0888 - class_loss: 0.0603 - bb_acc: 0.7234 - class_acc: 0.9894 - val_loss: 25.1971 - val_bb_loss: 25077.5691 - val_class_loss: 0.1195 - val_bb_acc: 0.7236 - val_class_acc: 0.9894
# Train on 11331 samples, validate on 2073 samples
# Epoch 1/1
# 11331/11331 [==============================] - 101s - loss: 22.0191 - bb_loss: 21981.4134 - class_loss: 0.0377 - bb_acc: 0.7365 - class_acc: 0.9937 - val_loss: 20.6375 - val_bb_loss: 20574.8870 - val_class_loss: 0.0626 - val_bb_acc: 0.7458 - val_class_acc: 0.9966
# [2017-02-20 23:21:39.135970] INFO: Logbook: Bagged Validation Logloss 0.063
# [2017-02-20 23:21:39.136750] INFO: Logbook: Bagged Validation Accuracy 0.997
# Train on 11331 samples, validate on 2073 samples
# Epoch 1/1
# 11331/11331 [==============================] - 100s - loss: 18.3635 - bb_loss: 18342.7286 - class_loss: 0.0208 - bb_acc: 0.7466 - class_acc: 0.9970 - val_loss: 16.2985 - val_bb_loss: 16262.8538 - val_class_loss: 0.0356 - val_bb_acc: 0.7410 - val_class_acc: 0.9995
# [2017-02-20 23:23:30.261747] INFO: Logbook: Bagged Validation Logloss 0.048
# [2017-02-20 23:23:30.262569] INFO: Logbook: Bagged Validation Accuracy 0.998
# Train on 11331 samples, validate on 2073 samples
# Epoch 1/1
# 11331/11331 [==============================] - 100s - loss: 14.5850 - bb_loss: 14570.3758 - class_loss: 0.0146 - bb_acc: 0.7618 - class_acc: 0.9977 - val_loss: 12.5009 - val_bb_loss: 12464.4680 - val_class_loss: 0.0364 - val_bb_acc: 0.7583 - val_class_acc: 0.9976
# [2017-02-20 23:25:21.355576] INFO: Logbook: Bagged Validation Logloss 0.043
# [2017-02-20 23:25:21.356412] INFO: Logbook: Bagged Validation Accuracy 0.998
# Train on 11331 samples, validate on 2073 samples
# Epoch 1/1
# 11331/11331 [==============================] - 100s - loss: 10.9579 - bb_loss: 10945.1647 - class_loss: 0.0128 - bb_acc: 0.7675 - class_acc: 0.9984 - val_loss: 8.6439 - val_bb_loss: 8622.7954 - val_class_loss: 0.0211 - val_bb_acc: 0.7839 - val_class_acc: 1.0000
# [2017-02-20 23:27:12.718777] INFO: Logbook: Bagged Validation Logloss 0.037
# [2017-02-20 23:27:12.719728] INFO: Logbook: Bagged Validation Accuracy 1.000
# Train on 11331 samples, validate on 2073 samples
# Epoch 1/1
# 11331/11331 [==============================] - 100s - loss: 7.8485 - bb_loss: 7834.4669 - class_loss: 0.0141 - bb_acc: 0.7811 - class_acc: 0.9975 - val_loss: 6.1458 - val_bb_loss: 6124.1077 - val_class_loss: 0.0217 - val_bb_acc: 0.7641 - val_class_acc: 0.9995
# [2017-02-20 23:29:03.850641] INFO: Logbook: Bagged Validation Logloss 0.034
# [2017-02-20 23:29:03.851449] INFO: Logbook: Bagged Validation Accuracy 1.000
# Train on 11331 samples, validate on 2073 samples
# Epoch 1/1
# 11331/11331 [==============================] - 100s - loss: 5.4074 - bb_loss: 5396.2392 - class_loss: 0.0112 - bb_acc: 0.7908 - class_acc: 0.9983 - val_loss: 3.8550 - val_bb_loss: 3836.0791 - val_class_loss: 0.0189 - val_bb_acc: 0.8070 - val_class_acc: 0.9986
# [2017-02-20 23:30:55.189636] INFO: Logbook: Bagged Validation Logloss 0.031
# [2017-02-20 23:30:55.190551] INFO: Logbook: Bagged Validation Accuracy 1.000
# Train on 11331 samples, validate on 2073 samples
# Epoch 1/1
# 11331/11331 [==============================] - 101s - loss: 3.6327 - bb_loss: 3610.0463 - class_loss: 0.0227 - bb_acc: 0.8086 - class_acc: 0.9959 - val_loss: 2.6626 - val_bb_loss: 2635.8460 - val_class_loss: 0.0267 - val_bb_acc: 0.8321 - val_class_acc: 0.9976
# [2017-02-20 23:32:46.870459] INFO: Logbook: Bagged Validation Logloss 0.030
# [2017-02-20 23:32:46.871352] INFO: Logbook: Bagged Validation Accuracy 1.000
# Train on 11331 samples, validate on 2073 samples
# Epoch 1/1
# 11331/11331 [==============================] - 100s - loss: 2.3821 - bb_loss: 2368.1287 - class_loss: 0.0139 - bb_acc: 0.8148 - class_acc: 0.9974 - val_loss: 1.4257 - val_bb_loss: 1409.9067 - val_class_loss: 0.0158 - val_bb_acc: 0.8625 - val_class_acc: 0.9981
# [2017-02-20 23:34:38.131352] INFO: Logbook: Bagged Validation Logloss 0.028
# [2017-02-20 23:34:38.132150] INFO: Logbook: Bagged Validation Accuracy 1.000
# th
# Train on 11331 samples, validate on 2073 samples
# Epoch 1/1
# 11331/11331 [==============================] - 101s - loss: 36.4691 - bb_loss: 35771.4389 - class_loss: 0.6977 - bb_acc: 0.6426 - class_acc: 0.7706 - val_loss: 36.4057 - val_bb_loss: 35969.8772 - val_class_loss: 0.4358 - val_bb_acc: 0.7033 - val_class_acc: 0.9001
# Train on 11331 samples, validate on 2073 samples
# Epoch 1/3
# 11331/11331 [==============================] - 100s - loss: 32.0655 - bb_loss: 31883.5510 - class_loss: 0.1820 - bb_acc: 0.7010 - class_acc: 0.9512 - val_loss: 32.1384 - val_bb_loss: 31971.3529 - val_class_loss: 0.1670 - val_bb_acc: 0.7274 - val_class_acc: 0.9952
# Epoch 2/3
# 11331/11331 [==============================] - 101s - loss: 28.5286 - bb_loss: 28450.0750 - class_loss: 0.0785 - bb_acc: 0.7271 - class_acc: 0.9826 - val_loss: 27.3736 - val_bb_loss: 27280.9441 - val_class_loss: 0.0927 - val_bb_acc: 0.7496 - val_class_acc: 0.9957
# Epoch 3/3
# 11331/11331 [==============================] - 101s - loss: 25.3086 - bb_loss: 25264.6231 - class_loss: 0.0440 - bb_acc: 0.7388 - class_acc: 0.9913 - val_loss: 24.2103 - val_bb_loss: 24122.8277 - val_class_loss: 0.0875 - val_bb_acc: 0.7347 - val_class_acc: 0.9957
# Train on 11331 samples, validate on 2073 samples
# Epoch 1/1
# 11331/11331 [==============================] - 101s - loss: 22.0744 - bb_loss: 22034.6287 - class_loss: 0.0398 - bb_acc: 0.7430 - class_acc: 0.9944 - val_loss: 20.6609 - val_bb_loss: 20606.9354 - val_class_loss: 0.0539 - val_bb_acc: 0.7246 - val_class_acc: 0.9947
# [2017-02-20 23:43:33.340303] INFO: Logbook: Bagged Validation Logloss 0.030
# [2017-02-20 23:43:33.341170] INFO: Logbook: Bagged Validation Accuracy 1.000
# Train on 11331 samples, validate on 2073 samples
# Epoch 1/1
# 11331/11331 [==============================] - 101s - loss: 18.3918 - bb_loss: 18371.9176 - class_loss: 0.0199 - bb_acc: 0.7491 - class_acc: 0.9975 - val_loss: 15.9685 - val_bb_loss: 15928.2034 - val_class_loss: 0.0403 - val_bb_acc: 0.7458 - val_class_acc: 0.9971
# [2017-02-20 23:45:24.915915] INFO: Logbook: Bagged Validation Logloss 0.030
# [2017-02-20 23:45:24.916737] INFO: Logbook: Bagged Validation Accuracy 1.000
# Train on 11331 samples, validate on 2073 samples
# Epoch 1/1
# 11331/11331 [==============================] - 101s - loss: 14.6688 - bb_loss: 14651.7314 - class_loss: 0.0171 - bb_acc: 0.7567 - class_acc: 0.9974 - val_loss: 13.1997 - val_bb_loss: 13171.1636 - val_class_loss: 0.0286 - val_bb_acc: 0.7713 - val_class_acc: 1.0000
# [2017-02-20 23:47:16.610113] INFO: Logbook: Bagged Validation Logloss 0.030
# [2017-02-20 23:47:16.610911] INFO: Logbook: Bagged Validation Accuracy 1.000
# Train on 11331 samples, validate on 2073 samples
# Epoch 1/1
# 11331/11331 [==============================] - 100s - loss: 11.0118 - bb_loss: 11000.7511 - class_loss: 0.0110 - bb_acc: 0.7730 - class_acc: 0.9990 - val_loss: 9.1818 - val_bb_loss: 9157.4279 - val_class_loss: 0.0244 - val_bb_acc: 0.7694 - val_class_acc: 0.9995
# [2017-02-20 23:49:07.850551] INFO: Logbook: Bagged Validation Logloss 0.029
# [2017-02-20 23:49:07.851342] INFO: Logbook: Bagged Validation Accuracy 1.000
# Train on 11331 samples, validate on 2073 samples
# Epoch 1/1
# 11331/11331 [==============================] - 101s - loss: 7.9156 - bb_loss: 7896.1357 - class_loss: 0.0195 - bb_acc: 0.7830 - class_acc: 0.9952 - val_loss: 6.7304 - val_bb_loss: 6695.9735 - val_class_loss: 0.0344 - val_bb_acc: 0.7636 - val_class_acc: 0.9961
# [2017-02-20 23:50:59.255047] INFO: Logbook: Bagged Validation Logloss 0.030
# [2017-02-20 23:50:59.255836] INFO: Logbook: Bagged Validation Accuracy 1.000
# Train on 11331 samples, validate on 2073 samples
# Epoch 1/1
# 11331/11331 [==============================] - 101s - loss: 5.4269 - bb_loss: 5417.9714 - class_loss: 0.0090 - bb_acc: 0.7953 - class_acc: 0.9984 - val_loss: 4.0276 - val_bb_loss: 4017.5841 - val_class_loss: 0.0100 - val_bb_acc: 0.7902 - val_class_acc: 1.0000
# [2017-02-20 23:52:51.088713] INFO: Logbook: Bagged Validation Logloss 0.028
# [2017-02-20 23:52:51.089544] INFO: Logbook: Bagged Validation Accuracy 1.000
# Train on 11331 samples, validate on 2073 samples
# Epoch 1/1
# 11331/11331 [==============================] - 101s - loss: 3.6167 - bb_loss: 3599.5292 - class_loss: 0.0172 - bb_acc: 0.8105 - class_acc: 0.9963 - val_loss: 2.5544 - val_bb_loss: 2543.2006 - val_class_loss: 0.0112 - val_bb_acc: 0.8336 - val_class_acc: 1.0000
# [2017-02-20 23:54:42.608032] INFO: Logbook: Bagged Validation Logloss 0.027
# [2017-02-20 23:54:42.608786] INFO: Logbook: Bagged Validation Accuracy 1.000
# Train on 11331 samples, validate on 2073 samples
# Epoch 1/1
# 11331/11331 [==============================] - 101s - loss: 2.4121 - bb_loss: 2403.4736 - class_loss: 0.0087 - bb_acc: 0.8161 - class_acc: 0.9989 - val_loss: 1.2837 - val_bb_loss: 1271.3424 - val_class_loss: 0.0124 - val_bb_acc: 0.8601 - val_class_acc: 0.9995
# [2017-02-20 23:56:34.040996] INFO: Logbook: Bagged Validation Logloss 0.026
# [2017-02-20 23:56:34.041803] INFO: Logbook: Bagged Validation Accuracy 1.000
# th
# Train on 11331 samples, validate on 2073 samples
# Epoch 1/1
# 11331/11331 [==============================] - 101s - loss: 36.5454 - bb_loss: 35796.0681 - class_loss: 0.7494 - bb_acc: 0.6153 - class_acc: 0.7640 - val_loss: 33.2678 - val_bb_loss: 32799.1936 - val_class_loss: 0.4686 - val_bb_acc: 0.7048 - val_class_acc: 0.8577
# Train on 11331 samples, validate on 2073 samples
# Epoch 1/3
# 11331/11331 [==============================] - 101s - loss: 32.1200 - bb_loss: 31905.3369 - class_loss: 0.2147 - bb_acc: 0.6823 - class_acc: 0.9403 - val_loss: 29.5543 - val_bb_loss: 29355.2848 - val_class_loss: 0.1990 - val_bb_acc: 0.7255 - val_class_acc: 0.9817
# Epoch 2/3
# 11331/11331 [==============================] - 101s - loss: 28.5438 - bb_loss: 28459.0918 - class_loss: 0.0847 - bb_acc: 0.7105 - class_acc: 0.9847 - val_loss: 26.1164 - val_bb_loss: 26026.2876 - val_class_loss: 0.0901 - val_bb_acc: 0.7318 - val_class_acc: 0.9981
# Epoch 3/3
# 11331/11331 [==============================] - 101s - loss: 25.3298 - bb_loss: 25286.5600 - class_loss: 0.0432 - bb_acc: 0.7269 - class_acc: 0.9923 - val_loss: 22.8027 - val_bb_loss: 22681.8948 - val_class_loss: 0.1208 - val_bb_acc: 0.7328 - val_class_acc: 0.9918
# Train on 11331 samples, validate on 2073 samples
# Epoch 1/1
# 11331/11331 [==============================] - 100s - loss: 22.0354 - bb_loss: 22003.0398 - class_loss: 0.0324 - bb_acc: 0.7408 - class_acc: 0.9961 - val_loss: 21.1294 - val_bb_loss: 21079.8640 - val_class_loss: 0.0495 - val_bb_acc: 0.7424 - val_class_acc: 1.0000
# [2017-02-21 00:05:29.863360] INFO: Logbook: Bagged Validation Logloss 0.027
# [2017-02-21 00:05:29.864173] INFO: Logbook: Bagged Validation Accuracy 1.000
# Train on 11331 samples, validate on 2073 samples
# Epoch 1/1
# 11331/11331 [==============================] - 101s - loss: 18.4668 - bb_loss: 18434.9150 - class_loss: 0.0319 - bb_acc: 0.7451 - class_acc: 0.9945 - val_loss: 17.5215 - val_bb_loss: 17463.7017 - val_class_loss: 0.0578 - val_bb_acc: 0.7410 - val_class_acc: 0.9976
# [2017-02-21 00:07:21.297609] INFO: Logbook: Bagged Validation Logloss 0.029
# [2017-02-21 00:07:21.298521] INFO: Logbook: Bagged Validation Accuracy 1.000
# Train on 11331 samples, validate on 2073 samples
# Epoch 1/1
# 11331/11331 [==============================] - 101s - loss: 14.6189 - bb_loss: 14595.8532 - class_loss: 0.0230 - bb_acc: 0.7556 - class_acc: 0.9957 - val_loss: 12.9720 - val_bb_loss: 12917.2068 - val_class_loss: 0.0548 - val_bb_acc: 0.7458 - val_class_acc: 0.9942
# [2017-02-21 00:09:13.049762] INFO: Logbook: Bagged Validation Logloss 0.030
# [2017-02-21 00:09:13.050526] INFO: Logbook: Bagged Validation Accuracy 1.000
# Train on 11331 samples, validate on 2073 samples
# Epoch 1/1
# 11331/11331 [==============================] - 101s - loss: 11.0108 - bb_loss: 10997.1869 - class_loss: 0.0136 - bb_acc: 0.7682 - class_acc: 0.9976 - val_loss: 8.8634 - val_bb_loss: 8848.5289 - val_class_loss: 0.0148 - val_bb_acc: 0.7535 - val_class_acc: 0.9995
# [2017-02-21 00:11:05.169343] INFO: Logbook: Bagged Validation Logloss 0.029
# [2017-02-21 00:11:05.170165] INFO: Logbook: Bagged Validation Accuracy 1.000
# Train on 11331 samples, validate on 2073 samples
# Epoch 1/1
# 11331/11331 [==============================] - 101s - loss: 7.9156 - bb_loss: 7904.3489 - class_loss: 0.0112 - bb_acc: 0.7795 - class_acc: 0.9982 - val_loss: 6.4920 - val_bb_loss: 6301.5685 - val_class_loss: 0.1904 - val_bb_acc: 0.7607 - val_class_acc: 0.9440
# [2017-02-21 00:12:57.062248] INFO: Logbook: Bagged Validation Logloss 0.034
# [2017-02-21 00:12:57.063217] INFO: Logbook: Bagged Validation Accuracy 1.000
# Train on 11331 samples, validate on 2073 samples
# Epoch 1/1
# 11331/11331 [==============================] - 100s - loss: 5.4584 - bb_loss: 5430.0431 - class_loss: 0.0283 - bb_acc: 0.7923 - class_acc: 0.9933 - val_loss: 3.9240 - val_bb_loss: 3904.8322 - val_class_loss: 0.0191 - val_bb_acc: 0.7805 - val_class_acc: 1.0000
# [2017-02-21 00:14:48.297777] INFO: Logbook: Bagged Validation Logloss 0.033
# [2017-02-21 00:14:48.298574] INFO: Logbook: Bagged Validation Accuracy 1.000
# Train on 11331 samples, validate on 2073 samples
# Epoch 1/1
# 11331/11331 [==============================] - 100s - loss: 3.6780 - bb_loss: 3661.5015 - class_loss: 0.0165 - bb_acc: 0.8027 - class_acc: 0.9965 - val_loss: 2.5754 - val_bb_loss: 2548.8888 - val_class_loss: 0.0265 - val_bb_acc: 0.8326 - val_class_acc: 0.9995
# [2017-02-21 00:16:39.687631] INFO: Logbook: Bagged Validation Logloss 0.033
# [2017-02-21 00:16:39.688431] INFO: Logbook: Bagged Validation Accuracy 1.000
# Train on 11331 samples, validate on 2073 samples
# Epoch 1/1
# 11331/11331 [==============================] - 101s - loss: 2.5277 - bb_loss: 2492.1322 - class_loss: 0.0356 - bb_acc: 0.8065 - class_acc: 0.9921 - val_loss: 1.4934 - val_bb_loss: 1466.8688 - val_class_loss: 0.0265 - val_bb_acc: 0.8360 - val_class_acc: 0.9990
# [2017-02-21 00:18:31.203427] INFO: Logbook: Bagged Validation Logloss 0.033
# [2017-02-21 00:18:31.204219] INFO: Logbook: Bagged Validation Accuracy 1.000
# th
# Train on 11331 samples, validate on 2073 samples
# Epoch 1/1
# 11331/11331 [==============================] - 101s - loss: 36.5219 - bb_loss: 35804.1143 - class_loss: 0.7178 - bb_acc: 0.6073 - class_acc: 0.7680 - val_loss: 39.1068 - val_bb_loss: 38447.5024 - val_class_loss: 0.6593 - val_bb_acc: 0.6377 - val_class_acc: 0.7844
# Train on 11331 samples, validate on 2073 samples
# Epoch 1/3
# 11331/11331 [==============================] - 102s - loss: 32.0791 - bb_loss: 31882.7237 - class_loss: 0.1963 - bb_acc: 0.6848 - class_acc: 0.9475 - val_loss: 30.2230 - val_bb_loss: 30004.4769 - val_class_loss: 0.2185 - val_bb_acc: 0.7385 - val_class_acc: 0.9831
# Epoch 2/3
# 11331/11331 [==============================] - 101s - loss: 28.5499 - bb_loss: 28461.1808 - class_loss: 0.0887 - bb_acc: 0.7164 - class_acc: 0.9805 - val_loss: 34.4447 - val_bb_loss: 33874.0646 - val_class_loss: 0.5707 - val_bb_acc: 0.7077 - val_class_acc: 0.7651
# Epoch 3/3
# 11331/11331 [==============================] - 101s - loss: 25.3493 - bb_loss: 25292.5310 - class_loss: 0.0567 - bb_acc: 0.7316 - class_acc: 0.9894 - val_loss: 23.9176 - val_bb_loss: 23809.2700 - val_class_loss: 0.1083 - val_bb_acc: 0.7337 - val_class_acc: 0.9908
# Train on 11331 samples, validate on 2073 samples
# Epoch 1/1
# 11331/11331 [==============================] - 101s - loss: 22.0281 - bb_loss: 21996.7851 - class_loss: 0.0313 - bb_acc: 0.7421 - class_acc: 0.9936 - val_loss: 20.4204 - val_bb_loss: 20383.8027 - val_class_loss: 0.0366 - val_bb_acc: 0.7521 - val_class_acc: 1.0000
# [2017-02-21 00:27:27.177999] INFO: Logbook: Bagged Validation Logloss 0.033
# [2017-02-21 00:27:27.178813] INFO: Logbook: Bagged Validation Accuracy 1.000
# Train on 11331 samples, validate on 2073 samples
# Epoch 1/1
# 11331/11331 [==============================] - 101s - loss: 18.4384 - bb_loss: 18415.4854 - class_loss: 0.0229 - bb_acc: 0.7501 - class_acc: 0.9973 - val_loss: 18.1234 - val_bb_loss: 18022.5217 - val_class_loss: 0.1009 - val_bb_acc: 0.7395 - val_class_acc: 0.9952
# [2017-02-21 00:29:18.720895] INFO: Logbook: Bagged Validation Logloss 0.035
# [2017-02-21 00:29:18.721718] INFO: Logbook: Bagged Validation Accuracy 1.000
# Train on 11331 samples, validate on 2073 samples
# Epoch 1/1
# 11331/11331 [==============================] - 101s - loss: 14.6214 - bb_loss: 14607.6741 - class_loss: 0.0137 - bb_acc: 0.7611 - class_acc: 0.9988 - val_loss: 11.6425 - val_bb_loss: 11586.3453 - val_class_loss: 0.0561 - val_bb_acc: 0.7501 - val_class_acc: 0.9961
# [2017-02-21 00:31:10.275821] INFO: Logbook: Bagged Validation Logloss 0.036
# [2017-02-21 00:31:10.276621] INFO: Logbook: Bagged Validation Accuracy 1.000
# Train on 11331 samples, validate on 2073 samples
# Epoch 1/1
# 11331/11331 [==============================] - 100s - loss: 11.0724 - bb_loss: 11043.4950 - class_loss: 0.0289 - bb_acc: 0.7671 - class_acc: 0.9931 - val_loss: 9.3256 - val_bb_loss: 9284.9022 - val_class_loss: 0.0407 - val_bb_acc: 0.7709 - val_class_acc: 0.9986
# [2017-02-21 00:33:01.665147] INFO: Logbook: Bagged Validation Logloss 0.036
# [2017-02-21 00:33:01.665953] INFO: Logbook: Bagged Validation Accuracy 1.000
# Train on 11331 samples, validate on 2073 samples
# Epoch 1/1
# 11331/11331 [==============================] - 101s - loss: 7.8589 - bb_loss: 7847.6941 - class_loss: 0.0113 - bb_acc: 0.7852 - class_acc: 0.9989 - val_loss: 6.5658 - val_bb_loss: 6551.8977 - val_class_loss: 0.0139 - val_bb_acc: 0.7689 - val_class_acc: 1.0000
# [2017-02-21 00:34:53.339355] INFO: Logbook: Bagged Validation Logloss 0.035
# [2017-02-21 00:34:53.340341] INFO: Logbook: Bagged Validation Accuracy 1.000
# Train on 11331 samples, validate on 2073 samples
# Epoch 1/1
# 11331/11331 [==============================] - 101s - loss: 5.3841 - bb_loss: 5373.6019 - class_loss: 0.0105 - bb_acc: 0.7978 - class_acc: 0.9987 - val_loss: 4.9418 - val_bb_loss: 4880.5783 - val_class_loss: 0.0613 - val_bb_acc: 0.7583 - val_class_acc: 0.9855
# [2017-02-21 00:36:44.730032] INFO: Logbook: Bagged Validation Logloss 0.036
# [2017-02-21 00:36:44.730797] INFO: Logbook: Bagged Validation Accuracy 1.000
# Train on 11331 samples, validate on 2073 samples
# Epoch 1/1
# 11331/11331 [==============================] - 101s - loss: 3.5695 - bb_loss: 3562.3940 - class_loss: 0.0071 - bb_acc: 0.8131 - class_acc: 0.9994 - val_loss: 2.5317 - val_bb_loss: 2510.8388 - val_class_loss: 0.0209 - val_bb_acc: 0.8119 - val_class_acc: 0.9990
# [2017-02-21 00:38:36.261936] INFO: Logbook: Bagged Validation Logloss 0.035
# [2017-02-21 00:38:36.262729] INFO: Logbook: Bagged Validation Accuracy 1.000
# Train on 11331 samples, validate on 2073 samples
# Epoch 1/1
# 11331/11331 [==============================] - 100s - loss: 2.3406 - bb_loss: 2327.7047 - class_loss: 0.0129 - bb_acc: 0.8219 - class_acc: 0.9966 - val_loss: 1.3684 - val_bb_loss: 1357.8507 - val_class_loss: 0.0105 - val_bb_acc: 0.8485 - val_class_acc: 0.9995
# [2017-02-21 00:40:27.651447] INFO: Logbook: Bagged Validation Logloss 0.034
# [2017-02-21 00:40:27.652285] INFO: Logbook: Bagged Validation Accuracy 1.000
# th
# Train on 11331 samples, validate on 2073 samples
# Epoch 1/1
# 11331/11331 [==============================] - 101s - loss: 36.5104 - bb_loss: 35810.5895 - class_loss: 0.6998 - bb_acc: 0.6239 - class_acc: 0.7756 - val_loss: 36.1331 - val_bb_loss: 35710.7212 - val_class_loss: 0.4223 - val_bb_acc: 0.6918 - val_class_acc: 0.9402
# Train on 11331 samples, validate on 2073 samples
# Epoch 1/3
# 11331/11331 [==============================] - 101s - loss: 32.1470 - bb_loss: 31925.9710 - class_loss: 0.2210 - bb_acc: 0.6902 - class_acc: 0.9422 - val_loss: 31.4182 - val_bb_loss: 31154.5855 - val_class_loss: 0.2636 - val_bb_acc: 0.7072 - val_class_acc: 0.9725
# Epoch 2/3
# 11331/11331 [==============================] - 102s - loss: 28.6046 - bb_loss: 28493.6972 - class_loss: 0.1109 - bb_acc: 0.7121 - class_acc: 0.9747 - val_loss: 27.6721 - val_bb_loss: 27555.3876 - val_class_loss: 0.1168 - val_bb_acc: 0.7545 - val_class_acc: 0.9947
# Epoch 3/3
# 11331/11331 [==============================] - 101s - loss: 25.5022 - bb_loss: 25412.0539 - class_loss: 0.0902 - bb_acc: 0.7251 - class_acc: 0.9808 - val_loss: 26.5389 - val_bb_loss: 26391.1246 - val_class_loss: 0.1478 - val_bb_acc: 0.7226 - val_class_acc: 0.9894
# Train on 11331 samples, validate on 2073 samples
# Epoch 1/1
# 11331/11331 [==============================] - 101s - loss: 22.0486 - bb_loss: 22000.4711 - class_loss: 0.0481 - bb_acc: 0.7403 - class_acc: 0.9906 - val_loss: 21.0447 - val_bb_loss: 20988.1016 - val_class_loss: 0.0566 - val_bb_acc: 0.7323 - val_class_acc: 0.9990
# [2017-02-21 00:49:25.989357] INFO: Logbook: Bagged Validation Logloss 0.035
# [2017-02-21 00:49:25.990389] INFO: Logbook: Bagged Validation Accuracy 1.000
# Train on 11331 samples, validate on 2073 samples
# Epoch 1/1
# 11331/11331 [==============================] - 101s - loss: 18.4233 - bb_loss: 18391.4336 - class_loss: 0.0319 - bb_acc: 0.7510 - class_acc: 0.9943 - val_loss: 16.5859 - val_bb_loss: 16543.5749 - val_class_loss: 0.0423 - val_bb_acc: 0.7574 - val_class_acc: 0.9986
# [2017-02-21 00:51:18.048030] INFO: Logbook: Bagged Validation Logloss 0.035
# [2017-02-21 00:51:18.048779] INFO: Logbook: Bagged Validation Accuracy 1.000
# Train on 11331 samples, validate on 2073 samples
# Epoch 1/1
# 11331/11331 [==============================] - 101s - loss: 14.6209 - bb_loss: 14599.1699 - class_loss: 0.0218 - bb_acc: 0.7557 - class_acc: 0.9971 - val_loss: 13.3503 - val_bb_loss: 13278.2025 - val_class_loss: 0.0721 - val_bb_acc: 0.7328 - val_class_acc: 0.9918
# [2017-02-21 00:53:10.326519] INFO: Logbook: Bagged Validation Logloss 0.036
# [2017-02-21 00:53:10.327448] INFO: Logbook: Bagged Validation Accuracy 1.000
# Train on 11331 samples, validate on 2073 samples
# Epoch 1/1
# 11331/11331 [==============================] - 101s - loss: 11.1107 - bb_loss: 11076.0554 - class_loss: 0.0346 - bb_acc: 0.7660 - class_acc: 0.9924 - val_loss: 9.4434 - val_bb_loss: 9402.6263 - val_class_loss: 0.0408 - val_bb_acc: 0.7685 - val_class_acc: 0.9990
# [2017-02-21 00:55:02.169378] INFO: Logbook: Bagged Validation Logloss 0.036
# [2017-02-21 00:55:02.170238] INFO: Logbook: Bagged Validation Accuracy 1.000
# Train on 11331 samples, validate on 2073 samples
# Epoch 1/1
# 11331/11331 [==============================] - 101s - loss: 7.9420 - bb_loss: 7919.1723 - class_loss: 0.0228 - bb_acc: 0.7827 - class_acc: 0.9953 - val_loss: 6.7836 - val_bb_loss: 6763.4130 - val_class_loss: 0.0202 - val_bb_acc: 0.7641 - val_class_acc: 1.0000
# [2017-02-21 00:56:53.973341] INFO: Logbook: Bagged Validation Logloss 0.035
# [2017-02-21 00:56:53.974132] INFO: Logbook: Bagged Validation Accuracy 1.000
# Train on 11331 samples, validate on 2073 samples
# Epoch 1/1
# 11331/11331 [==============================] - 101s - loss: 5.5075 - bb_loss: 5476.9207 - class_loss: 0.0306 - bb_acc: 0.7910 - class_acc: 0.9933 - val_loss: 4.1939 - val_bb_loss: 4164.7794 - val_class_loss: 0.0291 - val_bb_acc: 0.7733 - val_class_acc: 0.9990
# [2017-02-21 00:58:46.252437] INFO: Logbook: Bagged Validation Logloss 0.035
# [2017-02-21 00:58:46.253262] INFO: Logbook: Bagged Validation Accuracy 1.000
# Train on 11331 samples, validate on 2073 samples
# Epoch 1/1
# 11331/11331 [==============================] - 101s - loss: 3.6641 - bb_loss: 3643.1880 - class_loss: 0.0209 - bb_acc: 0.8100 - class_acc: 0.9954 - val_loss: 2.4983 - val_bb_loss: 2477.9705 - val_class_loss: 0.0204 - val_bb_acc: 0.8302 - val_class_acc: 1.0000
# [2017-02-21 01:00:37.979664] INFO: Logbook: Bagged Validation Logloss 0.035
# [2017-02-21 01:00:37.980428] INFO: Logbook: Bagged Validation Accuracy 1.000
# Train on 11331 samples, validate on 2073 samples
# Epoch 1/1
# 11331/11331 [==============================] - 101s - loss: 2.4295 - bb_loss: 2412.0101 - class_loss: 0.0175 - bb_acc: 0.8140 - class_acc: 0.9972 - val_loss: 1.8273 - val_bb_loss: 1767.3513 - val_class_loss: 0.0600 - val_bb_acc: 0.8196 - val_class_acc: 0.9884
# [2017-02-21 01:02:29.514042] INFO: Logbook: Bagged Validation Logloss 0.035
# [2017-02-21 01:02:29.514826] INFO: Logbook: Bagged Validation Accuracy 1.000
# th
# Train on 11331 samples, validate on 2073 samples
# Epoch 1/1
# 11331/11331 [==============================] - 101s - loss: 36.4360 - bb_loss: 35769.6227 - class_loss: 0.6664 - bb_acc: 0.6295 - class_acc: 0.7822 - val_loss: 34.7021 - val_bb_loss: 34352.9322 - val_class_loss: 0.3491 - val_bb_acc: 0.7033 - val_class_acc: 0.9527
# Train on 11331 samples, validate on 2073 samples
# Epoch 1/3
# 11331/11331 [==============================] - 101s - loss: 31.9968 - bb_loss: 31824.8014 - class_loss: 0.1720 - bb_acc: 0.6954 - class_acc: 0.9541 - val_loss: 34.7718 - val_bb_loss: 34445.2326 - val_class_loss: 0.3266 - val_bb_acc: 0.6710 - val_class_acc: 0.9272
# Epoch 2/3
# 11331/11331 [==============================] - 101s - loss: 28.4990 - bb_loss: 28431.6006 - class_loss: 0.0674 - bb_acc: 0.7169 - class_acc: 0.9855 - val_loss: 26.8675 - val_bb_loss: 26750.5426 - val_class_loss: 0.1169 - val_bb_acc: 0.7564 - val_class_acc: 0.9875
# Epoch 3/3
# 11331/11331 [==============================] - 101s - loss: 25.2966 - bb_loss: 25250.4882 - class_loss: 0.0461 - bb_acc: 0.7323 - class_acc: 0.9907 - val_loss: 23.6208 - val_bb_loss: 23551.5499 - val_class_loss: 0.0692 - val_bb_acc: 0.7332 - val_class_acc: 0.9913
# Train on 11331 samples, validate on 2073 samples
# Epoch 1/1
# 11331/11331 [==============================] - 101s - loss: 22.0025 - bb_loss: 21970.8140 - class_loss: 0.0317 - bb_acc: 0.7412 - class_acc: 0.9951 - val_loss: 21.6444 - val_bb_loss: 21604.1156 - val_class_loss: 0.0403 - val_bb_acc: 0.7438 - val_class_acc: 0.9995
# [2017-02-21 01:11:26.509216] INFO: Logbook: Bagged Validation Logloss 0.035
# [2017-02-21 01:11:26.510025] INFO: Logbook: Bagged Validation Accuracy 1.000
# Train on 11331 samples, validate on 2073 samples
# Epoch 1/1
# 11331/11331 [==============================] - 101s - loss: 18.3628 - bb_loss: 18342.5972 - class_loss: 0.0202 - bb_acc: 0.7479 - class_acc: 0.9962 - val_loss: 15.7880 - val_bb_loss: 15742.2008 - val_class_loss: 0.0458 - val_bb_acc: 0.7959 - val_class_acc: 0.9942
# [2017-02-21 01:13:18.160983] INFO: Logbook: Bagged Validation Logloss 0.035
# [2017-02-21 01:13:18.161771] INFO: Logbook: Bagged Validation Accuracy 1.000
# Train on 11331 samples, validate on 2073 samples
# Epoch 1/1
# 11331/11331 [==============================] - 101s - loss: 14.6332 - bb_loss: 14613.5105 - class_loss: 0.0197 - bb_acc: 0.7558 - class_acc: 0.9963 - val_loss: 12.5565 - val_bb_loss: 12523.0385 - val_class_loss: 0.0335 - val_bb_acc: 0.7675 - val_class_acc: 0.9995
# [2017-02-21 01:15:10.140827] INFO: Logbook: Bagged Validation Logloss 0.035
# [2017-02-21 01:15:10.141607] INFO: Logbook: Bagged Validation Accuracy 1.000
# Train on 11331 samples, validate on 2073 samples
# Epoch 1/1
# 11331/11331 [==============================] - 102s - loss: 11.0096 - bb_loss: 10993.2128 - class_loss: 0.0164 - bb_acc: 0.7655 - class_acc: 0.9964 - val_loss: 9.0847 - val_bb_loss: 9057.5979 - val_class_loss: 0.0272 - val_bb_acc: 0.7853 - val_class_acc: 1.0000
# [2017-02-21 01:17:02.570389] INFO: Logbook: Bagged Validation Logloss 0.035
# [2017-02-21 01:17:02.571369] INFO: Logbook: Bagged Validation Accuracy 1.000
# Train on 11331 samples, validate on 2073 samples
# Epoch 1/1
# 11331/11331 [==============================] - 101s - loss: 7.9683 - bb_loss: 7945.6690 - class_loss: 0.0227 - bb_acc: 0.7776 - class_acc: 0.9963 - val_loss: 6.4139 - val_bb_loss: 6341.1173 - val_class_loss: 0.0728 - val_bb_acc: 0.7607 - val_class_acc: 0.9918
# [2017-02-21 01:18:54.655466] INFO: Logbook: Bagged Validation Logloss 0.036
# [2017-02-21 01:18:54.656284] INFO: Logbook: Bagged Validation Accuracy 1.000
# Train on 11331 samples, validate on 2073 samples
# Epoch 1/1
# 11331/11331 [==============================] - 102s - loss: 5.5109 - bb_loss: 5487.3436 - class_loss: 0.0236 - bb_acc: 0.7907 - class_acc: 0.9952 - val_loss: 4.2634 - val_bb_loss: 4243.8172 - val_class_loss: 0.0195 - val_bb_acc: 0.7940 - val_class_acc: 1.0000
# [2017-02-21 01:20:47.329442] INFO: Logbook: Bagged Validation Logloss 0.035
# [2017-02-21 01:20:47.330357] INFO: Logbook: Bagged Validation Accuracy 1.000
# Train on 11331 samples, validate on 2073 samples
# Epoch 1/1
# 11331/11331 [==============================] - 101s - loss: 3.6194 - bb_loss: 3611.1205 - class_loss: 0.0083 - bb_acc: 0.8094 - class_acc: 0.9987 - val_loss: 2.6109 - val_bb_loss: 2578.6810 - val_class_loss: 0.0323 - val_bb_acc: 0.8041 - val_class_acc: 0.9937
# [2017-02-21 01:22:39.571482] INFO: Logbook: Bagged Validation Logloss 0.035
# [2017-02-21 01:22:39.572258] INFO: Logbook: Bagged Validation Accuracy 1.000
# Train on 11331 samples, validate on 2073 samples
# Epoch 1/1
# 11331/11331 [==============================] - 101s - loss: 2.4005 - bb_loss: 2393.9397 - class_loss: 0.0066 - bb_acc: 0.8133 - class_acc: 0.9989 - val_loss: 1.3128 - val_bb_loss: 1300.9750 - val_class_loss: 0.0119 - val_bb_acc: 0.8659 - val_class_acc: 1.0000
# [2017-02-21 01:24:31.238744] INFO: Logbook: Bagged Validation Logloss 0.035
# [2017-02-21 01:24:31.239657] INFO: Logbook: Bagged Validation Accuracy 1.000
# th
# Train on 11331 samples, validate on 2073 samples
# Epoch 1/1
# 11331/11331 [==============================] - 101s - loss: 36.4963 - bb_loss: 35825.2502 - class_loss: 0.6710 - bb_acc: 0.6264 - class_acc: 0.7850 - val_loss: 35.3141 - val_bb_loss: 34996.0133 - val_class_loss: 0.3180 - val_bb_acc: 0.7381 - val_class_acc: 0.9590
# Train on 11331 samples, validate on 2073 samples
# Epoch 1/3
# 11331/11331 [==============================] - 102s - loss: 32.0578 - bb_loss: 31898.2880 - class_loss: 0.1595 - bb_acc: 0.6953 - class_acc: 0.9579 - val_loss: 30.1867 - val_bb_loss: 30027.5316 - val_class_loss: 0.1591 - val_bb_acc: 0.7376 - val_class_acc: 0.9715
# Epoch 2/3
# 11331/11331 [==============================] - 101s - loss: 28.5443 - bb_loss: 28467.7013 - class_loss: 0.0766 - bb_acc: 0.7192 - class_acc: 0.9831 - val_loss: 25.5956 - val_bb_loss: 25469.2730 - val_class_loss: 0.1264 - val_bb_acc: 0.7492 - val_class_acc: 0.9846
# Epoch 3/3
# 11331/11331 [==============================] - 101s - loss: 25.3345 - bb_loss: 25297.1705 - class_loss: 0.0374 - bb_acc: 0.7321 - class_acc: 0.9923 - val_loss: 24.8548 - val_bb_loss: 24778.7200 - val_class_loss: 0.0760 - val_bb_acc: 0.7434 - val_class_acc: 0.9947
# Train on 11331 samples, validate on 2073 samples
# Epoch 1/1
# 11331/11331 [==============================] - 101s - loss: 22.0442 - bb_loss: 22014.0824 - class_loss: 0.0301 - bb_acc: 0.7408 - class_acc: 0.9950 - val_loss: 21.4908 - val_bb_loss: 21414.9324 - val_class_loss: 0.0759 - val_bb_acc: 0.7434 - val_class_acc: 0.9894
# [2017-02-21 01:33:28.871203] INFO: Logbook: Bagged Validation Logloss 0.035
# [2017-02-21 01:33:28.872035] INFO: Logbook: Bagged Validation Accuracy 1.000
# Train on 11331 samples, validate on 2073 samples
# Epoch 1/1
# 11331/11331 [==============================] - 101s - loss: 18.4527 - bb_loss: 18434.7920 - class_loss: 0.0179 - bb_acc: 0.7549 - class_acc: 0.9974 - val_loss: 16.6406 - val_bb_loss: 16614.6279 - val_class_loss: 0.0260 - val_bb_acc: 0.7410 - val_class_acc: 0.9995
# [2017-02-21 01:35:20.802548] INFO: Logbook: Bagged Validation Logloss 0.035
# [2017-02-21 01:35:20.803378] INFO: Logbook: Bagged Validation Accuracy 1.000
# Train on 11331 samples, validate on 2073 samples
# Epoch 1/1
# 11331/11331 [==============================] - 101s - loss: 14.6247 - bb_loss: 14612.6539 - class_loss: 0.0121 - bb_acc: 0.7630 - class_acc: 0.9983 - val_loss: 12.5921 - val_bb_loss: 12579.0748 - val_class_loss: 0.0130 - val_bb_acc: 0.7699 - val_class_acc: 1.0000
# [2017-02-21 01:37:12.663284] INFO: Logbook: Bagged Validation Logloss 0.035
# [2017-02-21 01:37:12.664040] INFO: Logbook: Bagged Validation Accuracy 1.000
# Train on 11331 samples, validate on 2073 samples
# Epoch 1/1
# 11331/11331 [==============================] - 101s - loss: 10.9788 - bb_loss: 10967.0534 - class_loss: 0.0117 - bb_acc: 0.7693 - class_acc: 0.9983 - val_loss: 8.9688 - val_bb_loss: 8949.8574 - val_class_loss: 0.0189 - val_bb_acc: 0.7598 - val_class_acc: 0.9995
# [2017-02-21 01:39:04.449705] INFO: Logbook: Bagged Validation Logloss 0.034
# [2017-02-21 01:39:04.450504] INFO: Logbook: Bagged Validation Accuracy 1.000
# Train on 11331 samples, validate on 2073 samples
# Epoch 1/1
# 11331/11331 [==============================] - 101s - loss: 7.9245 - bb_loss: 7913.0940 - class_loss: 0.0114 - bb_acc: 0.7842 - class_acc: 0.9986 - val_loss: 5.8253 - val_bb_loss: 5808.0696 - val_class_loss: 0.0173 - val_bb_acc: 0.7935 - val_class_acc: 1.0000
# [2017-02-21 01:40:56.060394] INFO: Logbook: Bagged Validation Logloss 0.034
# [2017-02-21 01:40:56.061238] INFO: Logbook: Bagged Validation Accuracy 1.000
# Train on 11331 samples, validate on 2073 samples
# Epoch 1/1
# 11331/11331 [==============================] - 101s - loss: 5.4670 - bb_loss: 5454.2245 - class_loss: 0.0127 - bb_acc: 0.7966 - class_acc: 0.9977 - val_loss: 3.9885 - val_bb_loss: 3978.5043 - val_class_loss: 0.0100 - val_bb_acc: 0.7906 - val_class_acc: 1.0000
# [2017-02-21 01:42:47.716986] INFO: Logbook: Bagged Validation Logloss 0.034
# [2017-02-21 01:42:47.717769] INFO: Logbook: Bagged Validation Accuracy 1.000
# Train on 11331 samples, validate on 2073 samples
# Epoch 1/1
# 11331/11331 [==============================] - 101s - loss: 3.6345 - bb_loss: 3619.4980 - class_loss: 0.0150 - bb_acc: 0.8144 - class_acc: 0.9965 - val_loss: 2.5385 - val_bb_loss: 2507.2580 - val_class_loss: 0.0313 - val_bb_acc: 0.8162 - val_class_acc: 0.9976
# [2017-02-21 01:44:39.225648] INFO: Logbook: Bagged Validation Logloss 0.033
# [2017-02-21 01:44:39.226406] INFO: Logbook: Bagged Validation Accuracy 1.000
# Train on 11331 samples, validate on 2073 samples
# Epoch 1/1
# 11331/11331 [==============================] - 101s - loss: 2.3709 - bb_loss: 2360.8727 - class_loss: 0.0101 - bb_acc: 0.8182 - class_acc: 0.9978 - val_loss: 2.3289 - val_bb_loss: 2176.7348 - val_class_loss: 0.1522 - val_bb_acc: 0.8509 - val_class_acc: 0.9556
# [2017-02-21 01:46:31.134557] INFO: Logbook: Bagged Validation Logloss 0.035
# [2017-02-21 01:46:31.135350] INFO: Logbook: Bagged Validation Accuracy 1.000
# th
# Train on 11331 samples, validate on 2073 samples
# Epoch 1/1
# 11331/11331 [==============================] - 102s - loss: 36.4775 - bb_loss: 35769.1764 - class_loss: 0.7083 - bb_acc: 0.6361 - class_acc: 0.7667 - val_loss: 39.0186 - val_bb_loss: 38381.4863 - val_class_loss: 0.6371 - val_bb_acc: 0.6749 - val_class_acc: 0.8032
# Train on 11331 samples, validate on 2073 samples
# Epoch 1/3
# 11331/11331 [==============================] - 101s - loss: 32.0130 - bb_loss: 31819.3784 - class_loss: 0.1936 - bb_acc: 0.6975 - class_acc: 0.9485 - val_loss: 33.1426 - val_bb_loss: 32956.9992 - val_class_loss: 0.1856 - val_bb_acc: 0.7212 - val_class_acc: 0.9884
# Epoch 2/3
# 11331/11331 [==============================] - 101s - loss: 28.5136 - bb_loss: 28434.0190 - class_loss: 0.0796 - bb_acc: 0.7222 - class_acc: 0.9837 - val_loss: 28.5562 - val_bb_loss: 28441.7359 - val_class_loss: 0.1144 - val_bb_acc: 0.7221 - val_class_acc: 0.9904
# Epoch 3/3
# 11331/11331 [==============================] - 101s - loss: 25.3556 - bb_loss: 25300.9655 - class_loss: 0.0546 - bb_acc: 0.7321 - class_acc: 0.9917 - val_loss: 25.3873 - val_bb_loss: 25313.9529 - val_class_loss: 0.0734 - val_bb_acc: 0.7202 - val_class_acc: 0.9986
# Train on 11331 samples, validate on 2073 samples
# Epoch 1/1
# 11331/11331 [==============================] - 101s - loss: 22.1010 - bb_loss: 22064.7502 - class_loss: 0.0362 - bb_acc: 0.7404 - class_acc: 0.9944 - val_loss: 21.4988 - val_bb_loss: 21420.9288 - val_class_loss: 0.0778 - val_bb_acc: 0.7308 - val_class_acc: 0.9947
# [2017-02-21 01:55:28.760968] INFO: Logbook: Bagged Validation Logloss 0.035
# [2017-02-21 01:55:28.761823] INFO: Logbook: Bagged Validation Accuracy 1.000
# Train on 11331 samples, validate on 2073 samples
# Epoch 1/1
# 11331/11331 [==============================] - 101s - loss: 18.4067 - bb_loss: 18385.9669 - class_loss: 0.0207 - bb_acc: 0.7488 - class_acc: 0.9968 - val_loss: 17.2012 - val_bb_loss: 17172.8023 - val_class_loss: 0.0284 - val_bb_acc: 0.7381 - val_class_acc: 1.0000
# [2017-02-21 01:57:20.779433] INFO: Logbook: Bagged Validation Logloss 0.035
# [2017-02-21 01:57:20.780436] INFO: Logbook: Bagged Validation Accuracy 1.000
# Train on 11331 samples, validate on 2073 samples
# Epoch 1/1
# 11331/11331 [==============================] - 101s - loss: 14.6434 - bb_loss: 14624.9072 - class_loss: 0.0185 - bb_acc: 0.7561 - class_acc: 0.9972 - val_loss: 12.9710 - val_bb_loss: 12943.1855 - val_class_loss: 0.0278 - val_bb_acc: 0.7482 - val_class_acc: 1.0000
# [2017-02-21 01:59:13.061673] INFO: Logbook: Bagged Validation Logloss 0.035
# [2017-02-21 01:59:13.062467] INFO: Logbook: Bagged Validation Accuracy 1.000
# Train on 11331 samples, validate on 2073 samples
# Epoch 1/1
# 11331/11331 [==============================] - 102s - loss: 10.9799 - bb_loss: 10968.5770 - class_loss: 0.0114 - bb_acc: 0.7675 - class_acc: 0.9989 - val_loss: 9.2182 - val_bb_loss: 9199.2439 - val_class_loss: 0.0189 - val_bb_acc: 0.7752 - val_class_acc: 0.9990
# [2017-02-21 02:01:05.991918] INFO: Logbook: Bagged Validation Logloss 0.035
# [2017-02-21 02:01:05.992712] INFO: Logbook: Bagged Validation Accuracy 1.000
# Train on 11331 samples, validate on 2073 samples
# Epoch 1/1
# 11331/11331 [==============================] - 102s - loss: 7.9516 - bb_loss: 7934.8095 - class_loss: 0.0168 - bb_acc: 0.7817 - class_acc: 0.9976 - val_loss: 6.3966 - val_bb_loss: 6346.4444 - val_class_loss: 0.0502 - val_bb_acc: 0.7738 - val_class_acc: 0.9971
# [2017-02-21 02:02:58.906583] INFO: Logbook: Bagged Validation Logloss 0.035
# [2017-02-21 02:02:58.907369] INFO: Logbook: Bagged Validation Accuracy 1.000
# Train on 11331 samples, validate on 2073 samples
# Epoch 1/1
# 11331/11331 [==============================] - 101s - loss: 5.4270 - bb_loss: 5417.3013 - class_loss: 0.0097 - bb_acc: 0.7951 - class_acc: 0.9987 - val_loss: 4.0671 - val_bb_loss: 4053.6649 - val_class_loss: 0.0135 - val_bb_acc: 0.8046 - val_class_acc: 1.0000
# [2017-02-21 02:04:51.125369] INFO: Logbook: Bagged Validation Logloss 0.035
# [2017-02-21 02:04:51.126167] INFO: Logbook: Bagged Validation Accuracy 1.000
# Train on 11331 samples, validate on 2073 samples
# Epoch 1/1
# 11331/11331 [==============================] - 101s - loss: 3.6482 - bb_loss: 3634.5821 - class_loss: 0.0136 - bb_acc: 0.8090 - class_acc: 0.9973 - val_loss: 2.5111 - val_bb_loss: 2495.4771 - val_class_loss: 0.0156 - val_bb_acc: 0.8423 - val_class_acc: 1.0000
# [2017-02-21 02:06:42.867875] INFO: Logbook: Bagged Validation Logloss 0.034
# [2017-02-21 02:06:42.868662] INFO: Logbook: Bagged Validation Accuracy 1.000
# Train on 11331 samples, validate on 2073 samples
# Epoch 1/1
# 11331/11331 [==============================] - 101s - loss: 2.4037 - bb_loss: 2389.7021 - class_loss: 0.0140 - bb_acc: 0.8080 - class_acc: 0.9970 - val_loss: 1.4965 - val_bb_loss: 1488.5055 - val_class_loss: 0.0080 - val_bb_acc: 0.8370 - val_class_acc: 1.0000
# [2017-02-21 02:08:34.674527] INFO: Logbook: Bagged Validation Logloss 0.034
# [2017-02-21 02:08:34.675316] INFO: Logbook: Bagged Validation Accuracy 1.000
# th
# Train on 11331 samples, validate on 2073 samples
# Epoch 1/1
# 11331/11331 [==============================] - 101s - loss: 36.4975 - bb_loss: 35772.9384 - class_loss: 0.7245 - bb_acc: 0.6228 - class_acc: 0.7662 - val_loss: 35.7761 - val_bb_loss: 35315.0622 - val_class_loss: 0.4610 - val_bb_acc: 0.7057 - val_class_acc: 0.9320
# Train on 11331 samples, validate on 2073 samples
# Epoch 1/3
# 11331/11331 [==============================] - 102s - loss: 32.0319 - bb_loss: 31827.2953 - class_loss: 0.2046 - bb_acc: 0.6888 - class_acc: 0.9486 - val_loss: 29.5643 - val_bb_loss: 29392.2419 - val_class_loss: 0.1721 - val_bb_acc: 0.7265 - val_class_acc: 0.9860
# Epoch 2/3
# 11331/11331 [==============================] - 101s - loss: 28.5574 - bb_loss: 28465.1845 - class_loss: 0.0922 - bb_acc: 0.7144 - class_acc: 0.9808 - val_loss: 25.7205 - val_bb_loss: 25591.4072 - val_class_loss: 0.1291 - val_bb_acc: 0.7289 - val_class_acc: 0.9904
# Epoch 3/3
# 11331/11331 [==============================] - 101s - loss: 25.2921 - bb_loss: 25245.3974 - class_loss: 0.0467 - bb_acc: 0.7245 - class_acc: 0.9921 - val_loss: 25.4306 - val_bb_loss: 25360.7276 - val_class_loss: 0.0699 - val_bb_acc: 0.7303 - val_class_acc: 0.9981
# Train on 11331 samples, validate on 2073 samples
# Epoch 1/1
# 11331/11331 [==============================] - 101s - loss: 22.0200 - bb_loss: 21980.3744 - class_loss: 0.0396 - bb_acc: 0.7379 - class_acc: 0.9914 - val_loss: 20.6552 - val_bb_loss: 20574.9107 - val_class_loss: 0.0802 - val_bb_acc: 0.7738 - val_class_acc: 0.9981
# [2017-02-21 02:17:33.265287] INFO: Logbook: Bagged Validation Logloss 0.034
# [2017-02-21 02:17:33.266134] INFO: Logbook: Bagged Validation Accuracy 1.000
# Train on 11331 samples, validate on 2073 samples
# Epoch 1/1
# 11331/11331 [==============================] - 101s - loss: 18.4611 - bb_loss: 18430.2823 - class_loss: 0.0308 - bb_acc: 0.7480 - class_acc: 0.9951 - val_loss: 15.8088 - val_bb_loss: 15769.7606 - val_class_loss: 0.0390 - val_bb_acc: 0.7578 - val_class_acc: 0.9986
# [2017-02-21 02:19:25.530612] INFO: Logbook: Bagged Validation Logloss 0.034
# [2017-02-21 02:19:25.531444] INFO: Logbook: Bagged Validation Accuracy 1.000
# Train on 11331 samples, validate on 2073 samples
# Epoch 1/1
# 11331/11331 [==============================] - 101s - loss: 14.6823 - bb_loss: 14652.7087 - class_loss: 0.0296 - bb_acc: 0.7578 - class_acc: 0.9951 - val_loss: 12.9022 - val_bb_loss: 12715.6307 - val_class_loss: 0.1866 - val_bb_acc: 0.7361 - val_class_acc: 0.9682
# [2017-02-21 02:21:17.541463] INFO: Logbook: Bagged Validation Logloss 0.036
# [2017-02-21 02:21:17.542271] INFO: Logbook: Bagged Validation Accuracy 1.000
# Train on 11331 samples, validate on 2073 samples
# Epoch 1/1
# 11331/11331 [==============================] - 101s - loss: 11.0390 - bb_loss: 11016.5610 - class_loss: 0.0224 - bb_acc: 0.7636 - class_acc: 0.9972 - val_loss: 11.2456 - val_bb_loss: 11131.0418 - val_class_loss: 0.1145 - val_bb_acc: 0.7535 - val_class_acc: 0.9976
# [2017-02-21 02:23:09.550301] INFO: Logbook: Bagged Validation Logloss 0.037
# [2017-02-21 02:23:09.551146] INFO: Logbook: Bagged Validation Accuracy 1.000
# Train on 11331 samples, validate on 2073 samples
# Epoch 1/1
# 11331/11331 [==============================] - 101s - loss: 7.9644 - bb_loss: 7942.5422 - class_loss: 0.0218 - bb_acc: 0.7796 - class_acc: 0.9966 - val_loss: 5.8318 - val_bb_loss: 5815.6787 - val_class_loss: 0.0161 - val_bb_acc: 0.7834 - val_class_acc: 1.0000
# [2017-02-21 02:25:01.920004] INFO: Logbook: Bagged Validation Logloss 0.037
# [2017-02-21 02:25:01.920878] INFO: Logbook: Bagged Validation Accuracy 1.000
# Train on 11331 samples, validate on 2073 samples
# Epoch 1/1
# 11331/11331 [==============================] - 101s - loss: 5.4519 - bb_loss: 5443.0688 - class_loss: 0.0088 - bb_acc: 0.7979 - class_acc: 0.9992 - val_loss: 3.9946 - val_bb_loss: 3971.7644 - val_class_loss: 0.0228 - val_bb_acc: 0.7984 - val_class_acc: 0.9990
# [2017-02-21 02:26:54.133037] INFO: Logbook: Bagged Validation Logloss 0.037
# [2017-02-21 02:26:54.133856] INFO: Logbook: Bagged Validation Accuracy 1.000
# Train on 11331 samples, validate on 2073 samples
# Epoch 1/1
# 11331/11331 [==============================] - 101s - loss: 3.6368 - bb_loss: 3628.7987 - class_loss: 0.0080 - bb_acc: 0.8118 - class_acc: 0.9987 - val_loss: 2.6447 - val_bb_loss: 2634.3161 - val_class_loss: 0.0104 - val_bb_acc: 0.8283 - val_class_acc: 0.9995
# [2017-02-21 02:28:46.051593] INFO: Logbook: Bagged Validation Logloss 0.036
# [2017-02-21 02:28:46.052396] INFO: Logbook: Bagged Validation Accuracy 1.000
# Train on 11331 samples, validate on 2073 samples
# Epoch 1/1
# 11331/11331 [==============================] - 101s - loss: 2.3610 - bb_loss: 2353.6750 - class_loss: 0.0073 - bb_acc: 0.8114 - class_acc: 0.9993 - val_loss: 1.5782 - val_bb_loss: 1568.6908 - val_class_loss: 0.0095 - val_bb_acc: 0.8640 - val_class_acc: 0.9995
# [2017-02-21 02:30:37.912109] INFO: Logbook: Bagged Validation Logloss 0.036
# [2017-02-21 02:30:37.912945] INFO: Logbook: Bagged Validation Accuracy 1.000
# th
# Train on 11331 samples, validate on 2073 samples
# Epoch 1/1
# 11331/11331 [==============================] - 102s - loss: 36.5553 - bb_loss: 35802.2164 - class_loss: 0.7530 - bb_acc: 0.5779 - class_acc: 0.7668 - val_loss: 36.1786 - val_bb_loss: 35711.6477 - val_class_loss: 0.4669 - val_bb_acc: 0.6652 - val_class_acc: 0.9542
# Train on 11331 samples, validate on 2073 samples
# Epoch 1/3
# 11331/11331 [==============================] - 102s - loss: 32.1338 - bb_loss: 31920.2933 - class_loss: 0.2135 - bb_acc: 0.6799 - class_acc: 0.9472 - val_loss: 31.5200 - val_bb_loss: 31187.4256 - val_class_loss: 0.3325 - val_bb_acc: 0.7226 - val_class_acc: 0.9320
# Epoch 2/3
# 11331/11331 [==============================] - 101s - loss: 28.5949 - bb_loss: 28489.7633 - class_loss: 0.1052 - bb_acc: 0.7163 - class_acc: 0.9765 - val_loss: 29.6405 - val_bb_loss: 29461.6497 - val_class_loss: 0.1788 - val_bb_acc: 0.6980 - val_class_acc: 0.9793
# Epoch 3/3
# 11331/11331 [==============================] - 101s - loss: 25.3641 - bb_loss: 25310.9386 - class_loss: 0.0531 - bb_acc: 0.7335 - class_acc: 0.9891 - val_loss: 24.6592 - val_bb_loss: 24571.5352 - val_class_loss: 0.0877 - val_bb_acc: 0.7328 - val_class_acc: 0.9860
# Train on 11331 samples, validate on 2073 samples
# Epoch 1/1
# 11331/11331 [==============================] - 101s - loss: 22.0480 - bb_loss: 22018.8935 - class_loss: 0.0291 - bb_acc: 0.7400 - class_acc: 0.9959 - val_loss: 21.2396 - val_bb_loss: 21195.5894 - val_class_loss: 0.0440 - val_bb_acc: 0.7294 - val_class_acc: 0.9995
# [2017-02-21 02:39:35.396600] INFO: Logbook: Bagged Validation Logloss 0.036
# [2017-02-21 02:39:35.397702] INFO: Logbook: Bagged Validation Accuracy 1.000
# Train on 11331 samples, validate on 2073 samples
# Epoch 1/1
# 11331/11331 [==============================] - 101s - loss: 18.4352 - bb_loss: 18408.0962 - class_loss: 0.0271 - bb_acc: 0.7510 - class_acc: 0.9953 - val_loss: 17.5862 - val_bb_loss: 17541.9596 - val_class_loss: 0.0443 - val_bb_acc: 0.7381 - val_class_acc: 0.9995
# [2017-02-21 02:41:27.566474] INFO: Logbook: Bagged Validation Logloss 0.036
# [2017-02-21 02:41:27.567331] INFO: Logbook: Bagged Validation Accuracy 1.000
# Train on 11331 samples, validate on 2073 samples
# Epoch 1/1
# 11331/11331 [==============================] - 101s - loss: 14.6581 - bb_loss: 14641.3412 - class_loss: 0.0168 - bb_acc: 0.7593 - class_acc: 0.9978 - val_loss: 12.6513 - val_bb_loss: 12593.0455 - val_class_loss: 0.0583 - val_bb_acc: 0.7429 - val_class_acc: 0.9957
# [2017-02-21 02:43:19.508898] INFO: Logbook: Bagged Validation Logloss 0.036
# [2017-02-21 02:43:19.509776] INFO: Logbook: Bagged Validation Accuracy 1.000
# Train on 11331 samples, validate on 2073 samples
# Epoch 1/1
# 11331/11331 [==============================] - 101s - loss: 11.0099 - bb_loss: 10996.3179 - class_loss: 0.0136 - bb_acc: 0.7685 - class_acc: 0.9987 - val_loss: 10.0365 - val_bb_loss: 9533.1229 - val_class_loss: 0.5034 - val_bb_acc: 0.7482 - val_class_acc: 0.8355
# [2017-02-21 02:45:11.401451] INFO: Logbook: Bagged Validation Logloss 0.039
# [2017-02-21 02:45:11.402217] INFO: Logbook: Bagged Validation Accuracy 1.000
# Train on 11331 samples, validate on 2073 samples
# Epoch 1/1
# 11331/11331 [==============================] - 101s - loss: 7.9342 - bb_loss: 7895.3489 - class_loss: 0.0389 - bb_acc: 0.7829 - class_acc: 0.9913 - val_loss: 5.9763 - val_bb_loss: 5891.8764 - val_class_loss: 0.0845 - val_bb_acc: 0.7540 - val_class_acc: 0.9783
# [2017-02-21 02:47:03.593763] INFO: Logbook: Bagged Validation Logloss 0.039
# [2017-02-21 02:47:03.594568] INFO: Logbook: Bagged Validation Accuracy 1.000
# Train on 11331 samples, validate on 2073 samples
# Epoch 1/1
# 11331/11331 [==============================] - 101s - loss: 5.4309 - bb_loss: 5419.4408 - class_loss: 0.0115 - bb_acc: 0.7883 - class_acc: 0.9989 - val_loss: 3.7664 - val_bb_loss: 3731.3061 - val_class_loss: 0.0351 - val_bb_acc: 0.7988 - val_class_acc: 1.0000
# [2017-02-21 02:48:55.494623] INFO: Logbook: Bagged Validation Logloss 0.039
# [2017-02-21 02:48:55.495445] INFO: Logbook: Bagged Validation Accuracy 1.000
# Train on 11331 samples, validate on 2073 samples
# Epoch 1/1
# 11331/11331 [==============================] - 101s - loss: 3.6882 - bb_loss: 3665.5802 - class_loss: 0.0226 - bb_acc: 0.8002 - class_acc: 0.9966 - val_loss: 2.8432 - val_bb_loss: 2789.2498 - val_class_loss: 0.0540 - val_bb_acc: 0.8172 - val_class_acc: 0.9952
# [2017-02-21 02:50:47.693938] INFO: Logbook: Bagged Validation Logloss 0.039
# [2017-02-21 02:50:47.694760] INFO: Logbook: Bagged Validation Accuracy 1.000
# Train on 11331 samples, validate on 2073 samples
# Epoch 1/1
# 11331/11331 [==============================] - 101s - loss: 2.3765 - bb_loss: 2365.0250 - class_loss: 0.0115 - bb_acc: 0.8139 - class_acc: 0.9984 - val_loss: 1.4622 - val_bb_loss: 1444.9191 - val_class_loss: 0.0172 - val_bb_acc: 0.8558 - val_class_acc: 1.0000
# [2017-02-21 02:52:39.461643] INFO: Logbook: Bagged Validation Logloss 0.039
# [2017-02-21 02:52:39.462431] INFO: Logbook: Bagged Validation Accuracy 1.000

# %%
val = get_data(path+'valid', load_size)
pval_bbox = model[0].predict(da_conv_val_feat, batch_size=batch_size)[0]
# Out:
# Found 691 images belonging to 8 classes.

# %%
def create_rect(bb, color='red'):
    return plt.Rectangle((bb[2], bb[3]), bb[1], bb[0], color=color, fill=False, lw=3)

def show_bb(i):
    bb = val_bbox[i]
    pbb = pval_bbox[i]
    plot(val[i])
    plt.gca().add_patch(create_rect(bb, color='red'))
    plt.gca().add_patch(create_rect(pbb, color='yellow'))

show_bb(350)

# %%
# metrics.log_loss(val_labels, do_clip(sum(pvalsls)/len(pvalsls), .9999))
preds = sum(predsls)/len(predsls)
subm = do_clip(preds, clip)

if full:
    subm_name = path+'results/subm_full_conv_' + timestr + '.csv' #'.csv.gz'
else:
    subm_name = path+'results/subm_part_conv_' + timestr + '.csv' #'.csv.gz'

classes = ['ALB', 'BET', 'DOL', 'LAG', 'NoF', 'OTHER', 'SHARK', 'YFT']
submission = pd.DataFrame(subm, columns=classes)
submission.insert(0, 'image', raw_test_filenames)
submission.to_csv(subm_name, index=False)#, compression='gzip')
log.info('Done - files @ ' + subm_name)
# Out:
# [2017-02-21 02:53:37.541823] INFO: Logbook: Done - files @ ../data/fish/results/subm_full_conv_20170220.csv

# %%
FileLink(subm_name)
# Out:
# /home/ubuntu/fish/data/fish/results/subm_full_conv_20170220.csv
