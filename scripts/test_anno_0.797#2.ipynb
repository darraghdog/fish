# %%
# Read in Libraries
from __future__ import division, print_function
from logbook import Logger, StreamHandler
import sys
StreamHandler(sys.stdout).push_application()
log = Logger('Logbook')
import shutil, csv, time
timestr = time.strftime("%Y%m%d")
import ujson as json
import utils; reload(utils)
from utils import *
import gc
# from __future__ import division, print_function
from theano.sandbox import cuda
from vgg16bn import Vgg16BN
from sklearn import metrics
# %matplotlib inline

def accuracyfunc(y_act, y_pred):
    return metrics.accuracy_score(np.argmax(y_act, axis=1), np.argmax(y_pred, axis=1))
    
def refresh_directory_structure(name, sub_dirs):
    gdir = os.path.join(path, name)
    if os.path.exists(gdir):
        shutil.rmtree(gdir)
    os.makedirs(gdir)
    for sub_dir in sub_dirs:
        os.makedirs(os.path.join(gdir, sub_dir))
# Out:
# Using gpu device 0: Tesla K80 (CNMeM is disabled, cuDNN 5103)
# /home/ubuntu/anaconda2/lib/python2.7/site-packages/theano/sandbox/cuda/__init__.py:600: UserWarning: Your cuDNN version is more recent than the one Theano officially supports. If you see any problems, try updating Theano or downgrading cuDNN to version 5.
#   warnings.warn(warn)
# Using Theano backend.

# %%
# Set Parameters and check files
refresh_directories = False
input_exists = True
full = True
log.info('Set Paramters')
path = "../data/fish/"
batch_size=32
clip = 0.99
bags = 1
load_size = (440, 780)#(360, 640)
# Out:
# [2017-02-19 18:12:13.846453] INFO: Logbook: Set Paramters

# %%
# Create the test and valid directory
if refresh_directories:
    log.info('Create directory structure and validation files')
    sub_dirs = os.listdir(os.path.join(path, 'train-all'))
    if '.DS_Store' in sub_dirs: sub_dirs.remove('.DS_Store')
    refresh_directory_structure('train', sub_dirs)
    refresh_directory_structure('valid', sub_dirs)
    for c,row in enumerate(csv.DictReader(open('../image_validation_set.csv'))):
        value = 'valid' if row['Validation'] == '1' else 'train'
        name_from = os.path.join(path, 'train-all', row['SubDirectory'], row['file_name'])
        name_to   = os.path.join(path, value, row['SubDirectory'], row['file_name'])
        shutil.copyfile(name_from, name_to)

# %%
# Read in our VGG pretrained model
log.info('Get VGG')
model = vgg_ft_bn(8)

# Create our VGG model
log.info('Create VGG')
vgg640 = Vgg16BN(load_size).model
vgg640.pop()
vgg640.input_shape, vgg640.output_shape
vgg640.compile(Adam(), 'categorical_crossentropy', metrics=['accuracy'])

# get labels
(val_classes, trn_classes, val_labels, trn_labels,
    val_filenames, filenames, test_filenames) = get_classes(path)

# Read in filenames
log.info('Read filenames')
raw_filenames = [f.split('/')[-1] for f in filenames]
raw_test_filenames = [f.split('/')[-1] for f in test_filenames]
raw_val_filenames = [f.split('/')[-1] for f in val_filenames]
# Out:
# [2017-02-19 18:12:13.869791] INFO: Logbook: Get VGG
# [2017-02-19 18:12:17.043044] INFO: Logbook: Create VGG
# Found 3086 images belonging to 8 classes.
# Found 691 images belonging to 8 classes.
# Found 1000 images belonging to 1 classes.
# [2017-02-19 18:12:17.572167] INFO: Logbook: Read filenames

# %%
# Read in the boxes
anno_classes = ['alb', 'bet', 'dol', 'lag', 'other', 'shark', 'yft']
bb_json = {}
for c in anno_classes:
    j = json.load(open(os.path.join(path, 'box/{}_labels.json'.format(c)), 'r'))
    for l in j:
        if 'annotations' in l.keys() and len(l['annotations'])>0:
            bb_json[l['filename'].split('/')[-1]] = sorted(
                l['annotations'], key=lambda x: x['height']*x['width'])[-1]

# make it easy to find the nof dots, by putting themin the middle
#empty_bbox = {'height': 0., 'width': 0., 'x': 1280/2., 'y': 720/2}
empty_bbox = {'height': 0., 'width': 0., 'x': 0., 'y': 0.}

for f in raw_filenames:
    if not f in bb_json.keys(): bb_json[f] = empty_bbox
for f in raw_val_filenames:
    if not f in bb_json.keys(): bb_json[f] = empty_bbox

# %%
# Finally, we convert the dictionary into an array, and convert the coordinates to our resized 224x224 images.
bb_params = ['height', 'width', 'x', 'y']
def convert_bb(bb, size):
    bb = [bb[p] for p in bb_params]
    conv_x = (load_size[1] / size[0])#(224. / size[0])
    conv_y = (load_size[0] / size[1])#(224. / size[1])
    bb[0] = bb[0]*conv_y
    bb[1] = bb[1]*conv_x
    bb[2] = max(bb[2]*conv_x, 0)
    bb[3] = max(bb[3]*conv_y, 0)
    return bb

# %%
trn_sizes = [PIL.Image.open(path+'train/'+f).size for f in filenames]
val_sizes = [PIL.Image.open(path+'valid/'+f).size for f in val_filenames]
tst_sizes = [PIL.Image.open(path+'test/'+f).size for f in test_filenames]

# %%
trn_bbox = np.stack([convert_bb(bb_json[f], s) for f,s in zip(raw_filenames, trn_sizes)], 
                   ).astype(np.float32)
val_bbox = np.stack([convert_bb(bb_json[f], s) 
                   for f,s in zip(raw_val_filenames, val_sizes)]).astype(np.float32)

# %%
def create_rect(bb, color='red'):
    return plt.Rectangle((bb[2], bb[3]), bb[1], bb[0], color=color, fill=False, lw=3)

def show_bb(i):
    bb = val_bbox[i]
    plot(val[i])
    plt.gca().add_patch(create_rect(bb))

val = get_data(path+'valid', load_size)
show_bb(500)
del val
gc.collect()
# Out:
# Found 691 images belonging to 8 classes.
# 630

# %%
log.info('Read in data')
if not input_exists:

    batches = get_batches(path+'train', batch_size=batch_size)
    val_batches = get_batches(path+'valid', batch_size=batch_size*2, shuffle=False)
    (val_classes, trn_classes, val_labels, trn_labels, 
        val_filenames, filenames, test_filenames) = get_classes(path)
    
    # Fetch our large images 
    # Precompute the output of the convolutional part of VGG
    log.info('Fetch images')
    log.info('Get VGG output')
    log.info('Write VGG output')
    
    val = get_data(path+'valid', load_size)
    conv_val_feat = vgg640.predict(val, batch_size=16, verbose=1)
    save_array(path+'results/conv_val_big_feat.dat', conv_val_feat)
    del val, conv_val_feat
    gc.collect()
    
    trn = get_data(path+'train', load_size)
    conv_trn_feat = vgg640.predict(trn, batch_size=16, verbose=1)    
    del trn
    gc.collect()
    save_array(path+'results/conv_trn_big_feat.dat', conv_trn_feat) 
    del conv_trn_feat
    gc.collect()
    
    test = get_data(path+'test', load_size)
    conv_test_feat = vgg640.predict(test, batch_size=16, verbose=1)
    save_array(path+'results/conv_test_big_feat.dat', conv_test_feat)     
    del test, conv_test_feat
    gc.collect()

    # For memory purposes delete out the original train and validation
    log.info('Clear up memory')
    #del trn, val, test
    gc.collect()
    gc.collect()
# Out:
# [2017-02-19 18:13:09.240636] INFO: Logbook: Read in data

# %%
gc.collect()
conv_val_feat = load_array(path+'results/conv_val_big_feat.dat')
conv_trn_feat = load_array(path+'results/conv_trn_big_feat.dat') 
conv_test_feat = load_array(path+'results/conv_test_big_feat.dat')

# %%
if full:
    conv_trn_feat = np.concatenate([conv_trn_feat, conv_val_feat])
    trn_labels = np.concatenate([trn_labels, val_labels]) 
    trn_bbox = np.concatenate([trn_bbox, val_bbox])
    
# Our Convolutional Net Architecture
log.info('Create and fit CNN')
p=0.6
# Set up the fully convolutional net (FCN); 
conv_layers,_ = split_at(vgg640, Convolution2D)
nf=128; p=0. # No dropout
# Out:
# [2017-02-19 18:13:21.798691] INFO: Logbook: Create and fit CNN

# %%
gc.collect()
nf = 512
p  = 0.3
def create_model():
    inp = Input(conv_layers[-1].output_shape[1:])
    x = MaxPooling2D()(inp)
    x = ZeroPadding2D((1,1))(x)
    x = Convolution2D(nf,3,3, activation='relu', border_mode='same')(x)
    x =   Dropout(p)(x)
    x = BatchNormalization(axis=1)(x)
    #x = MaxPooling2D()(x)
    #x = ZeroPadding2D((1,1))(x)
    #x = Convolution2D(nf,3,3, activation='relu', border_mode='same')(x)
    #x =   Dropout(p)(x)
    #x = BatchNormalization(axis=1)(x)
    x = MaxPooling2D()(x)
    x = ZeroPadding2D((1,1))(x)
    x = Convolution2D(nf,3,3, activation='relu', border_mode='same')(x)
    x =   Dropout(p)(x)
    x = BatchNormalization(axis=1)(x)
    x1 =   MaxPooling2D()(x)
    x1 =   Convolution2D(8,3,3, border_mode='same')(x1)
    x1 =   Dropout(p/2)(x1)
    x1 =   GlobalAveragePooling2D()(x1)
    x = Dropout(p/2)(x)
    x = Flatten()(x)
    x = Dense(1024, activation='relu')(x)
    x = BatchNormalization()(x)
    x = Dropout(p/2)(x)
    x = Dense(1024, activation='relu')(x)
    x = BatchNormalization()(x)
    x = Dropout(p/2)(x)
    x_bb = Dense(4, name='bb')(x)
    x_class = Dense(8, activation='softmax', name='class')(x1)
    return inp, x_bb, x_class

## Set up the fully convolutional net (FCN); 
#conv_layers,_ = split_at(vgg640, Convolution2D)
#nf=128; p=0. # No dropout

model = []
predsls = []
pvalsls = []

for ii in range(10):
    inp, x_bb, x_class = create_model()
    model.append(Model([inp], [x_bb, x_class]))
    #model.summary()
    model[ii].compile(Adam(lr=1e-3), loss=['mse', 'categorical_crossentropy'], metrics=['accuracy'],
                 loss_weights=[.001, 1.])
    model[ii].fit(conv_trn_feat, [trn_bbox, trn_labels], batch_size=batch_size, nb_epoch=5, 
                 validation_data=(conv_val_feat, [val_bbox, val_labels]))
    model[ii].optimizer.lr = 1e-4
    model[ii].optimizer.loss_weights=[.00001, 1.]
    model[ii].fit(conv_trn_feat, [trn_bbox, trn_labels], batch_size=batch_size, nb_epoch=2, 
                 validation_data=(conv_val_feat, [val_bbox, val_labels]))
    model[ii].optimizer.lr = 1e-5

    count = 0
    while count < 8:
        model[ii].fit(conv_trn_feat, [trn_bbox, trn_labels], batch_size=batch_size, nb_epoch=1, 
                     validation_data=(conv_val_feat, [val_bbox, val_labels]))
        predsls.append(model[ii].predict(conv_test_feat, batch_size=batch_size)[1]) # or try 32 batch_size
        pvalsls.append(model[ii].predict(conv_val_feat, batch_size=batch_size)[1])
        val_score = "%.3f" % metrics.log_loss(val_labels, sum(pvalsls)/len(pvalsls))
        acc_score = "%.3f" % accuracyfunc(val_labels, do_clip(sum(pvalsls)/len(pvalsls), clip))
        log.info('Bagged Validation Logloss ' + str(val_score))
        log.info('Bagged Validation Accuracy ' + str(acc_score))
        count += 1
# Out:
# th
# Train on 3777 samples, validate on 691 samples
# Epoch 1/5
# 3777/3777 [==============================] - 33s - loss: 34.7166 - bb_loss: 33400.1754 - class_loss: 1.3164 - bb_acc: 0.6299 - class_acc: 0.6579 - val_loss: 29.1645 - val_bb_loss: 28606.8787 - val_class_loss: 0.5576 - val_bb_acc: 0.7424 - val_class_acc: 0.8220
# Epoch 2/5
# 3777/3777 [==============================] - 33s - loss: 22.4510 - bb_loss: 22037.1221 - class_loss: 0.4139 - bb_acc: 0.6995 - class_acc: 0.8748 - val_loss: 16.2440 - val_bb_loss: 15659.1638 - val_class_loss: 0.5849 - val_bb_acc: 0.7294 - val_class_acc: 0.7844
# Epoch 3/5
# 3777/3777 [==============================] - 33s - loss: 9.3769 - bb_loss: 9144.9646 - class_loss: 0.2320 - bb_acc: 0.7569 - class_acc: 0.9365 - val_loss: 4.1405 - val_bb_loss: 3943.1244 - val_class_loss: 0.1974 - val_bb_acc: 0.8133 - val_class_acc: 0.9638
# Epoch 4/5
# 3777/3777 [==============================] - 33s - loss: 3.0013 - bb_loss: 2906.2478 - class_loss: 0.0950 - bb_acc: 0.7945 - class_acc: 0.9743 - val_loss: 2.5179 - val_bb_loss: 1901.7162 - val_class_loss: 0.6161 - val_bb_acc: 0.7800 - val_class_acc: 0.7323
# Epoch 5/5
# 3777/3777 [==============================] - 33s - loss: 1.7315 - bb_loss: 1547.1208 - class_loss: 0.1844 - bb_acc: 0.7919 - class_acc: 0.9576 - val_loss: 1.3123 - val_bb_loss: 1134.6360 - val_class_loss: 0.1777 - val_bb_acc: 0.8075 - val_class_acc: 0.9392
# Train on 3777 samples, validate on 691 samples
# Epoch 1/2
# 3777/3777 [==============================] - 33s - loss: 1.3036 - bb_loss: 1187.0046 - class_loss: 0.1166 - bb_acc: 0.7964 - class_acc: 0.9701 - val_loss: 0.9835 - val_bb_loss: 840.6460 - val_class_loss: 0.1429 - val_bb_acc: 0.8119 - val_class_acc: 0.9682
# Epoch 2/2
# 3777/3777 [==============================] - 33s - loss: 1.1209 - bb_loss: 1066.2107 - class_loss: 0.0547 - bb_acc: 0.7967 - class_acc: 0.9868 - val_loss: 0.6424 - val_bb_loss: 569.0251 - val_class_loss: 0.0734 - val_bb_acc: 0.8307 - val_class_acc: 0.9826
# Train on 3777 samples, validate on 691 samples
# Epoch 1/1
# 3777/3777 [==============================] - 33s - loss: 0.9775 - bb_loss: 929.3138 - class_loss: 0.0482 - bb_acc: 0.7930 - class_acc: 0.9836 - val_loss: 0.4844 - val_bb_loss: 472.5587 - val_class_loss: 0.0119 - val_bb_acc: 0.8423 - val_class_acc: 0.9971
# [2017-02-19 18:18:16.597840] INFO: Logbook: Bagged Validation Logloss 0.012
# [2017-02-19 18:18:16.598654] INFO: Logbook: Bagged Validation Accuracy 0.997
# Train on 3777 samples, validate on 691 samples
# Epoch 1/1
# 3777/3777 [==============================] - 33s - loss: 0.7977 - bb_loss: 779.6545 - class_loss: 0.0181 - bb_acc: 0.7993 - class_acc: 0.9950 - val_loss: 0.5307 - val_bb_loss: 505.6996 - val_class_loss: 0.0250 - val_bb_acc: 0.8220 - val_class_acc: 0.9928
# [2017-02-19 18:18:56.102031] INFO: Logbook: Bagged Validation Logloss 0.017
# [2017-02-19 18:18:56.102922] INFO: Logbook: Bagged Validation Accuracy 0.997
# Train on 3777 samples, validate on 691 samples
# Epoch 1/1
# 3777/3777 [==============================] - 34s - loss: 0.9424 - bb_loss: 892.1147 - class_loss: 0.0503 - bb_acc: 0.7969 - class_acc: 0.9817 - val_loss: 0.4529 - val_bb_loss: 443.9203 - val_class_loss: 0.0090 - val_bb_acc: 0.8480 - val_class_acc: 1.0000
# [2017-02-19 18:19:35.942988] INFO: Logbook: Bagged Validation Logloss 0.014
# [2017-02-19 18:19:35.943836] INFO: Logbook: Bagged Validation Accuracy 0.999
# Train on 3777 samples, validate on 691 samples
# Epoch 1/1
# 3777/3777 [==============================] - 34s - loss: 0.
INFO: Logbook: Bagged Validation Accuracy 1.000
# Train on 3777 samples, validate on 691 samples
# Epoch 1/1
# 3777/3777 [==============================] - 33s - loss: 1.0802 - bb_loss: 970.0342 - class_loss: 0.1102 - bb_acc: 0.7967 - class_acc: 0.9719 - val_loss: 0.4852 - val_bb_loss: 380.8004 - val_class_loss: 0.1044 - val_bb_acc: 0.8365 - val_class_acc: 0.9566
# [2017-02-19 19:36:02.615037] INFO: Logbook: Bagged Validation Logloss 0.042
# [2017-02-19 19:36:02.615787] INFO: Logbook: Bagged Validation Accuracy 1.000
# Train on 3777 samples, validate on 691 samples
# Epoch 1/1
# 3777/3777 [==============================] - 33s - loss: 1.0105 - bb_loss: 946.5229 - class_loss: 0.0640 - bb_acc: 0.8038 - class_acc: 0.9852 - val_loss: 0.5791 - val_bb_loss: 550.6940 - val_class_loss: 0.0284 - val_bb_acc: 0.9045 - val_class_acc: 0.9899
# [2017-02-19 19:36:42.304950] INFO: Logbook: Bagged Validation Logloss 0.042
# [2017-02-19 19:36:42.305753] INFO: Logbook: Bagged Validation Accuracy 1.000
# Train on 3777 samples, validate on 691 samples
# Epoch 1/1
# 3777/3777 [==============================] - 33s - loss: 0.8067 - bb_loss: 774.5579 - class_loss: 0.0322 - bb_acc: 0.8104 - class_acc: 0.9915 - val_loss: 0.3472 - val_bb_loss: 341.0355 - val_class_loss: 0.0061 - val_bb_acc: 0.8553 - val_class_acc: 0.9986
# [2017-02-19 19:37:21.984823] INFO: Logbook: Bagged Validation Logloss 0.042
# [2017-02-19 19:37:21.985582] INFO: Logbook: Bagged Validation Accuracy 1.000
# Train on 3777 samples, validate on 691 samples
# Epoch 1/1
# 3777/3777 [==============================] - 33s - loss: 0.7156 - bb_loss: 708.7042 - class_loss: 0.0069 - bb_acc: 0.8022 - class_acc: 0.9984 - val_loss: 0.2441 - val_bb_loss: 213.5493 - val_class_loss: 0.0305 - val_bb_acc: 0.9016 - val_class_acc: 0.9899
# [2017-02-19 19:38:01.659909] INFO: Logbook: Bagged Validation Logloss 0.041
# [2017-02-19 19:38:01.660666] INFO: Logbook: Bagged Validation Accuracy 1.000
# Train on 3777 samples, validate on 691 samples
# Epoch 1/1
# 3777/3777 [==============================] - 33s - loss: 0.8330 - bb_loss: 776.7070 - class_loss: 0.0563 - bb_acc: 0.7956 - class_acc: 0.9868 - val_loss: 0.1788 - val_bb_loss: 168.2775 - val_class_loss: 0.0106 - val_bb_acc: 0.8828 - val_class_acc: 0.9971
# [2017-02-19 19:38:41.341884] INFO: Logbook: Bagged Validation Logloss 0.041
# [2017-02-19 19:38:41.342638] INFO: Logbook: Bagged Validation Accuracy 1.000
# Train on 3777 samples, validate on 691 samples
# Epoch 1/1
# 3777/3777 [==============================] - 33s - loss: 0.7712 - bb_loss: 710.4264 - class_loss: 0.0608 - bb_acc: 0.8173 - class_acc: 0.9860 - val_loss: 0.3081 - val_bb_loss: 294.2721 - val_class_loss: 0.0138 - val_bb_acc: 0.8784 - val_class_acc: 0.9986
# [2017-02-19 19:39:20.989957] INFO: Logbook: Bagged Validation Logloss 0.040
# [2017-02-19 19:39:20.990877] INFO: Logbook: Bagged Validation Accuracy 1.000
# Train on 3777 samples, validate on 691 samples
# Epoch 1/1
# 3777/3777 [==============================] - 33s - loss: 0.7296 - bb_loss: 722.8013 - class_loss: 0.0068 - bb_acc: 0.8033 - class_acc: 0.9974 - val_loss: 0.1874 - val_bb_loss: 186.1245 - val_class_loss: 0.0013 - val_bb_acc: 0.9334 - val_class_acc: 1.0000
# [2017-02-19 19:40:00.659802] INFO: Logbook: Bagged Validation Logloss 0.040
# [2017-02-19 19:40:00.660595] INFO: Logbook: Bagged Validation Accuracy 1.000
# th
# Train on 3777 samples, validate on 691 samples
# Epoch 1/5
# 3777/3777 [==============================] - 34s - loss: 34.5653 - bb_loss: 33365.3495 - class_loss: 1.1999 - bb_acc: 0.6164 - class_acc: 0.7003 - val_loss: 26.8005 - val_bb_loss: 26269.2755 - val_class_loss: 0.5312 - val_bb_acc: 0.6975 - val_class_acc: 0.8336
# Epoch 2/5
# 3777/3777 [==============================] - 33s - loss: 22.4003 - bb_loss: 22064.4071 - class_loss: 0.3359 - bb_acc: 0.6947 - class_acc: 0.9055 - val_loss: 15.8085 - val_bb_loss: 15462.0806 - val_class_loss: 0.3464 - val_bb_acc: 0.7713 - val_class_acc: 0.8929
# Epoch 3/5
# 3777/3777 [==============================] - 34s - loss: 9.4168 - bb_loss: 9157.9153 - class_loss: 0.2589 - bb_acc: 0.7543 - class_acc: 0.9346 - val_loss: 5.4581 - val_bb_loss: 5347.0554 - val_class_loss: 0.1110 - val_bb_acc: 0.7902 - val_class_acc: 0.9638
# Epoch 4/5
# 3777/3777 [==============================] - 33s - loss: 2.8732 - bb_loss: 2799.5609 - class_loss: 0.0737 - bb_acc: 0.7996 - class_acc: 0.9846 - val_loss: 4.0197 - val_bb_loss: 2739.0698 - val_class_loss: 1.2806 - val_bb_acc: 0.7974 - val_class_acc: 0.6136
# Epoch 5/5
# 3777/3777 [==============================] - 34s - loss: 1.9505 - bb_loss: 1485.8279 - class_loss: 0.4646 - bb_acc: 0.7903 - class_acc: 0.9216 - val_loss: 0.9171 - val_bb_loss: 869.3490 - val_class_loss: 0.0477 - val_bb_acc: 0.8191 - val_class_acc: 0.9855
# Train on 3777 samples, validate on 691 samples
# Epoch 1/2
# 3777/3777 [==============================] - 34s - loss: 1.3666 - bb_loss: 1308.6682 - class_loss: 0.0579 - bb_acc: 0.7935 - class_acc: 0.9844 - val_loss: 0.9163 - val_bb_loss: 780.3922 - val_class_loss: 0.1359 - val_bb_acc: 0.8394 - val_class_acc: 0.9551
# Epoch 2/2
# 3777/3777 [==============================] - 34s - loss: 1.0090 - bb_loss: 978.2413 - class_loss: 0.0308 - bb_acc: 0.8059 - class_acc: 0.9910 - val_loss: 0.9917 - val_bb_loss: 879.3558 - val_class_loss: 0.1123 - val_bb_acc: 0.8321 - val_class_acc: 0.9696
# Train on 3777 samples, validate on 691 samples
# Epoch 1/1
# 3777/3777 [==============================] - 34s - loss: 0.9481 - bb_loss: 940.2143 - class_loss: 0.0079 - bb_acc: 0.8020 - class_acc: 0.9987 - val_loss: 0.9083 - val_bb_loss: 761.7664 - val_class_loss: 0.1466 - val_bb_acc: 0.8162 - val_class_acc: 0.9479
# [2017-02-19 19:44:59.664175] INFO: Logbook: Bagged Validation Logloss 0.041
# [2017-02-19 19:44:59.665157] INFO: Logbook: Bagged Validation Accuracy 1.000
# Train on 3777 samples, validate on 691 samples
# Epoch 1/1
# 3777/3777 [==============================] - 48s - loss: 0.9537 - bb_loss: 926.2241 - class_loss: 0.0274 - bb_acc: 0.8038 - class_acc: 0.9923 - val_loss: 0.4848 - val_bb_loss: 466.4601 - val_class_loss: 0.0183 - val_bb_acc: 0.8509 - val_class_acc: 0.9942
# [2017-02-19 19:45:53.862427] INFO: Logbook: Bagged Validation Logloss 0.040
# [2017-02-19 19:45:53.863242] INFO: Logbook: Bagged Validation Accuracy 1.000
# Train on 3777 samples, validate on 691 samples
# Epoch 1/1
# 3777/3777 [==============================] - 33s - loss: 0.9704 - bb_loss: 918.1407 - class_loss: 0.0523 - bb_acc: 0.8054 - class_acc: 0.9831 - val_loss: 8.7924 - val_bb_loss: 3197.1849 - val_class_loss: 5.5953 - val_bb_acc: 0.6860 - val_class_acc: 0.2865
# [2017-02-19 19:46:33.602216] INFO: Logbook: Bagged Validation Logloss 0.050
# [2017-02-19 19:46:33.603039] INFO: Logbook: Bagged Validation Accuracy 1.000
# Train on 3777 samples, validate on 691 samples
# Epoch 1/1
# 3777/3777 [==============================] - 33s - loss: 1.3402 - bb_loss: 1059.0227 - class_loss: 0.2811 - bb_acc: 0.7938 - class_acc: 0.9380 - val_loss: 0.5099 - val_bb_loss: 445.0089 - val_class_loss: 0.0649 - val_bb_acc: 0.8596 - val_class_acc: 0.9899
# [2017-02-19 19:47:13.411684] INFO: Logbook: Bagged Validation Logloss 0.050
# [2017-02-19 19:47:13.412471] INFO: Logbook: Bagged Validation Accuracy 1.000
# Train on 3777 samples, validate on 691 samples
# Epoch 1/1
# 3777/3777 [==============================] - 34s - loss: 0.7901 - bb_loss: 770.1951 - class_loss: 0.0200 - bb_acc: 0.8001 - class_acc: 0.9934 - val_loss: 0.2680 - val_bb_loss: 236.8112 - val_class_loss: 0.0312 - val_bb_acc: 0.8321 - val_class_acc: 0.9913
# [2017-02-19 19:47:53.365434] INFO: Logbook: Bagged Validation Logloss 0.049
# [2017-02-19 19:47:53.366307] INFO: Logbook: Bagged Validation Accuracy 1.000
# Train on 3777 samples, validate on 691 samples
# Epoch 1/1
# 3777/3777 [==============================] - 34s - loss: 0.6915 - bb_loss: 684.4784 - class_loss: 0.0070 - bb_acc: 0.8157 - class_acc: 0.9981 - val_loss: 0.2819 - val_bb_loss: 270.2533 - val_class_loss: 0.0116 - val_bb_acc: 0.8495 - val_class_acc: 0.9986
# [2017-02-19 19:48:33.426995] INFO: Logbook: Bagged Validation Logloss 0.049
# [2017-02-19 19:48:33.427779] INFO: Logbook: Bagged Validation Accuracy 1.000
# Train on 3777 samples, validate on 691 samples
# Epoch 1/1
# 3777/3777 [==============================] - 34s - loss: 0.6493 - bb_loss: 644.4131 - class_loss: 0.0049 - bb_acc: 0.8059 - class_acc: 0.9992 - val_loss: 0.2460 - val_bb_loss: 238.9978 - val_class_loss: 0.0070 - val_bb_acc: 0.8915 - val_class_acc: 0.9986
# [2017-02-19 19:49:13.668379] INFO: Logbook: Bagged Validation Logloss 0.048
# [2017-02-19 19:49:13.669152] INFO: Logbook: Bagged Validation Accuracy 1.000
# Train on 3777 samples, validate on 691 samples
# Epoch 1/1
# 3777/3777 [==============================] - 35s - loss: 0.7040 - bb_loss: 695.5843 - class_loss: 0.0084 - bb_acc: 0.8115 - class_acc: 0.9979 - val_loss: 0.4289 - val_bb_loss: 202.6570 - val_class_loss: 0.2263 - val_bb_acc: 0.8567 - val_class_acc: 0.9247
# [2017-02-19 19:49:58.818154] INFO: Logbook: Bagged Validation Logloss 0.049
# [2017-02-19 19:49:58.819340] INFO: Logbook: Bagged Validation Accuracy 1.000

# %%
val = get_data(path+'valid', load_size)
pval_bbox = model[0].predict(conv_val_feat, batch_size=batch_size)[0]
# Out:
# Found 691 images belonging to 8 classes.

# %%
def create_rect(bb, color='red'):
    return plt.Rectangle((bb[2], bb[3]), bb[1], bb[0], color=color, fill=False, lw=3)

def show_bb(i):
    bb = val_bbox[i]
    pbb = pval_bbox[i]
    plot(val[i])
    plt.gca().add_patch(create_rect(bb, color='red'))
    plt.gca().add_patch(create_rect(pbb, color='yellow'))

show_bb(350)

# %%
# metrics.log_loss(val_labels, do_clip(sum(pvalsls)/len(pvalsls), .9999))
preds = sum(predsls)/len(predsls)
subm = do_clip(preds, clip)

if full:
    subm_name = path+'results/subm_full_conv_' + timestr + 'B.csv' #'.csv.gz'
else:
    subm_name = path+'results/subm_part_conv_' + timestr + 'B.csv' #'.csv.gz'

classes = ['ALB', 'BET', 'DOL', 'LAG', 'NoF', 'OTHER', 'SHARK', 'YFT']
submission = pd.DataFrame(subm, columns=classes)
submission.insert(0, 'image', raw_test_filenames)
submission.to_csv(subm_name, index=False)#, compression='gzip')
log.info('Done - files @ ' + subm_name)
# Out:
# [2017-02-19 19:51:12.550922] INFO: Logbook: Done - files @ ../data/fish/results/subm_full_conv_20170219B.csv

# %%
FileLink(subm_name)
# Out:
# /home/ubuntu/fish/data/fish/results/subm_full_conv_20170219B.csv
