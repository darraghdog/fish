# %%
# Read in Libraries
from __future__ import division, print_function
from logbook import Logger, StreamHandler
import sys
StreamHandler(sys.stdout).push_application()
log = Logger('Logbook')
import shutil, csv, time
timestr = time.strftime("%Y%m%d")
import ujson as json
import utils; reload(utils)
from utils import *
import gc
# from __future__ import division, print_function
from theano.sandbox import cuda
from vgg16bn import Vgg16BN
from sklearn import metrics
from distutils.dir_util import copy_tree
import glob
# %matplotlib inline

def accuracyfunc(y_act, y_pred):
    return metrics.accuracy_score(np.argmax(y_act, axis=1), np.argmax(y_pred, axis=1))
    
def refresh_directory_structure(name, sub_dirs):
    gdir = os.path.join(path, name)
    if os.path.exists(gdir):
        shutil.rmtree(gdir)
    os.makedirs(gdir)
    for sub_dir in sub_dirs:
        os.makedirs(os.path.join(gdir, sub_dir))
# Out:
# Using gpu device 0: Tesla K80 (CNMeM is disabled, cuDNN 5103)
# /home/ubuntu/anaconda2/lib/python2.7/site-packages/theano/sandbox/cuda/__init__.py:600: UserWarning: Your cuDNN version is more recent than the one Theano officially supports. If you see any problems, try updating Theano or downgrading cuDNN to version 5.
#   warnings.warn(warn)
# Using Theano backend.

# %%
os.getcwd()
# Out:
# '/home/ubuntu/fish/scripts'

# %%
# Set Parameters and check files
refresh_directories = False
input_exists = False
full = True
log.info('Set Paramters')
path = "../data/fish/"
batch_size=32
clip = 0.99
bags = 10
load_size = (400, 700)#(440, 780)#(360, 640)
yolo_cutoff = 0.7
sub_cutoff = 0.85
# Out:
# [2017-03-20 23:12:01.226060] INFO: Logbook: Set Paramters

# %%
# Create the test and valid directory
if refresh_directories:
    log.info('Create directory structure and validation files')
    sub_dirs = os.listdir(os.path.join(path, 'train-all'))
    if '.DS_Store' in sub_dirs: sub_dirs.remove('.DS_Store')
    refresh_directory_structure('pseudo/train', sub_dirs)
    refresh_directory_structure('pseudo/valid', sub_dirs)
    refresh_directory_structure('pseudo/test', ['test'])
    for c,row in enumerate(csv.DictReader(open('../image_validation_set.csv'))):
        value = 'pseudo/valid' if row['Validation'] == '1' else 'pseudo/train'
        name_from = os.path.join(path, 'train-all', row['SubDirectory'], row['file_name'])
        name_to   = os.path.join(path, value, row['SubDirectory'], row['file_name'])
        shutil.copyfile(name_from, name_to)   
    copy_tree(os.path.join(path, 'test'), os.path.join(path, 'pseudo/test'))

# %%
# Use our best some to idenify high confidence test images
best_sub = pd.read_csv("../best_sub.csv")
hiconf_test = best_sub[best_sub.drop(['image'], axis=1).apply(np.max, axis=1)>sub_cutoff].reset_index(drop=True)
hiconf_test['class'] = hiconf_test.drop(['image'], axis=1).idxmax(axis = 1)
hiconf_test.head(3)
# Out:
#            image       ALB       BET       DOL       LAG       NoF     OTHER  \
# 0  img_00007.jpg  0.073193  0.030304  0.007515  0.007025  0.001001  0.002952
# 1  img_00053.jpg  0.885459  0.018413  0.011608  0.004756  0.001013  0.061516
# 2  img_00071.jpg  0.067176  0.006945  0.003022  0.910044  0.001001  0.005329
#
#       SHARK       YFT class
# 0  0.002951  0.875060   YFT
# 1  0.003243  0.013992   ALB
# 2  0.002918  0.003566   LAG

# %%
# Now we read in our high confidence boundary boxes. 
# Load up YOLO bounding boxes for each class
all_files = glob.glob(os.path.join('../yolo_coords', "*.txt"))
allFiles = [f for f in all_files if 'FISH' in f]
frame = pd.DataFrame()
list_ = []
for file_ in allFiles:
    df = pd.read_csv(file_,index_col=None, header=None, sep = " ", names = ['image', 'proba', 'x0', 'y0', 'x1', 'y1'])
    df['class'] = file_.split('_')[-1].split('.')[0]
    list_.append(df)
yolo_frame = pd.concat(list_)
yolo_frame = yolo_frame[yolo_frame['proba']>yolo_cutoff].sort(['image'])
# Just keep the highest confidence one
yolo_frame = yolo_frame.loc[yolo_frame.groupby(['image'])['proba'].idxmax()].reset_index(drop=True)
yolo_frame['image'] = yolo_frame['image'] + '.jpg'
yolo_frame[:3]
# Out:
# /home/ubuntu/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:12: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
#            image     proba          x0          y0           x1          y1  \
# 0  img_00007.jpg  0.895428  740.284363  264.430939  1153.247192  521.133301
# 1  img_00009.jpg  0.864695  607.911011   96.096519   929.203857  213.035217
# 2  img_00018.jpg  0.886466  651.871094  118.684822  1016.892090  220.451233
#
#   class
# 0  FISH
# 1  FISH
# 2  FISH

# %%
# Get the innder join of each as we need the labels and the boundary box
yolo_frame = yolo_frame[yolo_frame['image'].isin(hiconf_test['image'].tolist())].reset_index(drop=True)
hiconf_test = hiconf_test[(hiconf_test['image'].isin(yolo_frame['image'].tolist())) | (hiconf_test['class']=='NoF')].reset_index(drop=True)
hiconf_test.shape, yolo_frame.shape
# Out:
# ((459, 10), (360, 7))

# %%
# Now we do pseudo labelling by copying test images to pseudo/train data set
for i in range(len(hiconf_test)):
    row = hiconf_test.iloc[i].values.tolist()
    img = row[0]
    img_class = row[9]
    name_from = os.path.join(path, 'test', 'test', img)
    name_to   = os.path.join(path, 'pseudo/train', img_class, img)
    shutil.copyfile(name_from, name_to) 
    #print (img, img_class)

# %%
# Read in our VGG pretrained model
log.info('Get VGG')
model = vgg_ft_bn(8)

# Create our VGG model
log.info('Create VGG')
vgg640 = Vgg16BN(load_size).model
vgg640.pop()
vgg640.input_shape, vgg640.output_shape
vgg640.compile(Adam(), 'categorical_crossentropy', metrics=['accuracy'])

# get labels
(val_classes, trn_classes, val_labels, trn_labels,
    val_filenames, filenames, test_filenames) = get_classes(path+ 'pseudo/')

# Read in filenames
log.info('Read filenames')
raw_filenames = [f.split('/')[-1] for f in filenames]
raw_test_filenames = [f.split('/')[-1] for f in test_filenames]
raw_val_filenames = [f.split('/')[-1] for f in val_filenames]
# Out:
# [2017-03-20 23:12:16.771400] INFO: Logbook: Get VGG
# /home/ubuntu/anaconda2/lib/python2.7/site-packages/keras/layers/core.py:622: UserWarning: `output_shape` argument not specified for layer lambda_1 and cannot be automatically inferred with the Theano backend. Defaulting to output shape `(None, 3, 224, 224)` (same as input shape). If the expected output shape is different, specify it via the `output_shape` argument.
#   .format(self.name, input_shape))
# [2017-03-20 23:12:19.869404] INFO: Logbook: Create VGG
# /home/ubuntu/anaconda2/lib/python2.7/site-packages/keras/layers/core.py:622: UserWarning: `output_shape` argument not specified for layer lambda_2 and cannot be automatically inferred with the Theano backend. Defaulting to output shape `(None, 3, 400, 700)` (same as input shape). If the expected output shape is different, specify it via the `output_shape` argument.
#   .format(self.name, input_shape))
# Found 3545 images belonging to 8 classes.
# Found 691 images belonging to 8 classes.
# Found 1000 images belonging to 1 classes.
# [2017-03-20 23:12:20.388830] INFO: Logbook: Read filenames

# %%
# Read in the boxes
anno_classes = ['alb', 'bet', 'dol', 'lag', 'other', 'shark', 'yft']
bb_json = {}
for c in anno_classes:
    j = json.load(open(os.path.join(path, 'box/{}_labels.json'.format(c)), 'r'))
    for l in j:
        if 'annotations' in l.keys() and len(l['annotations'])>0:
            bb_json[l['filename'].split('/')[-1]] = sorted(
                l['annotations'], key=lambda x: x['height']*x['width'])[-1]

# %%
yolo_frame[:3]
# Out:
#            image     proba          x0          y0           x1          y1  \
# 0  img_00007.jpg  0.895428  740.284363  264.430939  1153.247192  521.133301
# 1  img_00053.jpg  0.851613  485.583313  540.210205   675.545349  718.030029
# 2  img_00071.jpg  0.822174  802.048096  210.676193  1054.677979  627.320862
#
#   class
# 0  FISH
# 1  FISH
# 2  FISH

# %%
for i in range(len(yolo_frame)):
    row = yolo_frame.iloc[i].values.tolist()
    image, x, y, width, height = row[0], row[2], row[3], row[4]-row[2], row[5]-row[3]
    bb_json[image] = {}
    bb_json[image]['class'] = 'rect'
    bb_json[image]['x'] = x
    bb_json[image]['y'] = y
    bb_json[image]['height'] = height
    bb_json[image]['width'] = width

# %%
# make it easy to find the nof dots, by putting themin the middle
#empty_bbox = {'height': 0., 'width': 0., 'x': 1280/2., 'y': 720/2}
empty_bbox = {'height': 0., 'width': 0., 'x': 0., 'y': 0.}

for f in raw_filenames:
    if not f in bb_json.keys(): bb_json[f] = empty_bbox
for f in raw_val_filenames:
    if not f in bb_json.keys(): bb_json[f] = empty_bbox

# %%
# Finally, we convert the dictionary into an array, and convert the coordinates to our resized 224x224 images.
bb_params = ['height', 'width', 'x', 'y']
def convert_bb(bb, size):
    bb = [bb[p] for p in bb_params]
    conv_x = (load_size[1] / size[0])#(224. / size[0])
    conv_y = (load_size[0] / size[1])#(224. / size[1])
    bb[0] = bb[0]*conv_y
    bb[1] = bb[1]*conv_x
    bb[2] = max(bb[2]*conv_x, 0)
    bb[3] = max(bb[3]*conv_y, 0)
    return bb

# %%
trn_sizes = [PIL.Image.open(path+'pseudo/train/'+f).size for f in filenames]
val_sizes = [PIL.Image.open(path+'pseudo/valid/'+f).size for f in val_filenames]
tst_sizes = [PIL.Image.open(path+'pseudo/test/'+f).size for f in test_filenames]

# %%
trn_bbox = np.stack([convert_bb(bb_json[f], s) for f,s in zip(raw_filenames, trn_sizes)], 
                   ).astype(np.float32)
val_bbox = np.stack([convert_bb(bb_json[f], s) 
                   for f,s in zip(raw_val_filenames, val_sizes)]).astype(np.float32)

# %%
def create_rect(bb, color='red'):
    return plt.Rectangle((bb[2], bb[3]), bb[1], bb[0], color=color, fill=False, lw=3)

def show_bb(i):
    bb = trn_bbox[i]
    plot(trn[i])
    plt.gca().add_patch(create_rect(bb))

#trn = get_data(path+'pseudo/train', load_size)
#show_bb(1628)
#del trn
#gc.collect()

# %%
log.info('Read in data')
if not input_exists:

    batches = get_batches(path+'pseudo/train', batch_size=batch_size)
    val_batches = get_batches(path+'pseudo/valid', batch_size=batch_size*2, shuffle=False)
    (val_classes, trn_classes, val_labels, trn_labels, 
        val_filenames, filenames, test_filenames) = get_classes(path+ 'pseudo/')
    
    # Fetch our large images 
    # Precompute the output of the convolutional part of VGG
    log.info('Fetch images')
    log.info('Get VGG output')
    log.info('Write VGG output')
    
    val = get_data(path+'pseudo/valid', load_size)
    conv_val_feat = vgg640.predict(val, batch_size=16, verbose=1)
    save_array(path+'results/conv_val_pseudo_feat.dat', conv_val_feat)
    del val, conv_val_feat
    gc.collect()
    
    trn = get_data(path+'pseudo/train', load_size)
    conv_trn_feat = vgg640.predict(trn, batch_size=16, verbose=1)    
    del trn
    gc.collect()
    save_array(path+'results/conv_trn_pseudo_feat.dat', conv_trn_feat) 
    del conv_trn_feat
    gc.collect()
    
    test = get_data(path+'pseudo/test', load_size)
    conv_test_feat = vgg640.predict(test, batch_size=16, verbose=1)
    save_array(path+'results/conv_test_pseudo_feat.dat', conv_test_feat)     
    del test, conv_test_feat
    gc.collect()

    # For memory purposes delete out the original train and validation
    log.info('Clear up memory')
    #del trn, val, test
    gc.collect()
    gc.collect()
# Out:
# [2017-03-20 23:12:22.875238] INFO: Logbook: Read in data
# Found 3545 images belonging to 8 classes.
# Found 691 images belonging to 8 classes.
# Found 3545 images belonging to 8 classes.
# Found 691 images belonging to 8 classes.
# Found 1000 images belonging to 1 classes.
# [2017-03-20 23:12:23.160643] INFO: Logbook: Fetch images
# [2017-03-20 23:12:23.161229] INFO: Logbook: Get VGG output
# [2017-03-20 23:12:23.161839] INFO: Logbook: Write VGG output
# Found 691 images belonging to 8 classes.
# 691/691 [==============================] - 101s
# Found 3545 images belonging to 8 classes.
# 3545/3545 [==============================] - 522s
# Found 1000 images belonging to 1 classes.
# 1000/1000 [==============================] - 147s
# [2017-03-20 23:30:47.389601] INFO: Logbook: Clear up memory

# %%
gc.collect()
conv_val_feat = load_array(path+'results/conv_val_pseudo_feat.dat')
conv_trn_feat = load_array(path+'results/conv_trn_pseudo_feat.dat') 
conv_test_feat = load_array(path+'results/conv_test_pseudo_feat.dat')

# %%
if full:
    conv_trn_feat = np.concatenate([conv_trn_feat, conv_val_feat])
    trn_labels = np.concatenate([trn_labels, val_labels]) 
    trn_bbox = np.concatenate([trn_bbox, val_bbox])
    
# Our Convolutional Net Architecture
log.info('Create and fit CNN')
p=0.6
# Set up the fully convolutional net (FCN); 
conv_layers,_ = split_at(vgg640, Convolution2D)
nf=128; p=0. # No dropout
# Out:
# [2017-03-20 23:30:59.743221] INFO: Logbook: Create and fit CNN

# %%
gc.collect()
nf = 512
p  = 0.3
def create_model():
    inp = Input(conv_layers[-1].output_shape[1:])
    x = MaxPooling2D()(inp)
    x = ZeroPadding2D((1,1))(x)
    x = Convolution2D(nf,3,3, activation='relu', border_mode='same')(x)
    x =   Dropout(p)(x)
    x = BatchNormalization(axis=1)(x)
    #x = MaxPooling2D()(x)
    #x = ZeroPadding2D((1,1))(x)
    #x = Convolution2D(nf,3,3, activation='relu', border_mode='same')(x)
    #x =   Dropout(p)(x)
    #x = BatchNormalization(axis=1)(x)
    x = MaxPooling2D()(x)
    x = ZeroPadding2D((1,1))(x)
    x = Convolution2D(nf,3,3, activation='relu', border_mode='same')(x)
    x =   Dropout(p)(x)
    x = BatchNormalization(axis=1)(x)
    x1 =   MaxPooling2D()(x)
    x1 =   Convolution2D(8,3,3, border_mode='same')(x1)
    x1 =   Dropout(p/2)(x1)
    x1 =   GlobalAveragePooling2D()(x1)
    x = Dropout(p/2)(x)
    x = Flatten()(x)
    x = Dense(1024, activation='relu')(x)
    x = BatchNormalization()(x)
    x = Dropout(p/2)(x)
    x = Dense(1024, activation='relu')(x)
    x = BatchNormalization()(x)
    x = Dropout(p/2)(x)
    x_bb = Dense(4, name='bb')(x)
    x_class = Dense(8, activation='softmax', name='class')(x1)
    return inp, x_bb, x_class

## Set up the fully convolutional net (FCN); 
#conv_layers,_ = split_at(vgg640, Convolution2D)
#nf=128; p=0. # No dropout

model = []
predsls = []
pvalsls = []

for ii in range(bags):
    inp, x_bb, x_class = create_model()
    model.append(Model([inp], [x_bb, x_class]))
    #model.summary()
    model[ii].compile(Adam(lr=1e-3), loss=['mse', 'categorical_crossentropy'], metrics=['accuracy'],
                 loss_weights=[.001, 1.])
    model[ii].fit(conv_trn_feat, [trn_bbox, trn_labels], batch_size=batch_size, nb_epoch=5, 
                 validation_data=(conv_val_feat, [val_bbox, val_labels]))
    model[ii].optimizer.lr = 1e-4
    model[ii].optimizer.loss_weights=[.00001, 1.]
    model[ii].fit(conv_trn_feat, [trn_bbox, trn_labels], batch_size=batch_size, nb_epoch=2, 
                 validation_data=(conv_val_feat, [val_bbox, val_labels]))
    model[ii].optimizer.lr = 1e-5

    count = 0
    while count < 8:
        model[ii].fit(conv_trn_feat, [trn_bbox, trn_labels], batch_size=batch_size, nb_epoch=1, 
                     validation_data=(conv_val_feat, [val_bbox, val_labels]))
        predsls.append(model[ii].predict(conv_test_feat, batch_size=batch_size)[1]) # or try 32 batch_size
        pvalsls.append(model[ii].predict(conv_val_feat, batch_size=batch_size)[1])
        val_score = "%.3f" % metrics.log_loss(val_labels, sum(pvalsls)/len(pvalsls))
        acc_score = "%.3f" % accuracyfunc(val_labels, do_clip(sum(pvalsls)/len(pvalsls), clip))
        log.info('Bagged Validation Logloss ' + str(val_score))
        log.info('Bagged Validation Accuracy ' + str(acc_score))
        count += 1
# Out:
# Train on 4236 samples, validate on 691 samples
# Epoch 1/5
# 4236/4236 [==============================] - 28s - loss: 27.1946 - bb_loss: 26101.8513 - class_loss: 1.0927 - bb_acc: 0.6346 - class_acc: 0.7290 - val_loss: 23.0485 - val_bb_loss: 22441.4590 - val_class_loss: 0.6070 - val_bb_acc: 0.7873 - val_class_acc: 0.7583
# Epoch 2/5
# 4236/4236 [==============================] - 28s - loss: 15.3513 - bb_loss: 15101.6123 - class_loss: 0.2497 - bb_acc: 0.7172 - class_acc: 0.9304 - val_loss: 8.6335 - val_bb_loss: 8271.0197 - val_class_loss: 0.3625 - val_bb_acc: 0.7525 - val_class_acc: 0.8741
# Epoch 3/5
# 4236/4236 [==============================] - 28s - loss: 4.6862 - bb_loss: 4575.9370 - class_loss: 0.1103 - bb_acc: 0.7882 - class_acc: 0.9686 - val_loss: 2.1128 - val_bb_loss: 1971.6980 - val_class_loss: 0.1411 - val_bb_acc: 0.7931 - val_class_acc: 0.9580
# Epoch 4/5
# 4236/4236 [==============================] - 28s - loss: 1.5475 - bb_loss: 1484.1334 - class_loss: 0.0634 - bb_acc: 0.7975 - class_acc: 0.9806 - val_loss: 1.1717 - val_bb_loss: 853.2238 - val_class_loss: 0.3185 - val_bb_acc: 0.7815 - val_class_acc: 0.8973
# Epoch 5/5
# 4236/4236 [==============================] - 28s - loss: 1.1542 - bb_loss: 1108.0410 - class_loss: 0.0461 - bb_acc: 0.7835 - class_acc: 0.9877 - val_loss: 0.6979 - val_bb_loss: 649.0310 - val_class_loss: 0.0489 - val_bb_acc: 0.8249 - val_class_acc: 0.9884
# Train on 4236 samples, validate on 691 samples
# Epoch 1/2
# 4236/4236 [==============================] - 28s - loss: 0.9347 - bb_loss: 893.5113 - class_loss: 0.0412 - bb_acc: 0.7963 - class_acc: 0.9837 - val_loss: 0.4668 - val_bb_loss: 420.3135 - val_class_loss: 0.0465 - val_bb_acc: 0.8278 - val_class_acc: 0.9855
# Epoch 2/2
# 4236/4236 [==============================] - 28s - loss: 0.7873 - bb_loss: 751.9707 - class_loss: 0.0354 - bb_acc: 0.7901 - class_acc: 0.9889 - val_loss: 0.4725 - val_bb_loss: 388.5460 - val_class_loss: 0.0839 - val_bb_acc: 0.7974 - val_class_acc: 0.9725
# Train on 4236 samples, validate on 691 samples
# Epoch 1/1
# 4236/4236 [==============================] - 28s - loss: 0.7734 - bb_loss: 747.1253 - class_loss: 0.0263 - bb_acc: 0.7975 - class_acc: 0.9950 - val_loss: 0.4414 - val_bb_loss: 351.7090 - val_class_loss: 0.0897 - val_bb_acc: 0.8466 - val_class_acc: 0.9913
# [2017-03-20 23:36:17.127178] INFO: Logbook: Bagged Validation Logloss 0.102
# [2017-03-20 23:36:17.128031] INFO: Logbook: Bagged Validation Accuracy 0.991
# Train on 4236 samples, validate on 691 samples
# Epoch 1/1
# 4236/4236 [==============================] - 28s - loss: 0.7539 - bb_loss: 688.6909 - class_loss: 0.0652 - bb_acc: 0.7982 - class_acc: 0.9861 - val_loss: 0.3139 - val_bb_loss: 221.9196 - val_class_loss: 0.0920 - val_bb_acc: 0.8452 - val_class_acc: 0.9899
# [2017-03-20 23:36:50.489446] INFO: Logbook: Bagged Validation Logloss 0.098
# [2017-03-20 23:36:50.490220] INFO: Logbook: Bagged Validation Accuracy 0.993
# Train on 4236 samples, validate on 691 samples
# Epoch 1/1
# 4236/4236 [==============================] - 28s - loss: 0.6337 - bb_loss: 600.8760 - class_loss: 0.0328 - bb_acc: 0.7975 - class_acc: 0.9924 - val_loss: 0.2631 - val_bb_loss: 224.9165 - val_class_loss: 0.0382 - val_bb_acc: 0.8495 - val_class_acc: 0.9855
# [2017-03-20 23:37:23.857821] INFO: Logbook: Bagged Validation Logloss 0.025
# [2017-03-20 23:37:23.858634] INFO: Logbook: Bagged Validation Accuracy 0.996
# Train on 4236 samples, validate on 691 samples
# Epoch 1/1
# 4236/4236 [==============================] - 29s - loss: 0.6134 - bb_loss: 599.6384 - class_loss: 0.0138 - bb_acc: 0.8036 - class_acc: 0.9965 - val_loss: 0.2056 - val_bb_loss: 198.4497 - val_class_loss: 0.0071 - val_bb_acc: 0.8495 - val_class_acc: 0.9971
# [2017-03-20 23:37:57.448569] INFO: Logbook: Bagged Validation Logloss 0.019
# [2017-03-20 23:37:57.449344] INFO: Logbook: Bagged Validation Accuracy 0.996
# Train on 4236 samples, validate on 691 samples
# Epoch 1/1
# 4236/4236 [==============================] - 28s - loss: 0.5813 - bb_loss: 574.5943 - class_loss: 0.0067 - bb_acc: 0.8008 - class_acc: 0.9974 - val_loss: 0.1919 - val_bb_loss: 180.0356 - val_class_loss: 0.0119 - val_bb_acc: 0.9175 - val_class_acc: 1.0000
# [2017-03-20 23:38:30.806444] INFO: Logbook: Bagged Validation Logloss 0.017
# [2017-03-20 23:38:30.807236] INFO: Logbook: Bagged Validation Accuracy 1.000
# Train on 4236 samples, validate on 691 samples
# Epoch 1/1
# 4236/4236 [==============================] - 28s - loss: 0.5323 - bb_loss: 528.7347 - class_loss: 0.0035 - bb_acc: 0.8012 - class_acc: 0.9988 - val_loss: 0.2086 - val_bb_loss: 199.0963 - val_class_loss: 0.0095 - val_bb_acc: 0.8886 - val_class_acc: 0.9986
# [2017-03-20 23:39:04.197768] INFO: Logbook: Bagged Validation Logloss 0.015
# [2017-03-20 23:39:04.198597] INFO: Logbook: Bagged Validation Accuracy 1.000
# Train on 4236 samples, validate on 691 samples
# Epoch 1/1
# 4236/4236 [==============================] - 28s - loss: 0.5324 - bb_loss: 522.3084 - class_loss: 0.0101 - bb_acc: 0.8116 - class_acc: 0.9962 - val_loss: 0.1216 - val_bb_loss: 118.9294 - val_class_loss: 0.0026 - val_bb_acc: 0.8871 - val_class_acc: 1.0000
# [2017-03-20 23:39:37.522910] INFO: Logbook: Bagged Validation Logloss 0.013
# [2017-03-20 23:39:37.523711] INFO: Logbook: Bagged Validation Accuracy 1.000
# Train on 4236 samples, validate on 691 samples
# Epoch 1/1
# 4236/4236 [==============================] - 28s - loss: 0.5440 - bb_loss: 522.7417 - class_loss: 0.0213 - bb_acc: 0.7967 - class_acc: 0.9941 - val_loss: 0.2054 - val_bb_loss: 164.5152 - val_class_loss: 0.0409 - val_bb_acc: 0.8582 - val_class_acc: 0.9899
# [2017-03-20 23:40:10.902370] INFO: Logbook: Bagged Validation Logloss 0.014
# [2017-03-20 23:40:10.903174] INFO: Logbook: Bagged Validation Accuracy 1.000
# Train on 4236 samples, validate on 691 samples
# Epoch 1/5
# 4236/4236 [==============================] - 28s - loss: 26.9550 - bb_loss: 25965.3209 - class_loss: 0.9897 - bb_acc: 0.6537 - class_acc: 0.7252 - val_loss: 20.3688 - val_bb_loss: 20023.5538 - val_class_loss: 0.3453 - val_bb_acc: 0.7742 - val_class_acc: 0.9001
# Epoch 2/5
# 4236/4236 [==============================] - 28s - loss: 15.1311 - bb_loss: 14914.2092 - class_loss: 0.2169 - bb_acc: 0.7273 - class_acc: 0.9393 - val_loss: 8.8880 - val_bb_loss: 8308.5314 - val_class_loss: 0.5795 - val_bb_acc: 0.7771 - val_class_acc: 0.8683
# Epoch 3/5
# 4236/4236 [==============================] - 28s - loss: 4.7258 - bb_loss: 4581.7300 - class_loss: 0.1440 - bb_acc: 0.7814 - class_acc: 0.9570 - val_loss: 1.6462 - val_bb_loss: 1539.7342 - val_class_loss: 0.1065 - val_bb_acc: 0.8625 - val_class_acc: 0.9768
# Epoch 4/5
# 4236/4236 [==============================] - 28s - loss: 1.5695 - bb_loss: 1502.6544 - class_loss: 0.0668 - bb_acc: 0.7911 - class_acc: 0.9804 - val_loss: 0.7593 - val_bb_loss: 671.7093 - val_class_loss: 0.0876 - val_bb_acc: 0.8423 - val_class_acc: 0.9797
# Epoch 5/5
# 4236/4236 [==============================] - 28s - loss: 0.9414 - bb_loss: 913.5889 - class_loss: 0.0279 - bb_acc: 0.7915 - class_acc: 0.9920 - val_loss: 0.7493 - val_bb_loss: 688.2709 - val_class_loss: 0.0610 - val_bb_acc: 0.8423 - val_class_acc: 0.9826
# Train on 4236 samples, validate on 691 samples
# Epoch 1/2
# 4236/4236 [==============================] - 28s - loss: 0.8838 - bb_loss: 836.9666 - class_loss: 0.0468 - bb_acc: 0.7923 - class_acc: 0.9873 - val_loss: 0.5001 - val_bb_loss: 435.8461 - val_class_loss: 0.0643 - val_bb_acc: 0.7829 - val_class_acc: 0.9841
# Epoch 2/2
# 4236/4236 [==============================] - 28s - loss: 0.9415 - bb_loss: 884.3470 - class_loss: 0.0572 - bb_acc: 0.7795 - class_acc: 0.9832 - val_loss: 0.5939 - val_bb_loss: 572.3443 - val_class_loss: 0.0216 - val_bb_acc: 0.9001 - val_class_acc: 0.9957
# Train on 4236 samples, validate on 691 samples
# Epoch 1/1
# 4236/4236 [==============================] - 28s - loss: 0.7083 - bb_loss: 683.7213 - class_loss: 0.0245 - bb_acc: 0.8024 - class_acc: 0.9932 - val_loss: 0.3504 - val_bb_loss: 318.7866 - val_class_loss: 0.0316 - val_bb_acc: 0.8871 - val_class_acc: 0.9957
# [2017-03-20 23:44:25.588572] INFO: Logbook: Bagged Validation Logloss 0.013
# [2017-03-20 23:44:25.589392] INFO: Logbook: Bagged Validation Accuracy 1.000
# Train on 4236 samples, validate on 691 samples
# Epoch 1/1
# 4236/4236 [==============================] - 28s - loss: 0.6940 - bb_loss: 671.7937 - class_loss: 0.0222 - bb_acc: 0.8012 - class_acc: 0.9922 - val_loss: 0.3625 - val_bb_loss: 348.0684 - val_class_loss: 0.0144 - val_bb_acc: 0.8249 - val_class_acc: 0.9971
# [2017-03-20 23:44:59.017194] INFO: Logbook: Bagged Validation Logloss 0.013
# [2017-03-20 23:44:59.018154] INFO: Logbook: Bagged Validation Accuracy 1.000
# Train on 4236 samples, validate on 691 samples
# Epoch 1/1
# 4236/4236 [==============================] - 28s - loss: 0.6542 - bb_loss: 634.1805 - class_loss: 0.0201 - bb_acc: 0.7913 - class_acc: 0.9967 - val_loss: 0.2765 - val_bb_loss: 231.2159 - val_class_loss: 0.0453 - val_bb_acc: 0.8654 - val_class_acc: 0.9957
# [2017-03-20 23:45:32.502874] INFO: Logbook: Bagged Validation Logloss 0.013
# [2017-03-20 23:45:32.503619] INFO: Logbook: Bagged Validation Accuracy 1.000
# Train on 4236 samples, validate on 691 samples
# Epoch 1/1
# 4236/4236 [==============================] - 29s - loss: 0.5779 - bb_loss: 565.3844 - class_loss: 0.0125 - bb_acc: 0.8074 - class_acc: 0.9965 - val_loss: 0.1804 - val_bb_loss: 143.6015 - val_class_loss: 0.0368 - val_bb_acc: 0.8726 - val_class_acc: 0.9855
# [2017-03-20 23:46:06.161026] INFO: Logbook: Bagged Validation Logloss 0.014
# [2017-03-20 23:46:06.161807] INFO: Logbook: Bagged Validation Accuracy 1.000
# Train on 4236 samples, validate on 691 samples
# Epoch 1/1
# 4236/4236 [==============================] - 29s - loss: 0.5684 - bb_loss: 553.5094 - class_loss: 0.0149 - bb_acc: 0.8034 - class_acc: 0.9960 - val_loss: 0.1232 - val_bb_loss: 118.5390 - val_class_loss: 0.0046 - val_bb_acc: 0.8813 - val_class_acc: 1.0000
# [2017-03-20 23:46:39.860432] INFO: Logbook: Bagged Validation Logloss 0.013
# [2017-03-20 23:46:39.861228] INFO: Logbook: Bagged Validation Accuracy 1.000
# Train on 4236 samples, validate on 691 samples
# Epoch 1/1
# 4236/4236 [==============================] - 29s - loss: 0.5140 - bb_loss: 494.3515 - class_loss: 0.0196 - bb_acc: 0.8074 - class_acc: 0.9939 - val_loss: 0.2043 - val_bb_loss: 192.1312 - val_class_loss: 0.0122 - val_bb_acc: 0.8741 - val_class_acc: 0.9971
# [2017-03-20 23:47:13.459286] INFO: Logbook: Bagged Validation Logloss 0.013
# [2017-03-20 23:47:13.460061] INFO: Logbook: Bagged Validation Accuracy 1.000
# Train on 4236 samples, validate on 691 samples
# Epoch 1/1
# 4236/4236 [==============================] - 29s - loss: 0.5492 - bb_loss: 531.0395 - class_loss: 0.0182 - bb_acc: 0.8088 - class_acc: 0.9943 - val_loss: 0.1311 - val_bb_loss: 121.0591 - val_class_loss: 0.0101 - val_bb_acc: 0.8350 - val_class_acc: 0.9971
# [2017-03-20 23:47:47.145115] INFO: Logbook: Bagged Validation Logloss 0.012
# [2017-03-20 23:47:47.146016] INFO: Logbook: Bagged Validation Accuracy 1.000
# Train on 4236 samples, validate on 691 samples
# Epoch 1/1
# 4236/4236 [==============================] - 29s - loss: 0.5111 - bb_loss: 503.5754 - class_loss: 0.0075 - bb_acc: 0.8064 - class_acc: 0.9981 - val_loss: 0.0844 - val_bb_loss: 83.2826 - val_class_loss: 0.0011 - val_bb_acc: 0.8857 - val_class_acc: 1.0000
# [2017-03-20 23:48:20.947504] INFO: Logbook: Bagged Validation Logloss 0.011
# [2017-03-20 23:48:20.948299] INFO: Logbook: Bagged Validation Accuracy 1.000
# Train on 4236 samples, validate on 691 samples
# Epoch 1/5
# 4236/4236 [==============================] - 29s - loss: 27.3752 - bb_loss: 26087.3841 - class_loss: 1.2878 - bb_acc: 0.6520 - class_acc: 0.6919 - val_loss: 25.8072 - val_bb_loss: 25452.5445 - val_class_loss: 0.3547 - val_bb_acc: 0.7583 - val_class_acc: 0.9363
# Epoch 2/5
# 4236/4236 [==============================] - 28s - loss: 15.3246 - bb_loss: 15015.7472 - class_loss: 0.3088 - bb_acc: 0.7115 - class_acc: 0.9202 - val_loss: 9.5605 - val_bb_loss: 9307.9606 - val_class_loss: 0.2525 - val_bb_acc: 0.8061 - val_class_acc: 0.9334
# Epoch 3/5
# 4236/4236 [==============================] - 28s - loss: 4.7129 - bb_loss: 4593.5636 - class_loss: 0.1194 - bb_acc: 0.7743 - class_acc: 0.9681 - val_loss: 1.6979 - val_bb_loss: 1602.0540 - val_class_loss: 0.0958 - val_bb_acc: 0.8177 - val_class_acc: 0.9711
# Epoch 4/5
# 4236/4236 [==============================] - 28s - loss: 1.6471 - bb_loss: 1543.6673 - class_loss: 0.1034 - bb_acc: 0.7920 - class_acc: 0.9707 - val_loss: 0.8339 - val_bb_loss: 767.1255 - val_class_loss: 0.0667 - val_bb_acc: 0.8249 - val_class_acc: 0.9870
# Epoch 5/5
# 4236/4236 [==============================] - 28s - loss: 1.0780 - bb_loss: 1021.9757 - class_loss: 0.0560 - bb_acc: 0.7847 - class_acc: 0.9851 - val_loss: 0.8036 - val_bb_loss: 660.2624 - val_class_loss: 0.1433 - val_bb_acc: 0.8307 - val_class_acc: 0.9479
# Train on 4236 samples, validate on 691 samples
# Epoch 1/2
# 4236/4236 [==============================] - 28s - loss: 0.9748 - bb_loss: 916.8078 - class_loss: 0.0580 - bb_acc: 0.7904 - class_acc: 0.9844 - val_loss: 0.7955 - val_bb_loss: 679.2855 - val_class_loss: 0.1162 - val_bb_acc: 0.8292 - val_class_acc: 0.9884
# Epoch 2/2
# 4236/4236 [==============================] - 28s - loss: 0.8194 - bb_loss: 783.0196 - class_loss: 0.0364 - bb_acc: 0.7960 - class_acc: 0.9917 - val_loss: 0.4972 - val_bb_loss: 414.0207 - val_class_loss: 0.0832 - val_bb_acc: 0.8408 - val_class_acc: 0.9957
# Train on 4236 samples, validate on 691 samples
# Epoch 1/1
# 4236/4236 [==============================] - 28s - loss: 0.6905 - bb_loss: 656.6001 - class_loss: 0.0339 - bb_acc: 0.7970 - class_acc: 0.9924 - val_loss: 0.2860 - val_bb_loss: 267.3323 - val_class_loss: 0.0187 - val_bb_acc: 0.8480 - val_class_acc: 0.9971
# [2017-03-20 23:52:36.436771] INFO: Logbook: Bagged Validation Logloss 0.011
# [2017-03-20 23:52:36.437562] INFO: Logbook: Bagged Validation Accuracy 1.000
# Train on 4236 samples, validate on 691 samples
# Epoch 1/1
# 4236/4236 [==============================] - 28s - loss: 0.6500 - bb_loss: 641.0176 - class_loss: 0.0090 - bb_acc: 0.8005 - class_acc: 0.9969 - val_loss: 0.4085 - val_bb_loss: 402.8167 - val_class_loss: 0.0057 - val_bb_acc: 0.9450 - val_class_acc: 1.0000
# [2017-03-20 23:53:09.883371] INFO: Logbook: Bagged Validation Logloss 0.011
# [2017-03-20 23:53:09.884106] INFO: Logbook: Bagged Validation Accuracy 1.000
# Train on 4236 samples, validate on 691 samples
# Epoch 1/1
# 4236/4236 [==============================] - 28s - loss: 0.6117 - bb_loss: 571.8016 - class_loss: 0.0399 - bb_acc: 0.7993 - class_acc: 0.9889 - val_loss: 0.3361 - val_bb_loss: 266.9457 - val_class_loss: 0.0692 - val_bb_acc: 0.8394 - val_class_acc: 0.9826
# [2017-03-20 23:53:43.411646] INFO: Logbook: Bagged Validation Logloss 0.012
# [2017-03-20 23:53:43.412530] INFO: Logbook: Bagged Validation Accuracy 1.000
# Train on 4236 samples, validate on 691 samples
# Epoch 1/1
# 4236/4236 [==============================] - 28s - loss: 0.6534 - bb_loss: 609.5700 - class_loss: 0.0438 - bb_acc: 0.7939 - class_acc: 0.9887 - val_loss: 0.4296 - val_bb_loss: 403.3653 - val_class_loss: 0.0263 - val_bb_acc: 0.8524 - val_class_acc: 0.9942
# [2017-03-20 23:54:16.860545] INFO: Logbook: Bagged Validation Logloss 0.012
# [2017-03-20 23:54:16.861329] INFO: Logbook: Bagged Validation Accuracy 1.000
# Train on 4236 samples, validate on 691 samples
# Epoch 1/1
# 4236/4236 [==============================] - 28s - loss: 0.6286 - bb_loss: 612.8615 - class_loss: 0.0158 - bb_acc: 0.8095 - class_acc: 0.9953 - val_loss: 0.1792 - val_bb_loss: 167.5591 - val_class_loss: 0.0116 - val_bb_acc: 0.8553 - val_class_acc: 0.9942
# [2017-03-20 23:54:50.356327] INFO: Logbook: Bagged Validation Logloss 0.012
# [2017-03-20 23:54:50.357070] INFO: Logbook: Bagged Validation Accuracy 1.000
# Train on 4236 samples, validate on 691 samples
# Epoch 1/1
# 4236/4236 [==============================] - 28s - loss: 0.5719 - bb_loss: 555.3186 - class_loss: 0.0166 - bb_acc: 0.8017 - class_acc: 0.9943 - val_loss: 0.1235 - val_bb_loss: 118.3932 - val_class_loss: 0.0051 - val_bb_acc: 0.8596 - val_class_acc: 0.9986
# [2017-03-20 23:55:23.779514] INFO: Logbook: Bagged Validation Logloss 0.011
# [2017-03-20 23:55:23.780383] INFO: Logbook: Bagged Validation Accuracy 1.000
# Train on 4236 samples, validate on 691 samples
# Epoch 1/1
# 4236/4236 [==============================] - 28s - loss: 0.6428 - bb_loss: 553.7892 - class_loss: 0.0890 - bb_acc: 0.8008 - class_acc: 0.9816 - val_loss: 0.2821 - val_bb_loss: 257.9501 - val_class_loss: 0.0242 - val_bb_acc: 0.8799 - val_class_acc: 0.9928
# [2017-03-20 23:55:57.247179] INFO: Logbook: Bagged Validation Logloss 0.011
# [2017-03-20 23:55:57.247960] INFO: Logbook: Bagged Validation Accuracy 1.000
# Train on 4236 samples, validate on 691 samples
# Epoch 1/1
# 4236/4236 [==============================] - 28s - loss: 0.5604 - bb_loss: 544.1127 - class_loss: 0.0162 - bb_acc: 0.8071 - class_acc: 0.9953 - val_loss: 0.1428 - val_bb_loss: 140.8757 - val_class_loss: 0.0019 - val_bb_acc: 0.8683 - val_class_acc: 1.0000
# [2017-03-20 23:56:30.683722] INFO: Logbook: Bagged Validation Logloss 0.011
# [2017-03-20 23:56:30.684702] INFO: Logbook: Bagged Validation Accuracy 1.000
# Train on 4236 samples, validate on 691 samples
# Epoch 1/5
# 4236/4236 [==============================] - 29s - loss: 27.0072 - bb_loss: 26036.6870 - class_loss: 0.9705 - bb_acc: 0.6433 - class_acc: 0.7344 - val_loss: 22.1262 - val_bb_loss: 21785.2940 - val_class_loss: 0.3409 - val_bb_acc: 0.7670 - val_class_acc: 0.9045
# Epoch 2/5
# 4236/4236 [==============================] - 28s - loss: 15.2618 - bb_loss: 15035.0182 - class_loss: 0.2268 - bb_acc: 0.7304 - class_acc: 0.9365 - val_loss: 9.1432 - val_bb_loss: 9011.1783 - val_class_loss: 0.1321 - val_bb_acc: 0.7931 - val_class_acc: 0.9783
# Epoch 3/5
# 4236/4236 [==============================] - 28s - loss: 4.7147 - bb_loss: 4586.7439 - class_loss: 0.1280 - bb_acc: 0.7996 - class_acc: 0.9641 - val_loss: 1.5863 - val_bb_loss: 1410.2863 - val_class_loss: 0.1760 - val_bb_acc: 0.8755 - val_class_acc: 0.9609
# Epoch 4/5
# 4236/4236 [==============================] - 28s - loss: 1.5510 - bb_loss: 1484.3443 - class_loss: 0.0667 - bb_acc: 0.7986 - class_acc: 0.9814 - val_loss: 0.9113 - val_bb_loss: 846.3937 - val_class_loss: 0.0649 - val_bb_acc: 0.7612 - val_class_acc: 0.9841
# Epoch 5/5
# 4236/4236 [==============================] - 28s - loss: 0.9928 - bb_loss: 947.3825 - class_loss: 0.0454 - bb_acc: 0.7989 - class_acc: 0.9891 - val_loss: 0.5776 - val_bb_loss: 488.4822 - val_class_loss: 0.0891 - val_bb_acc: 0.8220 - val_class_acc: 0.9812
# Train on 4236 samples, validate on 691 samples
# Epoch 1/2
# 4236/4236 [==============================] - 28s - loss: 0.9496 - bb_loss: 890.9216 - class_loss: 0.0587 - bb_acc: 0.7925 - class_acc: 0.9839 - val_loss: 0.7478 - val_bb_loss: 624.3642 - val_class_loss: 0.1235 - val_bb_acc: 0.8205 - val_class_acc: 0.9624
# Epoch 2/2
# 4236/4236 [==============================] - 28s - loss: 0.7539 - bb_loss: 719.1619 - class_loss: 0.0347 - bb_acc: 0.7958 - class_acc: 0.9906 - val_loss: 0.4356 - val_bb_loss: 405.9756 - val_class_loss: 0.0297 - val_bb_acc: 0.8509 - val_class_acc: 0.9942
# Train on 4236 samples, validate on 691 samples
# Epoch 1/1
# 4236/4236 [==============================] - 28s - loss: 0.7941 - bb_loss: 775.9096 - class_loss: 0.0181 - bb_acc: 0.8012 - class_acc: 0.9950 - val_loss: 0.2552 - val_bb_loss: 243.1219 - val_class_loss: 0.0120 - val_bb_acc: 0.8307 - val_class_acc: 0.9986
# [2017-03-21 00:00:46.536684] INFO: Logbook: Bagged Validation Logloss 0.011
# [2017-03-21 00:00:46.537518] INFO: Logbook: Bagged Validation Accuracy 1.000
# Train on 4236 samples, validate on 691 samples
# Epoch 1/1
# 4236/4236 [==============================] - 28s - loss: 0.6894 - bb_loss: 676.6486 - class_loss: 0.0128 - bb_acc: 0.7878 - class_acc: 0.9965 - val_loss: 0.2929 - val_bb_loss: 264.4518 - val_class_loss: 0.0284 - val_bb_acc: 0.8452 - val_class_acc: 0.9928
# [2017-03-21 00:01:19.936437] INFO: Logbook: Bagged Validation Logloss 0.011
# [2017-03-21 00:01:19.937194] INFO: Logbook: Bagged Validation Accuracy 1.000
# Train on 4236 samples, validate on 691 samples
# Epoch 1/1
# 4236/4236 [==============================] - 28s - loss: 0.6491 - bb_loss: 640.1693 - class_loss: 0.0089 - bb_acc: 0.7998 - class_acc: 0.9979 - val_loss: 0.5049 - val_bb_loss: 434.6906 - val_class_loss: 0.0702 - val_bb_acc: 0.8423 - val_class_acc: 0.9942
# [2017-03-21 00:01:53.375651] INFO: Logbook: Bagged Validation Logloss 0.011
# [2017-03-21 00:01:53.376427] INFO: Logbook: Bagged Validation Accuracy 1.000
# Train on 4236 samples, validate on 691 samples
# Epoch 1/1
# 4236/4236 [==============================] - 28s - loss: 0.6168 - bb_loss: 600.2002 - class_loss: 0.0166 - bb_acc: 0.8050 - class_acc: 0.9981 - val_loss: 0.3728 - val_bb_loss: 309.5715 - val_class_loss: 0.0632 - val_bb_acc: 0.8698 - val_class_acc: 0.9928
# [2017-03-21 00:02:26.802285] INFO: Logbook: Bagged Validation Logloss 0.011
# [2017-03-21 00:02:26.803297] INFO: Logbook: Bagged Validation Accuracy 1.000
# Train on 4236 samples, validate on 691 samples
# Epoch 1/1
# 4236/4236 [==============================] - 28s - loss: 0.6092 - bb_loss: 588.5526 - class_loss: 0.0207 - bb_acc: 0.8111 - class_acc: 0.9950 - val_loss: 0.2697 - val_bb_loss: 250.4964 - val_class_loss: 0.0192 - val_bb_acc: 0.8538 - val_class_acc: 0.9957
# [2017-03-21 00:03:00.234238] INFO: Logbook: Bagged Validation Logloss 0.011
# [2017-03-21 00:03:00.235045] INFO: Logbook: Bagged Validation Accuracy 1.000
# Train on 4236 samples, validate on 691 samples
# Epoch 1/1
# 4236/4236 [==============================] - 28s - loss: 0.6022 - bb_loss: 549.4893 - class_loss: 0.0527 - bb_acc: 0.8005 - class_acc: 0.9882 - val_loss: 0.1691 - val_bb_loss: 163.5263 - val_class_loss: 0.0055 - val_bb_acc: 0.8495 - val_class_acc: 0.9986
# [2017-03-21 00:03:33.671615] INFO: Logbook: Bagged Validation Logloss 0.011
# [2017-03-21 00:03:33.672419] INFO: Logbook: Bagged Validation Accuracy 1.000
# Train on 4236 samples, validate on 691 samples
# Epoch 1/1
# 4236/4236 [==============================] - 28s - loss: 0.6076 - bb_loss: 563.5728 - class_loss: 0.0441 - bb_acc: 0.8057 - class_acc: 0.9854 - val_loss: 0.2110 - val_bb_loss: 178.7518 - val_class_loss: 0.0322 - val_bb_acc: 0.8553 - val_class_acc: 0.9855
# [2017-03-21 00:04:07.087881] INFO: Logbook: Bagged Validation Logloss 0.012
# [2017-03-21 00:04:07.088720] INFO: Logbook: Bagged Validation Accuracy 1.000
# Train on 4236 samples, validate on 691 samples
# Epoch 1/1
# 4236/4236 [==============================] - 28s - loss: 0.5382 - bb_loss: 524.9342 - class_loss: 0.0133 - bb_acc: 0.8045 - class_acc: 0.9962 - val_loss: 0.1354 - val_bb_loss: 134.5337 - val_class_loss: 9.0584e-04 - val_bb_acc: 0.8958 - val_class_acc: 1.0000
# [2017-03-21 00:04:40.496221] INFO: Logbook: Bagged Validation Logloss 0.011
# [2017-03-21 00:04:40.496964] INFO: Logbook: Bagged Validation Accuracy 1.000
# Train on 4236 samples, validate on 691 samples
# Epoch 1/5
# 4236/4236 [==============================] - 29s - loss: 27.1503 - bb_loss: 26021.1647 - class_loss: 1.1292 - bb_acc: 0.6374 - class_acc: 0.7195 - val_loss: 23.4184 - val_bb_loss: 23056.9115 - val_class_loss: 0.3615 - val_bb_acc: 0.8090 - val_class_acc: 0.9117
# Epoch 2/5
# 4236/4236 [==============================] - 29s - loss: 15.1741 - bb_loss: 14949.3677 - class_loss: 0.2247 - bb_acc: 0.7129 - class_acc: 0.9313 - val_loss: 6.4525 - val_bb_loss: 6297.7489 - val_class_loss: 0.1548 - val_bb_acc: 0.7438 - val_class_acc: 0.9566
# Epoch 3/5
# 4236/4236 [==============================] - 29s - loss: 4.6441 - bb_loss: 4517.1868 - class_loss: 0.1269 - bb_acc: 0.7831 - class_acc: 0.9667 - val_loss: 1.7428 - val_bb_loss: 1631.9904 - val_class_loss: 0.1108 - val_bb_acc: 0.7844 - val_class_acc: 0.9653
# Epoch 4/5
# 4236/4236 [==============================] - 29s - loss: 1.6046 - bb_loss: 1516.8844 - class_loss: 0.0877 - bb_acc: 0.7880 - class_acc: 0.9754 - val_loss: 1.0814 - val_bb_loss: 1031.2022 - val_class_loss: 0.0502 - val_bb_acc: 0.8263 - val_class_acc: 0.9942
# Epoch 5/5
# 4236/4236 [==============================] - 29s - loss: 1.0253 - bb_loss: 981.0954 - class_loss: 0.0442 - bb_acc: 0.7890 - class_acc: 0.9856 - val_loss: 0.5778 - val_bb_loss: 535.8254 - val_class_loss: 0.0420 - val_bb_acc: 0.8046 - val_class_acc: 0.9899
# Train on 4236 samples, validate on 691 samples
# Epoch 1/2
# 4236/4236 [==============================] - 29s - loss: 0.9549 - bb_loss: 910.8912 - class_loss: 0.0440 - bb_acc: 0.7918 - class_acc: 0.9863 - val_loss: 0.5348 - val_bb_loss: 478.9864 - val_class_loss: 0.0558 - val_bb_acc: 0.7988 - val_class_acc: 0.9928
# Epoch 2/2
# 4236/4236 [==============================] - 29s - loss: 0.7826 - bb_loss: 761.7366 - class_loss: 0.0209 - bb_acc: 0.7953 - class_acc: 0.9936 - val_loss: 0.3176 - val_bb_loss: 293.0815 - val_class_loss: 0.0245 - val_bb_acc: 0.8423 - val_class_acc: 0.9957
# Train on 4236 samples, validate on 691 samples
# Epoch 1/1
# 4236/4236 [==============================] - 29s - loss: 0.7583 - bb_loss: 698.1219 - class_loss: 0.0602 - bb_acc: 0.7930 - class_acc: 0.9839 - val_loss: 0.4346 - val_bb_loss: 392.5620 - val_class_loss: 0.0420 - val_bb_acc: 0.8640 - val_class_acc: 0.9855
# [2017-03-21 00:08:56.403524] INFO: Logbook: Bagged Validation Logloss 0.012
# [2017-03-21 00:08:56.404321] INFO: Logbook: Bagged Validation Accuracy 1.000
# Train on 4236 samples, validate on 691 samples
# Epoch 1/1
# 4236/4236 [==============================] - 29s - loss: 0.6551 - bb_loss: 639.7045 - class_loss: 0.0154 - bb_acc: 0.8019 - class_acc: 0.9960 - val_loss: 0.4415 - val_bb_loss: 361.1512 - val_class_loss: 0.0803 - val_bb_acc: 0.8524 - val_class_acc: 0.9942
# [2017-03-21 00:09:30.212173] INFO: Logbook: Bagged Validation Logloss 0.012
# [2017-03-21 00:09:30.213114] INFO: Logbook: Bagged Validation Accuracy 1.000
# Train on 4236 samples, validate on 691 samples
# Epoch 1/1
# 4236/4236 [==============================] - 29s - loss: 0.6138 - bb_loss: 600.5419 - class_loss: 0.0133 - bb_acc: 0.8000 - class_acc: 0.9974 - val_loss: 0.2369 - val_bb_loss: 223.6863 - val_class_loss: 0.0132 - val_bb_acc: 0.8509 - val_class_acc: 0.9971
# [2017-03-21 00:10:03.793644] INFO: Logbook: Bagged Validation Logloss 0.012
# [2017-03-21 00:10:03.794485] INFO: Logbook: Bagged Validation Accuracy 1.000
# Train on 4236 samples, validate on 691 samples
# Epoch 1/1
# 4236/4236 [==============================] - 29s - loss: 0.6194 - bb_loss: 603.2240 - class_loss: 0.0162 - bb_acc: 0.8071 - class_acc: 0.9941 - val_loss: 0.2404 - val_bb_loss: 208.0106 - val_class_loss: 0.0324 - val_bb_acc: 0.8394 - val_class_acc: 0.9913
# [2017-03-21 00:10:37.359372] INFO: Logbook: Bagged Validation Logloss 0.012
# [2017-03-21 00:10:37.360165] INFO: Logbook: Bagged Validation Accuracy 1.000
# Train on 4236 samples, validate on 691 samples
# Epoch 1/1
# 4236/4236 [==============================] - 28s - loss: 0.5588 - bb_loss: 553.8035 - class_loss: 0.0050 - bb_acc: 0.8069 - class_acc: 0.9986 - val_loss: 0.1296 - val_bb_loss: 127.9303 - val_class_loss: 0.0016 - val_bb_acc: 0.9537 - val_class_acc: 1.0000
# [2017-03-21 00:11:10.916248] INFO: Logbook: Bagged Validation Logloss 0.012
# [2017-03-21 00:11:10.917021] INFO: Logbook: Bagged Validation Accuracy 1.000
# Train on 4236 samples, validate on 691 samples
# Epoch 1/1
# 4236/4236 [==============================] - 29s - loss: 0.5268 - bb_loss: 525.4424 - class_loss: 0.0013 - bb_acc: 0.8045 - class_acc: 0.9998 - val_loss: 0.1129 - val_bb_loss: 112.0466 - val_class_loss: 8.2603e-04 - val_bb_acc: 0.9190 - val_class_acc: 1.0000
# [2017-03-21 00:11:44.495664] INFO: Logbook: Bagged Validation Logloss 0.011
# [2017-03-21 00:11:44.496435] INFO: Logbook: Bagged Validation Accuracy 1.000
# Train on 4236 samples, validate on 691 samples
# Epoch 1/1
# 4236/4236 [==============================] - 28s - loss: 0.4909 - bb_loss: 488.3201 - class_loss: 0.0026 - bb_acc: 0.8111 - class_acc: 0.9986 - val_loss: 0.1098 - val_bb_loss: 107.0824 - val_class_loss: 0.0027 - val_bb_acc: 0.8683 - val_class_acc: 1.0000
# [2017-03-21 00:12:18.047874] INFO: Logbook: Bagged Validation Logloss 0.011
# [2017-03-21 00:12:18.048669] INFO: Logbook: Bagged Validation Accuracy 1.000
# Train on 4236 samples, validate on 691 samples
# Epoch 1/1
# 4236/4236 [==============================] - 28s - loss: 0.4947 - bb_loss: 492.5974 - class_loss: 0.0021 - bb_acc: 0.8062 - class_acc: 0.9998 - val_loss: 0.1337 - val_bb_loss: 89.0400 - val_class_loss: 0.0446 - val_bb_acc: 0.8857 - val_class_acc: 0.9870
# [2017-03-21 00:12:51.591937] INFO: Logbook: Bagged Validation Logloss 0.012
# [2017-03-21 00:12:51.592773] INFO: Logbook: Bagged Validation Accuracy 1.000
# Train on 4236 samples, validate on 691 samples
# Epoch 1/5
# 4236/4236 [==============================] - 29s - loss: 27.1362 - bb_loss: 26068.5820 - class_loss: 1.0676 - bb_acc: 0.6263 - class_acc: 0.7174 - val_loss: 22.2215 - val_bb_loss: 21879.4823 - val_class_loss: 0.3420 - val_bb_acc: 0.7511 - val_class_acc: 0.8987
# Epoch 2/5
# 4236/4236 [==============================] - 28s - loss: 15.2203 - bb_loss: 14976.1532 - class_loss: 0.2441 - bb_acc: 0.7254 - class_acc: 0.9315 - val_loss: 6.9428 - val_bb_loss: 6821.0433 - val_class_loss: 0.1218 - val_bb_acc: 0.7728 - val_class_acc: 0.9754
# Epoch 3/5
# 4236/4236 [==============================] - 29s - loss: 4.7827 - bb_loss: 4626.0559 - class_loss: 0.1566 - bb_acc: 0.7861 - class_acc: 0.9547 - val_loss: 2.5636 - val_bb_loss: 2414.2590 - val_class_loss: 0.1493 - val_bb_acc: 0.7713 - val_class_acc: 0.9711
# Epoch 4/5
# 4236/4236 [==============================] - 29s - loss: 1.6138 - bb_loss: 1532.2362 - class_loss: 0.0815 - bb_acc: 0.7890 - class_acc: 0.9783 - val_loss: 1.1091 - val_bb_loss: 1049.3093 - val_class_loss: 0.0598 - val_bb_acc: 0.8350 - val_class_acc: 0.9841
# Epoch 5/5
# 4236/4236 [==============================] - 28s - loss: 1.0877 - bb_loss: 1023.9513 - class_loss: 0.0638 - bb_acc: 0.7861 - class_acc: 0.9785 - val_loss: 0.7019 - val_bb_loss: 645.3816 - val_class_loss: 0.0566 - val_bb_acc: 0.8148 - val_class_acc: 0.9928
# Train on 4236 samples, validate on 691 samples
# Epoch 1/2
# 4236/4236 [==============================] - 29s - loss: 0.9795 - bb_loss: 943.4278 - class_loss: 0.0361 - bb_acc: 0.8017 - class_acc: 0.9880 - val_loss: 0.4827 - val_bb_loss: 449.1450 - val_class_loss: 0.0336 - val_bb_acc: 0.8220 - val_class_acc: 0.9899
# Epoch 2/2
# 4236/4236 [==============================] - 29s - loss: 0.8004 - bb_loss: 779.0399 - class_loss: 0.0214 - bb_acc: 0.7965 - class_acc: 0.9950 - val_loss: 0.2890 - val_bb_loss: 280.7479 - val_class_loss: 0.0082 - val_bb_acc: 0.8394 - val_class_acc: 1.0000
# Train on 4236 samples, validate on 691 samples
# Epoch 1/1
# 4236/4236 [==============================] - 29s - loss: 0.7147 - bb_loss: 676.5993 - class_loss: 0.0381 - bb_acc: 0.7925 - class_acc: 0.9908 - val_loss: 0.3547 - val_bb_loss: 322.8373 - val_class_loss: 0.0318 - val_bb_acc: 0.9016 - val_class_acc: 0.9913
# [2017-03-21 00:17:07.977890] INFO: Logbook: Bagged Validation Logloss 0.012
# [2017-03-21 00:17:07.978731] INFO: Logbook: Bagged Validation Accuracy 1.000
# Train on 4236 samples, validate on 691 samples
# Epoch 1/1
# 4236/4236 [==============================] - 29s - loss: 0.5925 - bb_loss: 577.4140 - class_loss: 0.0151 - bb_acc: 0.8055 - class_acc: 0.9958 - val_loss: 0.4865 - val_bb_loss: 448.9530 - val_class_loss: 0.0375 - val_bb_acc: 0.9247 - val_class_acc: 0.9899
# [2017-03-21 00:17:41.824541] INFO: Logbook: Bagged Validation Logloss 0.012
# [2017-03-21 00:17:41.825317] INFO: Logbook: Bagged Validation Accuracy 1.000
# Train on 4236 samples, validate on 691 samples
# Epoch 1/1
# 4236/4236 [==============================] - 29s - loss: 0.6554 - bb_loss: 631.3374 - class_loss: 0.0240 - bb_acc: 0.7932 - class_acc: 0.9929 - val_loss: 0.4099 - val_bb_loss: 299.9780 - val_class_loss: 0.1099 - val_bb_acc: 0.8466 - val_class_acc: 0.9711
# [2017-03-21 00:18:15.627876] INFO: Logbook: Bagged Validation Logloss 0.013
# [2017-03-21 00:18:15.628692] INFO: Logbook: Bagged Validation Accuracy 1.000
# Train on 4236 samples, validate on 691 samples
# Epoch 1/1
# 4236/4236 [==============================] - 29s - loss: 0.6275 - bb_loss: 603.3762 - class_loss: 0.0242 - bb_acc: 0.7991 - class_acc: 0.9929 - val_loss: 0.2550 - val_bb_loss: 247.2146 - val_class_loss: 0.0078 - val_bb_acc: 0.8669 - val_class_acc: 0.9986
# [2017-03-21 00:18:49.508994] INFO: Logbook: Bagged Validation Logloss 0.013
# [2017-03-21 00:18:49.509767] INFO: Logbook: Bagged Validation Accuracy 1.000
# Train on 4236 samples, validate on 691 samples
# Epoch 1/1
# 4236/4236 [==============================] - 29s - loss: 0.6210 - bb_loss: 594.8552 - class_loss: 0.0261 - bb_acc: 0.8031 - class_acc: 0.9924 - val_loss: 0.2524 - val_bb_loss: 246.3502 - val_class_loss: 0.0060 - val_bb_acc: 0.8726 - val_class_acc: 1.0000
# [2017-03-21 00:19:23.236124] INFO: Logbook: Bagged Validation Logloss 0.013
# [2017-03-21 00:19:23.236893] INFO: Logbook: Bagged Validation Accuracy 1.000
# Train on 4236 samples, validate on 691 samples
# Epoch 1/1
# 4236/4236 [==============================] - 28s - loss: 0.6116 - bb_loss: 588.5752 - class_loss: 0.0230 - bb_acc: 0.7977 - class_acc: 0.9955 - val_loss: 0.1700 - val_bb_loss: 164.7372 - val_class_loss: 0.0053 - val_bb_acc: 0.8567 - val_class_acc: 0.9986
# [2017-03-21 00:19:56.733402] INFO: Logbook: Bagged Validation Logloss 0.012
# [2017-03-21 00:19:56.734138] INFO: Logbook: Bagged Validation Accuracy 1.000
# Train on 4236 samples, validate on 691 samples
# Epoch 1/1
# 4236/4236 [==============================] - 28s - loss: 0.5788 - bb_loss: 554.4166 - class_loss: 0.0244 - bb_acc: 0.7986 - class_acc: 0.9939 - val_loss: 0.1947 - val_bb_loss: 184.0834 - val_class_loss: 0.0107 - val_bb_acc: 0.8292 - val_class_acc: 0.9971
# [2017-03-21 00:20:30.284819] INFO: Logbook: Bagged Validation Logloss 0.012
# [2017-03-21 00:20:30.285599] INFO: Logbook: Bagged Validation Accuracy 1.000
# Train on 4236 samples, validate on 691 samples
# Epoch 1/1
# 4236/4236 [==============================] - 28s - loss: 0.5032 - bb_loss: 492.2011 - class_loss: 0.0110 - bb_acc: 0.8074 - class_acc: 0.9967 - val_loss: 0.1178 - val_bb_loss: 116.6135 - val_class_loss: 0.0012 - val_bb_acc: 0.8828 - val_class_acc: 1.0000
# [2017-03-21 00:21:03.790323] INFO: Logbook: Bagged Validation Logloss 0.012
# [2017-03-21 00:21:03.791062] INFO: Logbook: Bagged Validation Accuracy 1.000
# Train on 4236 samples, validate on 691 samples
# Epoch 1/5
# 4236/4236 [==============================] - 29s - loss: 27.3429 - bb_loss: 25992.4231 - class_loss: 1.3505 - bb_acc: 0.6447 - class_acc: 0.7290 - val_loss: 17.6547 - val_bb_loss: 17328.0768 - val_class_loss: 0.3266 - val_bb_acc: 0.7685 - val_class_acc: 0.9204
# Epoch 2/5
# 4236/4236 [==============================] - 28s - loss: 15.1964 - bb_loss: 14970.9128 - class_loss: 0.2255 - bb_acc: 0.7221 - class_acc: 0.9356 - val_loss: 8.1144 - val_bb_loss: 7899.9292 - val_class_loss: 0.2145 - val_bb_acc: 0.7438 - val_class_acc: 0.9450
# Epoch 3/5
# 4236/4236 [==============================] - 28s - loss: 4.8229 - bb_loss: 4713.5305 - class_loss: 0.1093 - bb_acc: 0.7814 - class_acc: 0.9714 - val_loss: 2.0648 - val_bb_loss: 1965.0850 - val_class_loss: 0.0997 - val_bb_acc: 0.7916 - val_class_acc: 0.9768
# Epoch 4/5
# 4236/4236 [==============================] - 28s - loss: 1.5504 - bb_loss: 1484.8483 - class_loss: 0.0656 - bb_acc: 0.8017 - class_acc: 0.9837 - val_loss: 1.0011 - val_bb_loss: 960.7076 - val_class_loss: 0.0404 - val_bb_acc: 0.8046 - val_class_acc: 0.9957
# Epoch 5/5
# 4236/4236 [==============================] - 29s - loss: 1.0699 - bb_loss: 1029.3648 - class_loss: 0.0405 - bb_acc: 0.7925 - class_acc: 0.9887 - val_loss: 0.8324 - val_bb_loss: 735.9043 - val_class_loss: 0.0965 - val_bb_acc: 0.8263 - val_class_acc: 0.9653
# Train on 4236 samples, validate on 691 samples
# Epoch 1/2
# 4236/4236 [==============================] - 29s - loss: 0.8557 - bb_loss: 828.3790 - class_loss: 0.0273 - bb_acc: 0.7972 - class_acc: 0.9929 - val_loss: 0.4467 - val_bb_loss: 393.2517 - val_class_loss: 0.0535 - val_bb_acc: 0.8249 - val_class_acc: 0.9855
# Epoch 2/2
# 4236/4236 [==============================] - 29s - loss: 0.7378 - bb_loss: 719.7805 - class_loss: 0.0180 - bb_acc: 0.7918 - class_acc: 0.9960 - val_loss: 0.3979 - val_bb_loss: 325.2010 - val_class_loss: 0.0727 - val_bb_acc: 0.8408 - val_class_acc: 0.9682
# Train on 4236 samples, validate on 691 samples
# Epoch 1/1
# 4236/4236 [==============================] - 29s - loss: 0.7449 - bb_loss: 701.5316 - class_loss: 0.0434 - bb_acc: 0.8078 - class_acc: 0.9865 - val_loss: 0.2728 - val_bb_loss: 251.5094 - val_class_loss: 0.0213 - val_bb_acc: 0.8509 - val_class_acc: 0.9971
# [2017-03-21 00:25:19.961846] INFO: Logbook: Bagged Validation Logloss 0.012
# [2017-03-21 00:25:19.962682] INFO: Logbook: Bagged Validation Accuracy 1.000
# Train on 4236 samples, validate on 691 samples
# Epoch 1/1
# 4236/4236 [==============================] - 29s - loss: 0.7275 - bb_loss: 676.1670 - class_loss: 0.0513 - bb_acc: 0.7977 - class_acc: 0.9898 - val_loss: 0.2861 - val_bb_loss: 259.1445 - val_class_loss: 0.0270 - val_bb_acc: 0.8567 - val_class_acc: 0.9928
# [2017-03-21 00:25:53.695155] INFO: Logbook: Bagged Validation Logloss 0.012
# [2017-03-21 00:25:53.695939] INFO: Logbook: Bagged Validation Accuracy 1.000
# Train on 4236 samples, validate on 691 samples
# Epoch 1/1
# 4236/4236 [==============================] - 29s - loss: 0.6282 - bb_loss: 605.8071 - class_loss: 0.0224 - bb_acc: 0.7941 - class_acc: 0.9941 - val_loss: 0.2477 - val_bb_loss: 223.0793 - val_class_loss: 0.0246 - val_bb_acc: 0.8654 - val_class_acc: 0.9942
# [2017-03-21 00:26:27.528773] INFO: Logbook: Bagged Validation Logloss 0.012
# [2017-03-21 00:26:27.529534] INFO: Logbook: Bagged Validation Accuracy 1.000
# Train on 4236 samples, validate on 691 samples
# Epoch 1/1
# 4236/4236 [==============================] - 29s - loss: 0.5454 - bb_loss: 530.7705 - class_loss: 0.0147 - bb_acc: 0.7998 - class_acc: 0.9958 - val_loss: 0.1538 - val_bb_loss: 140.5483 - val_class_loss: 0.0132 - val_bb_acc: 0.8900 - val_class_acc: 0.9957
# [2017-03-21 00:27:01.307442] INFO: Logbook: Bagged Validation Logloss 0.012
# [2017-03-21 00:27:01.308225] INFO: Logbook: Bagged Validation Accuracy 1.000
# Train on 4236 samples, validate on 691 samples
# Epoch 1/1
# 4236/4236 [==============================] - 29s - loss: 0.5621 - bb_loss: 552.5181 - class_loss: 0.0096 - bb_acc: 0.8029 - class_acc: 0.9976 - val_loss: 0.1525 - val_bb_loss: 148.8353 - val_class_loss: 0.0037 - val_bb_acc: 0.8423 - val_class_acc: 0.9986
# [2017-03-21 00:27:35.007394] INFO: Logbook: Bagged Validation Logloss 0.012
# [2017-03-21 00:27:35.008283] INFO: Logbook: Bagged Validation Accuracy 1.000
# Train on 4236 samples, validate on 691 samples
# Epoch 1/1
# 4236/4236 [==============================] - 29s - loss: 0.5345 - bb_loss: 518.7848 - class_loss: 0.0157 - bb_acc: 0.8109 - class_acc: 0.9969 - val_loss: 0.1629 - val_bb_loss: 146.7748 - val_class_loss: 0.0162 - val_bb_acc: 0.8611 - val_class_acc: 0.9942
# [2017-03-21 00:28:08.763339] INFO: Logbook: Bagged Validation Logloss 0.012
# [2017-03-21 00:28:08.764105] INFO: Logbook: Bagged Validation Accuracy 1.000
# Train on 4236 samples, validate on 691 samples
# Epoch 1/1
# 4236/4236 [==============================] - 29s - loss: 0.5038 - bb_loss: 489.5761 - class_loss: 0.0142 - bb_acc: 0.8109 - class_acc: 0.9972 - val_loss: 0.1552 - val_bb_loss: 133.8509 - val_class_loss: 0.0213 - val_bb_acc: 0.8582 - val_class_acc: 0.9899
# [2017-03-21 00:28:42.457067] INFO: Logbook: Bagged Validation Logloss 0.012
# [2017-03-21 00:28:42.457860] INFO: Logbook: Bagged Validation Accuracy 1.000
# Train on 4236 samples, validate on 691 samples
# Epoch 1/1
# 4236/4236 [==============================] - 29s - loss: 0.5005 - bb_loss: 486.1693 - class_loss: 0.0144 - bb_acc: 0.8097 - class_acc: 0.9974 - val_loss: 0.0919 - val_bb_loss: 91.3183 - val_class_loss: 6.2495e-04 - val_bb_acc: 0.8640 - val_class_acc: 1.0000
# [2017-03-21 00:29:16.246145] INFO: Logbook: Bagged Validation Logloss 0.012
# [2017-03-21 00:29:16.246912] INFO: Logbook: Bagged Validation Accuracy 1.000
# Train on 4236 samples, validate on 691 samples
# Epoch 1/5
# 4236/4236 [==============================] - 29s - loss: 27.2637 - bb_loss: 26038.3479 - class_loss: 1.2253 - bb_acc: 0.6485 - class_acc: 0.7311 - val_loss: 18.7567 - val_bb_loss: 18399.0662 - val_class_loss: 0.3577 - val_bb_acc: 0.7048 - val_class_acc: 0.9001
# Epoch 2/5
# 4236/4236 [==============================] - 28s - loss: 15.1143 - bb_loss: 14893.4342 - class_loss: 0.2209 - bb_acc: 0.7247 - class_acc: 0.9360 - val_loss: 7.0886 - val_bb_loss: 6923.0718 - val_class_loss: 0.1655 - val_bb_acc: 0.8075 - val_class_acc: 0.9580
# Epoch 3/5
# 4236/4236 [==============================] - 28s - loss: 4.7186 - bb_loss: 4589.4008 - class_loss: 0.1292 - bb_acc: 0.7802 - class_acc: 0.9632 - val_loss: 2.0331 - val_bb_loss: 1875.8396 - val_class_loss: 0.1573 - val_bb_acc: 0.7496 - val_class_acc: 0.9595
# Epoch 4/5
# 4236/4236 [==============================] - 28s - loss: 1.5836 - bb_loss: 1533.5543 - class_loss: 0.0501 - bb_acc: 0.7951 - class_acc: 0.9847 - val_loss: 0.9319 - val_bb_loss: 660.7994 - val_class_loss: 0.2711 - val_bb_acc: 0.7945 - val_class_acc: 0.9146
# Epoch 5/5
# 4236/4236 [==============================] - 28s - loss: 1.0781 - bb_loss: 1014.9040 - class_loss: 0.0632 - bb_acc: 0.7904 - class_acc: 0.9821 - val_loss: 0.6899 - val_bb_loss: 625.0866 - val_class_loss: 0.0648 - val_bb_acc: 0.8321 - val_class_acc: 0.9855
# Train on 4236 samples, validate on 691 samples
# Epoch 1/2
# 4236/4236 [==============================] - 28s - loss: 0.9631 - bb_loss: 916.5614 - class_loss: 0.0465 - bb_acc: 0.7901 - class_acc: 0.9868 - val_loss: 0.6056 - val_bb_loss: 530.6945 - val_class_loss: 0.0749 - val_bb_acc: 0.8365 - val_class_acc: 0.9870
# Epoch 2/2
# 4236/4236 [==============================] - 28s - loss: 0.8516 - bb_loss: 822.1466 - class_loss: 0.0294 - bb_acc: 0.7906 - class_acc: 0.9920 - val_loss: 0.4568 - val_bb_loss: 441.3766 - val_class_loss: 0.0154 - val_bb_acc: 0.8307 - val_class_acc: 0.9957
# Train on 4236 samples, validate on 691 samples
# Epoch 1/1
# 4236/4236 [==============================] - 28s - loss: 0.7614 - bb_loss: 749.8037 - class_loss: 0.0116 - bb_acc: 0.7915 - class_acc: 0.9967 - val_loss: 0.3368 - val_bb_loss: 321.1577 - val_class_loss: 0.0156 - val_bb_acc: 0.8423 - val_class_acc: 0.9942
# [2017-03-21 00:33:32.334016] INFO: Logbook: Bagged Validation Logloss 0.012
# [2017-03-21 00:33:32.334814] INFO: Logbook: Bagged Validation Accuracy 1.000
# Train on 4236 samples, validate on 691 samples
# Epoch 1/1
# 4236/4236 [==============================] - 28s - loss: 0.6331 - bb_loss: 626.0148 - class_loss: 0.0071 - bb_acc: 0.7989 - class_acc: 0.9986 - val_loss: 0.2110 - val_bb_loss: 200.3599 - val_class_loss: 0.0106 - val_bb_acc: 0.8784 - val_class_acc: 0.9986
# [2017-03-21 00:34:05.843029] INFO: Logbook: Bagged Validation Logloss 0.012
# [2017-03-21 00:34:05.843774] INFO: Logbook: Bagged Validation Accuracy 1.000
# Train on 4236 samples, validate on 691 samples
# Epoch 1/1
# 4236/4236 [==============================] - 28s - loss: 0.5919 - bb_loss: 579.4733 - class_loss: 0.0124 - bb_acc: 0.8031 - class_acc: 0.9960 - val_loss: 0.2278 - val_bb_loss: 209.8763 - val_class_loss: 0.0179 - val_bb_acc: 0.8611 - val_class_acc: 0.9942
# [2017-03-21 00:34:39.374335] INFO: Logbook: Bagged Validation Logloss 0.012
# [2017-03-21 00:34:39.375217] INFO: Logbook: Bagged Validation Accuracy 1.000
# Train on 4236 samples, validate on 691 samples
# Epoch 1/1
# 4236/4236 [==============================] - 28s - loss: 0.5754 - bb_loss: 563.2641 - class_loss: 0.0122 - bb_acc: 0.8045 - class_acc: 0.9967 - val_loss: 0.1478 - val_bb_loss: 138.4511 - val_class_loss: 0.0094 - val_bb_acc: 0.8495 - val_class_acc: 0.9971
# [2017-03-21 00:35:12.854277] INFO: Logbook: Bagged Validation Logloss 0.012
# [2017-03-21 00:35:12.855172] INFO: Logbook: Bagged Validation Accuracy 1.000
# Train on 4236 samples, validate on 691 samples
# Epoch 1/1
# 4236/4236 [==============================] - 28s - loss: 0.6025 - bb_loss: 580.5644 - class_loss: 0.0219 - bb_acc: 0.8026 - class_acc: 0.9948 - val_loss: 0.2472 - val_bb_loss: 167.3400 - val_class_loss: 0.0798 - val_bb_acc: 0.8596 - val_class_acc: 0.9754
# [2017-03-21 00:35:46.372652] INFO: Logbook: Bagged Validation Logloss 0.013
# [2017-03-21 00:35:46.373463] INFO: Logbook: Bagged Validation Accuracy 1.000
# Train on 4236 samples, validate on 691 samples
# Epoch 1/1
# 4236/4236 [==============================] - 28s - loss: 0.6664 - bb_loss: 583.4259 - class_loss: 0.0830 - bb_acc: 0.7920 - class_acc: 0.9792 - val_loss: 0.2764 - val_bb_loss: 216.7520 - val_class_loss: 0.0596 - val_bb_acc: 0.8654 - val_class_acc: 0.9797
# [2017-03-21 00:36:19.859643] INFO: Logbook: Bagged Validation Logloss 0.013
# [2017-03-21 00:36:19.860447] INFO: Logbook: Bagged Validation Accuracy 1.000
# Train on 4236 samples, validate on 691 samples
# Epoch 1/1
# 4236/4236 [==============================] - 28s - loss: 0.7136 - bb_loss: 610.9118 - class_loss: 0.1027 - bb_acc: 0.7986 - class_acc: 0.9797 - val_loss: 0.1851 - val_bb_loss: 164.7987 - val_class_loss: 0.0203 - val_bb_acc: 0.8480 - val_class_acc: 0.9913
# [2017-03-21 00:36:53.384979] INFO: Logbook: Bagged Validation Logloss 0.013
# [2017-03-21 00:36:53.385704] INFO: Logbook: Bagged Validation Accuracy 1.000
# Train on 4236 samples, validate on 691 samples
# Epoch 1/1
# 4236/4236 [==============================] - 28s - loss: 0.5625 - bb_loss: 544.0862 - class_loss: 0.0185 - bb_acc: 0.8074 - class_acc: 0.9948 - val_loss: 0.1268 - val_bb_loss: 123.1205 - val_class_loss: 0.0036 - val_bb_acc: 0.8437 - val_class_acc: 0.9986
# [2017-03-21 00:37:26.891636] INFO: Logbook: Bagged Validation Logloss 0.013
# [2017-03-21 00:37:26.892461] INFO: Logbook: Bagged Validation Accuracy 1.000
# Train on 4236 samples, validate on 691 samples
# Epoch 1/5
# 4236/4236 [==============================] - 29s - loss: 26.8541 - bb_loss: 26054.3425 - class_loss: 0.7998 - bb_acc: 0.6466 - class_acc: 0.7665 - val_loss: 20.7874 - val_bb_loss: 19743.9737 - val_class_loss: 1.0434 - val_bb_acc: 0.7569 - val_class_acc: 0.6064
# Epoch 2/5
# 4236/4236 [==============================] - 28s - loss: 15.2698 - bb_loss: 15027.5863 - class_loss: 0.2422 - bb_acc: 0.7207 - class_acc: 0.9320 - val_loss: 7.5968 - val_bb_loss: 7421.6778 - val_class_loss: 0.1751 - val_bb_acc: 0.7685 - val_class_acc: 0.9609
# Epoch 3/5
# 4236/4236 [==============================] - 29s - loss: 4.8067 - bb_loss: 4667.2910 - class_loss: 0.1394 - bb_acc: 0.7757 - class_acc: 0.9610 - val_loss: 1.9641 - val_bb_loss: 1815.2152 - val_class_loss: 0.1489 - val_bb_acc: 0.8365 - val_class_acc: 0.9667
# Epoch 4/5
# 4236/4236 [==============================] - 28s - loss: 1.5834 - bb_loss: 1514.2887 - class_loss: 0.0691 - bb_acc: 0.8078 - class_acc: 0.9809 - val_loss: 0.8711 - val_bb_loss: 821.6967 - val_class_loss: 0.0494 - val_bb_acc: 0.7713 - val_class_acc: 0.9928
# Epoch 5/5
# 4236/4236 [==============================] - 28s - loss: 1.0713 - bb_loss: 1027.6389 - class_loss: 0.0437 - bb_acc: 0.7795 - class_acc: 0.9875 - val_loss: 0.5933 - val_bb_loss: 486.9644 - val_class_loss: 0.1063 - val_bb_acc: 0.8365 - val_class_acc: 0.9508
# Train on 4236 samples, validate on 691 samples
# Epoch 1/2
# 4236/4236 [==============================] - 28s - loss: 0.8695 - bb_loss: 845.5057 - class_loss: 0.0240 - bb_acc: 0.7868 - class_acc: 0.9920 - val_loss: 0.6414 - val_bb_loss: 558.6820 - val_class_loss: 0.0827 - val_bb_acc: 0.8466 - val_class_acc: 0.9812
# Epoch 2/2
# 4236/4236 [==============================] - 28s - loss: 0.7849 - bb_loss: 741.9904 - class_loss: 0.0429 - bb_acc: 0.7967 - class_acc: 0.9877 - val_loss: 0.5229 - val_bb_loss: 469.7480 - val_class_loss: 0.0531 - val_bb_acc: 0.8278 - val_class_acc: 0.9913
# Train on 4236 samples, validate on 691 samples
# Epoch 1/1
# 4236/4236 [==============================] - 28s - loss: 0.7775 - bb_loss: 751.8625 - class_loss: 0.0256 - bb_acc: 0.7967 - class_acc: 0.9924 - val_loss: 0.3574 - val_bb_loss: 330.2165 - val_class_loss: 0.0272 - val_bb_acc: 0.8944 - val_class_acc: 0.9957
# [2017-03-21 00:41:43.385314] INFO: Logbook: Bagged Validation Logloss 0.013
# [2017-03-21 00:41:43.386107] INFO: Logbook: Bagged Validation Accuracy 1.000
# Train on 4236 samples, validate on 691 samples
# Epoch 1/1
# 4236/4236 [==============================] - 28s - loss: 0.6768 - bb_loss: 670.6803 - class_loss: 0.0061 - bb_acc: 0.7993 - class_acc: 0.9979 - val_loss: 0.2382 - val_bb_loss: 222.8238 - val_class_loss: 0.0154 - val_bb_acc: 0.8553 - val_class_acc: 0.9986
# [2017-03-21 00:42:16.892732] INFO: Logbook: Bagged Validation Logloss 0.013
# [2017-03-21 00:42:16.893617] INFO: Logbook: Bagged Validation Accuracy 1.000
# Train on 4236 samples, validate on 691 samples
# Epoch 1/1
# 4236/4236 [==============================] - 28s - loss: 0.6077 - bb_loss: 599.3462 - class_loss: 0.0084 - bb_acc: 0.8036 - class_acc: 0.9974 - val_loss: 0.2562 - val_bb_loss: 236.6023 - val_class_loss: 0.0196 - val_bb_acc: 0.8466 - val_class_acc: 0.9942
# [2017-03-21 00:42:50.398463] INFO: Logbook: Bagged Validation Logloss 0.013
# [2017-03-21 00:42:50.399400] INFO: Logbook: Bagged Validation Accuracy 1.000
# Train on 4236 samples, validate on 691 samples
# Epoch 1/1
# 4236/4236 [==============================] - 28s - loss: 0.6688 - bb_loss: 654.7209 - class_loss: 0.0141 - bb_acc: 0.7930 - class_acc: 0.9941 - val_loss: 0.1754 - val_bb_loss: 166.3514 - val_class_loss: 0.0091 - val_bb_acc: 0.8611 - val_class_acc: 1.0000
# [2017-03-21 00:43:23.888865] INFO: Logbook: Bagged Validation Logloss 0.013
# [2017-03-21 00:43:23.889656] INFO: Logbook: Bagged Validation Accuracy 1.000
# Train on 4236 samples, validate on 691 samples
# Epoch 1/1
# 4236/4236 [==============================] - 28s - loss: 0.6068 - bb_loss: 594.7104 - class_loss: 0.0120 - bb_acc: 0.8026 - class_acc: 0.9962 - val_loss: 0.1692 - val_bb_loss: 153.6242 - val_class_loss: 0.0155 - val_bb_acc: 0.8394 - val_class_acc: 0.9971
# [2017-03-21 00:43:57.403000] INFO: Logbook: Bagged Validation Logloss 0.013
# [2017-03-21 00:43:57.403887] INFO: Logbook: Bagged Validation Accuracy 1.000
# Train on 4236 samples, validate on 691 samples
# Epoch 1/1
# 4236/4236 [==============================] - 29s - loss: 0.5278 - bb_loss: 523.3603 - class_loss: 0.0045 - bb_acc: 0.7977 - class_acc: 0.9986 - val_loss: 0.1213 - val_bb_loss: 119.4251 - val_class_loss: 0.0019 - val_bb_acc: 0.8538 - val_class_acc: 1.0000
# [2017-03-21 00:44:30.990037] INFO: Logbook: Bagged Validation Logloss 0.013
# [2017-03-21 00:44:30.990819] INFO: Logbook: Bagged Validation Accuracy 1.000
# Train on 4236 samples, validate on 691 samples
# Epoch 1/1
# 4236/4236 [==============================] - 29s - loss: 0.5387 - bb_loss: 532.9950 - class_loss: 0.0057 - bb_acc: 0.8078 - class_acc: 0.9983 - val_loss: 0.1138 - val_bb_loss: 108.1855 - val_class_loss: 0.0056 - val_bb_acc: 0.9291 - val_class_acc: 1.0000
# [2017-03-21 00:45:04.782462] INFO: Logbook: Bagged Validation Logloss 0.012
# [2017-03-21 00:45:04.783244] INFO: Logbook: Bagged Validation Accuracy 1.000
# Train on 4236 samples, validate on 691 samples
# Epoch 1/1
# 4236/4236 [==============================] - 29s - loss: 0.5455 - bb_loss: 509.1739 - class_loss: 0.0364 - bb_acc: 0.8111 - class_acc: 0.9917 - val_loss: 0.1789 - val_bb_loss: 128.6145 - val_class_loss: 0.0503 - val_bb_acc: 0.8350 - val_class_acc: 0.9855
# [2017-03-21 00:45:38.650748] INFO: Logbook: Bagged Validation Logloss 0.013
# [2017-03-21 00:45:38.651538] INFO: Logbook: Bagged Validation Accuracy 1.000
# Train on 4236 samples, validate on 691 samples
# Epoch 1/5
# 4236/4236 [==============================] - 29s - loss: 27.2317 - bb_loss: 26024.5564 - class_loss: 1.2071 - bb_acc: 0.6206 - class_acc: 0.7139 - val_loss: 18.1852 - val_bb_loss: 17800.0003 - val_class_loss: 0.3852 - val_bb_acc: 0.7771 - val_class_acc: 0.9074
# Epoch 2/5
# 4236/4236 [==============================] - 29s - loss: 15.2481 - bb_loss: 14966.9742 - class_loss: 0.2811 - bb_acc: 0.7162 - class_acc: 0.9216 - val_loss: 9.0644 - val_bb_loss: 8834.5508 - val_class_loss: 0.2299 - val_bb_acc: 0.7438 - val_class_acc: 0.9392
# Epoch 3/5
# 4236/4236 [==============================] - 29s - loss: 4.6050 - bb_loss: 4507.4273 - class_loss: 0.0976 - bb_acc: 0.7819 - class_acc: 0.9717 - val_loss: 1.7470 - val_bb_loss: 1661.0069 - val_class_loss: 0.0860 - val_bb_acc: 0.8148 - val_class_acc: 0.9855
# Epoch 4/5
# 4236/4236 [==============================] - 29s - loss: 1.5826 - bb_loss: 1492.2060 - class_loss: 0.0904 - bb_acc: 0.8031 - class_acc: 0.9776 - val_loss: 0.9533 - val_bb_loss: 847.6765 - val_class_loss: 0.1056 - val_bb_acc: 0.7815 - val_class_acc: 0.9696
# Epoch 5/5
# 4236/4236 [==============================] - 29s - loss: 1.0112 - bb_loss: 959.9856 - class_loss: 0.0512 - bb_acc: 0.8015 - class_acc: 0.9844 - val_loss: 0.6727 - val_bb_loss: 589.9882 - val_class_loss: 0.0827 - val_bb_acc: 0.7902 - val_class_acc: 0.9942
# Train on 4236 samples, validate on 691 samples
# Epoch 1/2
# 4236/4236 [==============================] - 29s - loss: 0.8729 - bb_loss: 838.5352 - class_loss: 0.0344 - bb_acc: 0.7937 - class_acc: 0.9910 - val_loss: 0.6428 - val_bb_loss: 444.7167 - val_class_loss: 0.1981 - val_bb_acc: 0.8032 - val_class_acc: 0.9247
# Epoch 2/2
# 4236/4236 [==============================] - 29s - loss: 0.9123 - bb_loss: 851.0628 - class_loss: 0.0612 - bb_acc: 0.7828 - class_acc: 0.9847 - val_loss: 0.5101 - val_bb_loss: 371.5364 - val_class_loss: 0.1385 - val_bb_acc: 0.8509 - val_class_acc: 0.9479
# Train on 4236 samples, validate on 691 samples
# Epoch 1/1
# 4236/4236 [==============================] - 29s - loss: 0.7313 - bb_loss: 714.9074 - class_loss: 0.0164 - bb_acc: 0.7915 - class_acc: 0.9953 - val_loss: 0.2891 - val_bb_loss: 258.5368 - val_class_loss: 0.0306 - val_bb_acc: 0.8321 - val_class_acc: 0.9957
# [2017-03-21 00:49:56.812976] INFO: Logbook: Bagged Validation Logloss 0.013
# [2017-03-21 00:49:56.813878] INFO: Logbook: Bagged Validation Accuracy 1.000
# Train on 4236 samples, validate on 691 samples
# Epoch 1/1
# 4236/4236 [==============================] - 29s - loss: 0.6793 - bb_loss: 646.6271 - class_loss: 0.0327 - bb_acc: 0.8041 - class_acc: 0.9901 - val_loss: 0.2661 - val_bb_loss: 239.0428 - val_class_loss: 0.0271 - val_bb_acc: 0.8365 - val_class_acc: 0.9942
# [2017-03-21 00:50:30.432174] INFO: Logbook: Bagged Validation Logloss 0.013
# [2017-03-21 00:50:30.432952] INFO: Logbook: Bagged Validation Accuracy 1.000
# Train on 4236 samples, validate on 691 samples
# Epoch 1/1
# 4236/4236 [==============================] - 29s - loss: 0.6408 - bb_loss: 628.6141 - class_loss: 0.0122 - bb_acc: 0.8026 - class_acc: 0.9969 - val_loss: 0.2189 - val_bb_loss: 205.4894 - val_class_loss: 0.0134 - val_bb_acc: 0.8408 - val_class_acc: 0.9971
# [2017-03-21 00:51:04.241681] INFO: Logbook: Bagged Validation Logloss 0.013
# [2017-03-21 00:51:04.242475] INFO: Logbook: Bagged Validation Accuracy 1.000
# Train on 4236 samples, validate on 691 samples
# Epoch 1/1
# 4236/4236 [==============================] - 29s - loss: 0.5691 - bb_loss: 557.7379 - class_loss: 0.0113 - bb_acc: 0.7967 - class_acc: 0.9969 - val_loss: 0.2547 - val_bb_loss: 247.3548 - val_class_loss: 0.0073 - val_bb_acc: 0.8596 - val_class_acc: 1.0000
# [2017-03-21 00:51:38.152993] INFO: Logbook: Bagged Validation Logloss 0.013
# [2017-03-21 00:51:38.153920] INFO: Logbook: Bagged Validation Accuracy 1.000
# Train on 4236 samples, validate on 691 samples
# Epoch 1/1
# 4236/4236 [==============================] - 29s - loss: 0.5638 - bb_loss: 543.9414 - class_loss: 0.0199 - bb_acc: 0.8048 - class_acc: 0.9946 - val_loss: 0.1952 - val_bb_loss: 162.2204 - val_class_loss: 0.0330 - val_bb_acc: 0.9074 - val_class_acc: 0.9913
# [2017-03-21 00:52:11.880930] INFO: Logbook: Bagged Validation Logloss 0.013
# [2017-03-21 00:52:11.881699] INFO: Logbook: Bagged Validation Accuracy 1.000
# Train on 4236 samples, validate on 691 samples
# Epoch 1/1
# 4236/4236 [==============================] - 29s - loss: 0.5874 - bb_loss: 555.4648 - class_loss: 0.0319 - bb_acc: 0.8036 - class_acc: 0.9908 - val_loss: 0.2308 - val_bb_loss: 173.7099 - val_class_loss: 0.0570 - val_bb_acc: 0.8741 - val_class_acc: 0.9884
# [2017-03-21 00:52:45.511680] INFO: Logbook: Bagged Validation Logloss 0.013
# [2017-03-21 00:52:45.512679] INFO: Logbook: Bagged Validation Accuracy 1.000
# Train on 4236 samples, validate on 691 samples
# Epoch 1/1
# 4236/4236 [==============================] - 29s - loss: 0.5854 - bb_loss: 565.5947 - class_loss: 0.0198 - bb_acc: 0.8000 - class_acc: 0.9950 - val_loss: 0.1542 - val_bb_loss: 135.7859 - val_class_loss: 0.0184 - val_bb_acc: 0.8726 - val_class_acc: 0.9957
# [2017-03-21 00:53:19.114182] INFO: Logbook: Bagged Validation Logloss 0.013
# [2017-03-21 00:53:19.114982] INFO: Logbook: Bagged Validation Accuracy 1.000
# Train on 4236 samples, validate on 691 samples
# Epoch 1/1
# 4236/4236 [==============================] - 29s - loss: 0.6097 - bb_loss: 537.3963 - class_loss: 0.0723 - bb_acc: 0.8069 - class_acc: 0.9804 - val_loss: 0.2212 - val_bb_loss: 206.1934 - val_class_loss: 0.0150 - val_bb_acc: 0.9204 - val_class_acc: 1.0000
# [2017-03-21 00:53:52.742304] INFO: Logbook: Bagged Validation Logloss 0.013
# [2017-03-21 00:53:52.743193] INFO: Logbook: Bagged Validation Accuracy 1.000

# %%
val = get_data(path+'pseudo/valid', load_size)
pval_bbox = model[0].predict(conv_val_feat, batch_size=batch_size)[0]
# Out:
# Found 691 images belonging to 8 classes.

# %%
def create_rect(bb, color='red'):
    return plt.Rectangle((bb[2], bb[3]), bb[1], bb[0], color=color, fill=False, lw=3)

def show_bb(i):
    bb = val_bbox[i]
    pbb = pval_bbox[i]
    plot(val[i])
    plt.gca().add_patch(create_rect(bb, color='red'))
    plt.gca().add_patch(create_rect(pbb, color='yellow'))

show_bb(350)

# %%
# metrics.log_loss(val_labels, do_clip(sum(pvalsls)/len(pvalsls), .9999))
preds = sum(predsls)/len(predsls)
subm = do_clip(preds, clip)

if full:
    subm_name = path+'results/subm_full_pseudo_' + timestr + 'B.csv' #'.csv.gz'
else:
    subm_name = path+'results/subm_part_pseudo_' + timestr + 'B.csv' #'.csv.gz'

classes = ['ALB', 'BET', 'DOL', 'LAG', 'NoF', 'OTHER', 'SHARK', 'YFT']
submission = pd.DataFrame(subm, columns=classes)
submission.insert(0, 'image', raw_test_filenames)
submission.to_csv(subm_name, index=False)#, compression='gzip')
log.info('Done - files @ ' + subm_name)
# Out:
# [2017-03-21 00:54:36.586993] INFO: Logbook: Done - files @ ../data/fish/results/subm_full_pseudo_20170320B.csv

# %%
FileLink(subm_name)
# Out:
# /home/ubuntu/fish/data/fish/results/subm_full_pseudo_20170320B.csv
